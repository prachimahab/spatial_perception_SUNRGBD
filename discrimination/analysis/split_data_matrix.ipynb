# %%
import numpy as np
import pandas as pd
from scipy.stats import stats
from sklearn.linear_model import LinearRegression
import random
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from time import process_time
import csv

# %%
matrix_5000 = pd.read_csv('/Users/prachimahableshwarkar/Documents/GW/Depth_MTurk/spatial_perception_SUNRGBD/joint_analyses/avg_randSplitMatrix_n5000.csv')

# %%
bottom_mean_df_corr = matrix_5000.tail(12)
bottom_mean_df_corr = bottom_mean_df_corr.drop(columns = ['r1_Discrim_PC_125', 'r1_Discrim_PC_250','r1_Discrim_PC_1000','r1_VE_PC_125', 'r1_VE_PC_250', 'r1_VE_PC_1000',
                                    'r1_Discrim 125 RT', 'r1_Discrim 250 RT','r1_Discrim 1000 RT', 'r1_VE 125 RT', 'r1_VE 250 RT', 'r1_VE 1000 RT'])

# %%
bottom_mean_df_corr = bottom_mean_df_corr.drop(columns=['r0_VE_PC_125', 'r0_VE_PC_250', 'r0_VE_PC_1000',
                                   'r0_VE 125 RT', 'r0_VE 250 RT', 'r0_VE 1000 RT'])

# %%
bottom_mean_df_corr = bottom_mean_df_corr.drop([15, 16, 17, 21, 22, 23])

# %%
bottom_mean_df_corr = bottom_mean_df_corr.rename(index={12: 'r1_Discrim_PC_125', 13: 'r1_Discrim_PC_250', 14: 'r1_Discrim_PC_1000',
                                                        18: 'r1_Discrim 125 RT', 19: 'r1_Discrim 250 RT', 20: 'r1_Discrim 1000 RT'})

# %%
bottom_mean_df_corr = bottom_mean_df_corr.drop(columns=['Unnamed: 0'])

# %%
bottom_mean_df_corr
# Out:
#                     r0_Discrim_PC_125  r0_Discrim_PC_250  r0_Discrim_PC_1000  \
# r1_Discrim_PC_125            0.845700           0.770401            0.698639
# r1_Discrim_PC_250            0.769487           0.790371            0.759993
# r1_Discrim_PC_1000           0.689110           0.755223            0.839597
# r1_Discrim 125 RT           -0.635199          -0.615788           -0.558383
# r1_Discrim 250 RT           -0.689139          -0.667939           -0.643995
# r1_Discrim 1000 RT          -0.526533          -0.577867           -0.563033
#
#                     r0_Discrim 125 RT  r0_Discrim 250 RT  r0_Discrim 1000 RT
# r1_Discrim_PC_125           -0.638179          -0.689445           -0.524439
# r1_Discrim_PC_250           -0.615785          -0.669144           -0.577747
# r1_Discrim_PC_1000          -0.554250          -0.639392           -0.558559
# r1_Discrim 125 RT            0.817952           0.719764            0.600234
# ...

# %% [markdown]
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
plt.figure(figsize=[15,15])

ax = sns.heatmap(bottom_mean_df_corr, annot=True, fmt=".2f", cmap= "icefire", square=True, center=0, vmin=-1, vmax=1, edgecolors='w', linewidths=3, cbar_kws={"shrink": .82}, annot_kws={'fontsize': 14, 'color':'white'}) #notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
ax.yaxis.label.set_size(20)


# plt.savefig('rand_5000.png')
plt.show();

# %%
import matplotlib.colors

norm = matplotlib.colors.Normalize(-1,1)
colors = [[norm(-1.0), "aqua"],
          [norm(-0.2), "blue"],
          [norm(0), "black"],
          [norm( 0.2), "red"],
          [norm( 1.0), "yellow"]]

cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)


plt.figure(figsize=[15,15])

ax = sns.heatmap(bottom_mean_df_corr, annot=True, fmt=".2f", cmap= cmap, square=True, center=0, vmin=-1, vmax=1, edgecolors='w', linewidths=3, cbar_kws={"shrink": .82}, annot_kws={'fontsize': 16, 'color':'black'}) #notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
ax.yaxis.label.set_size(20)

plt.savefig('rand_5000.png')
plt.show()
