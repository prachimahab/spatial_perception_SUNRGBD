# %%
import numpy as np
import pandas as pd
from scipy.stats import stats
from sklearn.linear_model import LinearRegression
import random
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from time import process_time
import csv
import matplotlib.colors

# %%
# matrix_5000 = pd.read_csv('/Users/pmahableshwarkar/Documents/Depth_Project/spatial_perception_SUNRGBD/joint_analyses/avg_randSplitMatrix_n5000.csv')
matrix_5000 = pd.read_csv('/Users/prachimahableshwarkar/Documents/GW/Depth_MTurk/spatial_perception_SUNRGBD/joint_analyses/avg_randSplitMatrix_n5000.csv')

mean_df_corr = matrix_5000.set_index('Unnamed: 0')

# %%
bottom_mean_df_corr = mean_df_corr.tail(12)
bottom_mean_df_corr = bottom_mean_df_corr.drop(columns = ['r1_Discrim_PC_125', 'r1_Discrim_PC_250','r1_Discrim_PC_1000','r1_VE_PC_125', 'r1_VE_PC_250', 'r1_VE_PC_1000',
                                    'r1_Discrim 125 RT', 'r1_Discrim 250 RT','r1_Discrim 1000 RT', 'r1_VE 125 RT', 'r1_VE 250 RT', 'r1_VE 1000 RT'])

# %%
bottom_mean_df_corr
# Out:
#                     r0_Discrim_PC_125  r0_Discrim_PC_250  r0_Discrim_PC_1000  \
# Unnamed: 0
# r1_Discrim_PC_125            0.845700           0.770401            0.698639
# r1_Discrim_PC_250            0.769487           0.790371            0.759993
# r1_Discrim_PC_1000           0.689110           0.755223            0.839597
# r1_VE_PC_125                 0.605376           0.616807            0.579827
# r1_VE_PC_250                 0.583095           0.628077            0.608702
# r1_VE_PC_1000                0.554127           0.631073            0.650623
# r1_Discrim 125 RT           -0.635199          -0.615788           -0.558383
# r1_Discrim 250 RT           -0.689139          -0.667939           -0.643995
# r1_Discrim 1000 RT          -0.526533          -0.577867           -0.563033
# r1_VE 125 RT                -0.026406          -0.069129           -0.100657
# r1_VE 250 RT                -0.127723          -0.166216           -0.177883
# ...

# %%
bottom_mean_df_corr = bottom_mean_df_corr.drop(columns=['r0_VE_PC_125', 'r0_VE_PC_250', 'r0_VE_PC_1000', 'r0_Discrim_PC_125', 'r0_Discrim_PC_250', 'r0_Discrim_PC_1000'])
bottom_mean_df_corr
# Out:
#                     r0_Discrim 125 RT  r0_Discrim 250 RT  r0_Discrim 1000 RT  \
# Unnamed: 0
# r1_Discrim_PC_125           -0.638179          -0.689445           -0.524439
# r1_Discrim_PC_250           -0.615785          -0.669144           -0.577747
# r1_Discrim_PC_1000          -0.554250          -0.639392           -0.558559
# r1_VE_PC_125                -0.448032          -0.501056           -0.378422
# r1_VE_PC_250                -0.438043          -0.508773           -0.424335
# r1_VE_PC_1000               -0.434798          -0.512679           -0.432891
# r1_Discrim 125 RT            0.817952           0.719764            0.600234
# r1_Discrim 250 RT            0.718125           0.785465            0.593849
# r1_Discrim 1000 RT           0.598010           0.592385            0.671548
# r1_VE 125 RT                 0.278472           0.199866            0.304854
# r1_VE 250 RT                 0.313256           0.288307            0.394424
# ...

# %%
RT_only_corr = bottom_mean_df_corr.drop(['r1_Discrim_PC_125', 'r1_Discrim_PC_250', 'r1_Discrim_PC_1000', 'r1_VE_PC_125', 'r1_VE_PC_250', 'r1_VE_PC_1000'])

# %%
RT_only_corr
# Out:
#                     r0_Discrim 125 RT  r0_Discrim 250 RT  r0_Discrim 1000 RT  \
# Unnamed: 0
# r1_Discrim 125 RT            0.817952           0.719764            0.600234
# r1_Discrim 250 RT            0.718125           0.785465            0.593849
# r1_Discrim 1000 RT           0.598010           0.592385            0.671548
# r1_VE 125 RT                 0.278472           0.199866            0.304854
# r1_VE 250 RT                 0.313256           0.288307            0.394424
# r1_VE 1000 RT                0.313205           0.319231            0.364453
#
#                     r0_VE 125 RT  r0_VE 250 RT  r0_VE 1000 RT
# Unnamed: 0
# r1_Discrim 125 RT       0.278896      0.313250       0.309818
# r1_Discrim 250 RT       0.197859      0.288110       0.314079
# r1_Discrim 1000 RT      0.300654      0.391734       0.356549
# r1_VE 125 RT            0.394447      0.470525       0.403817
# r1_VE 250 RT            0.470823      0.492579       0.454284
# ...

# %%
import matplotlib.colors

norm = matplotlib.colors.Normalize(-1,1)
colors = [[norm(-1.0), "aqua"],
          [norm(-0.2), "blue"],
          [norm(0), "black"],
          [norm( 0.2), "red"],
          [norm( 1.0), "yellow"]]


cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)


plt.figure(figsize=[17,17])

ax = sns.heatmap(RT_only_corr, annot=True, fmt=".2f", cmap= cmap, square=True, center=0, vmin=-1, vmax=1, edgecolors='w', linewidths=3, cbar_kws={"shrink": .82}, annot_kws={'fontsize': 12, 'color': 'white'}) #notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)


plt.savefig('RT_rand_5000.png', dpi=300)

plt.show();

# %%
# transposed_df = bottom_mean_df_corr.transpose()

# %%
# # Modify the normalization range from -0.7 to 0.7
# norm = matplotlib.colors.Normalize(-0.7, 0.7)

# colors = [[norm(-0.7), "aqua"],
#           [norm(-0.2), "blue"],
#           [norm(0), "black"],
#           [norm(0.2), "red"],
#           [norm(0.7), "yellow"]]

# cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)

# plt.figure(figsize=[17, 17])

# ax = sns.heatmap(transposed_df, annot=True, fmt=".2f", cmap=cmap, square=True, center=0, vmin=-0.7, vmax=0.7, edgecolors='w', linewidths=3, cbar_kws={"shrink": .82}, annot_kws={'fontsize': 18})
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# plt.savefig('ODC_rand_5000.png', dpi=300)
# plt.show();
