# %% [markdown]
# # Participant Exclusion and Replacement Pipeline
#
# 1. The counterbalancing.csv contains every json that needs to be sampled for the discrimination and verbal judgement experiment (includes all durations)
#     - The row number for each sequence corresponds to the url fragment used in the variables file uploaded to Mechanical Turk
#     - This file does not change, the variables files is updated to resample sequences that get excluded
# 2. First need to match up reported participant worker IDs to worker IDs reported in batch data
#     - All data files downloaded from the server need to be matched to a worker ID in batch data
#     - Data files that do not have a matched worker ID are moved to a seperate folder and are not analyzed
# 3. Participant exclusion criteron are pre-registered on OSF (https://osf.io/28vjd) - if the participant is excluded, the counterbalanced sequence needs to be replaced in the variables file
# 4. All participants who have completed need to be excluded from completing future HITs (exclude_workers.csv)

# %%
import os
import json 
import pandas as pd 
import numpy as np 
import math

# %% [markdown]
# ## Get all Worker IDs from Batch data

# %%
batch_path = '/Users/prachimahableshwarkar/Documents/GW/FacialAge/FacialAge_MTurk/BNav_EC2/DepthDuration/v2_depth_duration_MTurk/all_batch'

# %%
all_batch_worker_ids = []
for path in os.listdir(batch_path):   
    if 'csv' in path:
        batch_data = pd.read_csv(batch_path + '/' + path)
        batch_worker_ids = list(batch_data['WorkerId'])
        all_batch_worker_ids += batch_worker_ids
print(len(all_batch_worker_ids))
all_batch_worker_ids
# Out:
# 1245
# ['A1V0QQXL4GNB39',
#  'A272DQ8XF1JSRP',
#  'A3QDDYBRNDFRXX',
#  'AJI75GZM88W8X',
#  'A2B7SPYBPF7H8I',
#  'A1202VV9WS418S',
#  'A1CI6CBNEE7P83',
#  'A367HZKP3V2WR',
#  'A272DQ8XF1JSRP',
#  'A272DQ8XF1JSRP',
#  'AHZP05WVFXXCG',
#  'AR3MFFPQ39IXF',
#  'A2R0YYUAWNT7UD',
#  'A1Q0495NMQY3V0',
#  'A2OW2CIT4H7364',
#  'A9Z4JCJJ9X7NK',
#  'A3TUJBPLJGTI5',
#  'AD1ILDUXZHASF',
#  'AD9QQRANGJBO1',
#  'A3VLYXEJ44AA4K',
#  'AT80V0Q1U2LCI',
#  'AYPP7T2JCJYQ3',
#  'A1Q0495NMQY3V0',
#  'AN0LMTB0P5DYZ',
#  'A1IQMLM2LGOKJ0',
#  'A6G80VHTBZKXM',
#  'A1S5SPI4NQPGSI',
#  'A1QMJNJ5FGC09',
#  'A3QS7DY7B9K2B3',
#  'A2SN83HIW24DO2',
#  'A2I1WSRFJAPQAT',
#  'A32S6OJJ7ORT6D',
#  'A45QRE7ZGA20L',
#  'A3JDWMS5QJHREI',
#  'A3QDDYBRNDFRXX',
#  'ALT6TQMZJKSFQ',
#  'A2D84R95NDZ2NM',
#  'A2BABL5AHUOYC7',
#  'A3KQ0JO0Z1JCKW',
#  'A3CZCT3O24OHLM',
#  'AQP4PHYDXRBPI',
#  'A1VLH6ZN45VELT',
#  'A25V9A343COS6F',
#  'A3A448MW1VKCV',
#  'A2V1TRRRG3IH54',
#  'A3P7AXWF57BHNX',
#  'AREQ43Q0T8ENT',
#  'AJPB9XHN9HI8I',
#  'A166U1L1KVMPCL',
#  'A3ROYCIEAFHRCV',
#  'A2792CL1I7J298',
#  'A1ZFXY30B31DSJ',
#  'A2HCPC2V4OYFDV',
#  'A130X6CF795CQ5',
#  'AYYSG3O9FNU15',
#  'A2ICS8FOBVLLRP',
#  'A248QG4DPULP46',
#  'ABVSR4GA6S3U3',
#  'A1QIJ94TJ6FZ2W',
#  'A13EXIOBU0UVX4',
#  'AGGSZSOV7LQP7',
#  'ANK8K5WTHJ61C',
#  'A1T7N4ZRWIQH71',
#  'A1Q0495NMQY3V0',
#  'A7GT7BIC7ERWE',
#  'A2JGXBZNNX65ZS',
#  'AL42QQ0WUTNJY',
#  'A2325LZL2NO9BI',
#  'A4T4577P6JL6R',
#  'A1BGJG22X6REWU',
#  'A34K78HC5PDZU',
#  'A3GVUYY3TWRPZT',
#  'A23AIRWHYDPJON',
#  'ANZ4YBNNFVANB',
#  'A25VPV47HCP6DX',
#  'A21UA6O7ZFAIQJ',
#  'A314KKX6ONDO9O',
#  'A36FX03TEPQJZP',
#  'A150QX2OXHGK8P',
#  'A20N1NK5X5S88F',
#  'A5KU3E96BTL5V',
#  'A50UY1556VDIA',
#  'A2FQJCE190UHGQ',
#  'AAAWYYHUPGICY',
#  'A3ATU3VULAB7K2',
#  'A1TR2AOKWGQ78A',
#  'AEE63S661IS42',
#  'A2CA811M94B7NX',
#  'A3NXXMACEGVNIO',
#  'A2GOYSTIL3LOV1',
#  'A7GXQWPMIDQXG',
#  'A2POZSQDZE5C10',
#  'A1PTX4IB9R34LI',
#  'A7QBBXOG4ERRC',
#  'A2I43BDUPAM00C',
#  'A2P8V5SKYLL5I4',
#  'A204Q4T20BP8V',
#  'A36O3E1S5G5PAF',
#  'A2INXY39KBM92F',
#  'A2POU9TTW177VH',
#  'A3RE6BNYBWY42N',
#  'A3L0DCUXI7X3A9',
#  'A22JX0Q72601SW',
#  'A28AXX4NCWPH1F',
#  'A2QYXVJ6EKJBE6',
#  'AR5M3HHTQV9QY',
#  'A2T0P6DJFRIYJV',
#  'A24LUXW1DB1QI5',
#  'AL9SYQEUTNJXT',
#  'A159XL8NQQPGVK',
#  'A3G5OWGKHW6OL5',
#  'A2JDYN6QM8M5UN',
#  'A2X2DE9X949ECT',
#  'A2H1QUGX0SOUMH',
#  'A2IWZJPO67CAJ3',
#  'A73YME7RH2718',
#  'ACVWP0MRAU69A',
#  'A1XBWSV6TWJUU8',
#  'AXFCUZ1WQC2WY',
#  'AGJC17U0NL98Q',
#  'A38MMDL2ALKF0C',
#  'A2M5S1RXUCVE7L',
#  'A1O7AO7GD0SO9W',
#  'AUZNL6ARA1UEC',
#  'AONSG5WOC3OX0',
#  'A18AFIIAQOVC1B',
#  'A1ONILGBGJ8Y5K',
#  'A1BT6QJIRC46BB',
#  'A2EK1HDV4I4GSK',
#  'A3UUK65H63DHFX',
#  'A2RDRBB3EHQQN8',
#  'A1JXSNKXAXT9OU',
#  'A1WDKH2DYOYE8X',
#  'A2FOUSWQDYHIE0',
#  'A2LQO0696YYC1Q',
#  'A2T675UCHNTSSW',
#  'ALVDC8JPRXPF9',
#  'A19X8IA9EKC3XH',
#  'A3EYXR4HIZ4YL6',
#  'A2EPNHL2SYUUHY',
#  'A24LLJNSDBFVET',
#  'AICBYPYVA7NJ5',
#  'A2I4A21ZDS0GI7',
#  'A290HFZXIMBJ6W',
#  'AMJ5KVUCSZGGB',
#  'A2ZDXFFGSPHGBE',
#  'A1198W1SPF1R4',
#  'A2UYZFH5VT5R3H',
#  'A1C2TCLM2AT8LR',
#  'A2QATEH8PN2ZM8',
#  'ALUUZZUZ1EFJC',
#  'A2CWJRAEFZ44HU',
#  'A1W7QIHUF3MK9O',
#  'A3LO255HM94WIU',
#  'A22JX0Q72601SW',
#  'AQPFTUIJ0PW2N',
#  'A32OTBQ9Y8ZJUP',
#  'A3IQZGY36P090H',
#  'A3AKL0KTXI947R',
#  'ACSS93E03ZUGX',
#  'AX030GX2193N7',
#  'A6WYBPPG8Y2Q4',
#  'A2RNCA7PK35LHT',
#  'A2NDII2PZFIF5F',
#  'A3CVY8G619MGTI',
#  'A1AF2XEWM0KZ87',
#  'A2OZGNW6THEMJ',
#  'A217DANTQBBTW9',
#  'A53MOLGRRDHA4',
#  'A2R6KLBXVM5ANW',
#  'A34AZLYRHH6JJA',
#  'A2IV3SSVTU90BN',
#  'A11LNK1U3DT08V',
#  'A1BNTJB3GL8PQL',
#  'A2XZS401Q3PCH',
#  'A1RK093GG6Y1C9',
#  'A24GX1OZE6AY04',
#  'A24LB89P1BPKKF',
#  'A30RZC1AY4SCU',
#  'AT1JIRG16U42',
#  'A2QRJKXTK4JDD8',
#  'A3L9EN8YL1HZWF',
#  'A2OO4PG3LBLP5I',
#  'A35UWTV3KR42YN',
#  'A1RB4N7CLORR05',
#  'A2L0J2NQ0NDJQK',
#  'A3JGB3OMTOWR6I',
#  'AIH1A74CGJNB3',
#  'A11FRLH5KWRLBV',
#  'A2Z9ZZ5338VZOK',
#  'A1VFOKKVJ7B9D6',
#  'A2E5PV1BHNG67N',
#  'A1VVZ9XJIL1C0S',
#  'A122R62XGKRFDF',
#  'A3MJQ51KN9CMQ4',
#  'A1ZI4VU6650Q8B',
#  'A2TYVYRGXYSXJA',
#  'A7N7RA5KJRS57',
#  'A3SLT6KVF0NXPH',
#  'A3R97T5D3RR9JX',
#  'A3GTQ61TA3K2S3',
#  'A2FP41BSPG0Y4A',
#  'A1YRYQBQGQRY1Q',
#  'AIA7RZSAONU5M',
#  'ARWF605I7RWM7',
#  'A25N0K40JAZTN1',
#  'A1DBR498DU038O',
#  'AM8ZEA3RDPGSA',
#  'A3KQIZEPJJ7HV9',
#  'ALU19ABETSAY5',
#  'A1J4TXVBRW33KN',
#  'A1YFVXP4A1CXSF',
#  'A2WXZL2CB67AJH',
#  'A25PFSORDO3SWQ',
#  'A26WG74M652I3P',
#  'A196XR61DIW5GU',
#  'A2B9FATIOQ6WIO',
#  'A35ZVN8ZE9M60P',
#  'AZ5KAKZR0CVR',
#  'A2A6FH0F7LD9ND',
#  'A2IQW7R7L2RZAW',
#  'AFB3HRG78PD9H',
#  'A3V7HHS20YFRT4',
#  'A22DF0EWILGRLV',
#  'A3UZYBO3EGBDWR',
#  'ADS6ONEBLIK43',
#  'A28RL79ONUXTET',
#  'ADQB1CIQFO2V9',
#  'A7204W9E8IR1R',
#  'A3RCX3IQ8L6HHW',
#  'A2KW87ZD2ELYNG',
#  'AU566WRASK7Z0',
#  'AD15OW944ZV20',
#  'A2LHZMUV3Q81X0',
#  'A1P6OXEJ86HQRM',
#  'A2TZVJFRJ5I61B',
#  'A1SGTL6LGLW4DK',
#  'AQKRSW854ATWI',
#  'A3AP75LII2NPA',
#  'A38KCCSGBFR26L',
#  'AHZCC2V399WUN',
#  'A1UTNAK70QH9JS',
#  'A2PP6W7AW3NMFY',
#  'A6WXIKRYMXNIN',
#  'A34YDGVZKRJ0LZ',
#  'A2J4Y484J54JUA',
#  'A4U30E8MK1F4J',
#  'A2U556B3L5HSRO',
#  'AOOU57BC3GK9J',
#  'A2MJQG58XN41OW',
#  'A1NZFJHVJ9CNTO',
#  'A3KP8KFGG6734Q',
#  'AY1AFPZSEV5E2',
#  'A37R0JYAB3QEX9',
#  'A3VG22WR5I4UG2',
#  'AKP66RIZ3LQVX',
#  'A2AZYU1CT24O0K',
#  'A3DKSG1VT6L74U',
#  'A3ROADR7T6811',
#  'AZ69TBTDH7AZS',
#  'A2VFEDAK5C1E1O',
#  'A2OVX9UW5WANQE',
#  'A3UKRC3LBM1LEW',
#  'AGILQEFEPEK7N',
#  'A38I0E8UK53ME5',
#  'A1WSW7HWIF100A',
#  'AY7LRW5Q88WL7',
#  'A10HW8JXM17XLD',
#  'A1GEO1VUUQQ9K2',
#  'A12HZGOZQD5YK7',
#  'A2W5MSZP0O4Y2P',
#  'A26M997VYVK0E6',
#  'A22HIX1M4QXZBB',
#  'ATNY69UI91LMQ',
#  'AZ8AOL78L8C84',
#  'A2Y69684WT44XU',
#  'AD16ZVR7DUHWB',
#  'A222EOOD8O2IC9',
#  'AEWPAZBYA7XE',
#  'A2DSTHSND3PKN4',
#  'A2Z46Q1JXM6LEP',
#  'A2GIKDMPOC253Z',
#  'AUG6ZXYNR9TYB',
#  'A22SMU2MZ4FXYV',
#  'A10A7EZUXBD0II',
#  'ATPW1MWLW7RBL',
#  'A22DVMN2Y3XHWA',
#  'A002160837SWJFPIAI7L7',
#  'AG2YM9OWQP690',
#  'A2PPTQXFVA9H38',
#  'A210JGTRF11SFM',
#  'A1NOUBYTTZNNAZ',
#  'A1QUQ0TV9KVD4C',
#  'A2YTO4EY3MNYAJ',
#  'A1PNC3NZ8PQJUI',
#  'AOCQ83IC3FRUQ',
#  'A2OG7XGWOX5ZEF',
#  'AFK9ALQK5GPNG',
#  'A1ZD9SJXQ9C6EW',
#  'A3L5PJVWSIAAPB',
#  'A2R28I9SM3G0YL',
#  'A2C9OFEV72G568',
#  'A1W9J3UXKDM3DN',
#  'A3RC6TFQ9QHMXI',
#  'AUZP4FPD6UTNU',
#  'A1I9RLJQ0BYN21',
#  'A27Y2GMAKJ5OWE',
#  'AURYD2FH3FUOQ',
#  'A13WTEQ06V3B6D',
#  'AGB6853RIDWJ8',
#  'A1O57XVTTB1PNZ',
#  'A8C3WNWRBWUXO',
#  'A3AGXTSAHA2AFL',
#  'A2B1YSMEHN1G2K',
#  'A3I40B0FATY8VH',
#  'A198MSVO1VTAT5',
#  'A1901T07YJX1OD',
#  'A146QN6EU8LAEI',
#  'A9MJVJAMLCDMV',
#  'APF8F1M25DW76',
#  'A22CWNSGO4UVGO',
#  'A30GJ0HHLO16E8',
#  'A2JM5TNLFXS4ZV',
#  'A3N15463MQO5VF',
#  'A1Z1O6MMOB3UWW',
#  'AGANKP4PUZ4NC',
#  'A2KLIBLDVDV144',
#  'A2V27A9GZA1NR2',
#  'A1QUBLZCONL4QD',
#  'A3GO1DF6EIHJTL',
#  'A1VSEDABJFNUVQ',
#  'A1TVTGQOTEMGN3',
#  'ANZBO8QBL5XIU',
#  'AN7Z42U38BCQT',
#  'A38OPVI04AH4JG',
#  'A32IA0BBKKXZNK',
#  'A5P12YJP805RG',
#  'A166BS4L4QUBR9',
#  'A2I6HVUDBTGD1',
#  'A1XVEKS9O73ERE',
#  'A2I5G9ES6TS73M',
#  'AV7UX8QQXABSK',
#  'A2OT9ZJC4MQBS8',
#  'A1KVU6F3AVWW3A',
#  'A2VO8C41JJIQY9',
#  'A2TXZVXQU5FQZ9',
#  'ABLZE51NE44U8',
#  'A11MOA9HW11EP1',
#  'AIPLQYDLUSJM5',
#  'AKAM01E1R4KAF',
#  'A3KF6O09H04SP7',
#  'AG053ALQ5ZNCU',
#  'A3QK8YZIOP3LFB',
#  'ARRDHASPCGP4L',
#  'A3LMWQON9V2647',
#  'AE33JO53WTHZQ',
#  'A1CA6ZXKK09ZRI',
#  'A1TW2BZRRS874Z',
#  'AR8WYVS06UUYG',
#  'A1TW2BZRRS874Z',
#  'A1XIXGOB9KUMPJ',
#  'AAQREZOK13OV7',
#  'A1F0VEHWK3IAF4',
#  'A9LSEP71DNP4O',
#  'A16335MOISDG1F',
#  'A2U5OFMW8H30PC',
#  'A2E5CA83JIWPLF',
#  'AKZD89B2WLSX7',
#  'A2YTQDLACTLIBA',
#  'A2U5OFMW8H30PC',
#  'A37OUZOGQKGMW0',
#  'A3VHDQR8A9JJ4F',
#  'A2FFCQ9WU6R764',
#  'AROBXX0BPY0HZ',
#  'A3V24QUVVYM6C2',
#  'A1Y07DW8W2UXSD',
#  'ASNNAP90D5R1Z',
#  'A16N2JY89NKZN0',
#  'A26LOVXF4QZZCO',
#  'A3OFMEOMELZBBC',
#  'A1N35VV9QURKHX',
#  'A1QWXHF5EY3Q2O',
#  'A16N2JY89NKZN0',
#  'A3V24QUVVYM6C2',
#  'A4VUQ6627RJX8',
#  'A21AOJ6CWLKOME',
#  'A2CNWM7VG2VGTU',
#  'A3O8GRC06KG44S',
#  'A3V24QUVVYM6C2',
#  'A1FVZ9R0G7ULVS',
#  'A3A5IVJ55VFNIG',
#  'A1FVZ9R0G7ULVS',
#  'AF6OFCID04GG2',
#  'A3V24QUVVYM6C2',
#  'A39B6A084FBJM7',
#  'AFCMHQWCV6N02',
#  'A1HTR3THFK84RM',
#  'A3V24QUVVYM6C2',
#  'A1S05Q05GCT274',
#  'A21AOJ6CWLKOME',
#  'A18D69774I4CP8',
#  'AF6OFCID04GG2',
#  'A174SEDH0AZG4H',
#  'AZBM9ZNBJC3VM',
#  'A16N2JY89NKZN0',
#  'A43Z9G68U5GAF',
#  'AX8D3L76H0JR7',
#  'ALTJ8ONS93XVL',
#  'A2ADQ1YRXFBEF0',
#  'A2BVVFXMQU8AC7',
#  'A33A8Q29OSATZ3',
#  'A2I2VRN2PLOU7T',
#  'A3V24QUVVYM6C2',
#  'AE9KNJZWDCDSE',
#  'A16N2JY89NKZN0',
#  'A36QBKROJ4J9EJ',
#  'APDGHS08BD9J8',
#  'A1F9Y1M4EA0JWE',
#  'A2N4OJ2EQ6JNH2',
#  'A3V24QUVVYM6C2',
#  'A2HP2YBJF23XCY',
#  'A3NAONPCTVT6P1',
#  'A1PHX1B7PE52AR',
#  'AB1UHU4WQ9HFT',
#  'A34IPEKX5WXJIN',
#  'A3OGL1QQ4S6FH8',
#  'A3LGUYS3JU2C1T',
#  'A2615YW1YERQBO',
#  'A3E2NJU0V1O57Z',
#  'A175U4Y051W1UB',
#  'AF6OFCID04GG2',
#  'A1XCIN7E0QP1T8',
#  'AJZ6XER6DE8EE',
#  'A14YCUVA8HEBX7',
#  'A1QROF5BIOVI42',
#  'A3EFZUISB9NM1O',
#  'A27LZHCYFKQF60',
#  'A11KAZJGSOI573',
#  'A29UY77DJOCTRB',
#  'A29GSA76584SDW',
#  'A29UY77DJOCTRB',
#  'ATRB1HXZI3J2P',
#  'A29HCQ4JD64IS4',
#  'AJUVX0E4OPTAO',
#  'ALAMUAWFEZOXS',
#  'A15UL5WCZIZCAV',
#  'ANUA9X7BFPTR8',
#  'AGGVIMYQUA422',
#  'A2TZAXWOB3JMNV',
#  'A2P0EZBOOTBSAL',
#  'A3NFDDC2C6FKFJ',
#  'A1QROF5BIOVI42',
#  'A38DHLB88V8DL8',
#  'ALMXF26GM2PV9',
#  'ABVYNKCG6HU4R',
#  'ARQR5NIFA1AJ',
#  'ATZUUPHDC1ZQY',
#  'AF1AVB9D96QPR',
#  'A300NAQPMR0IN4',
#  'ATRB1HXZI3J2P',
#  'AJIT8FWMXWUO0',
#  'A2YS1UEOU64B4B',
#  'A29UY77DJOCTRB',
#  'A24QPBC5B055SO',
#  'A6U2C66WQ7QQN',
#  'A3GWRDHAURRNK6',
#  'AF1AVB9D96QPR',
#  'A3PQVDFT21IISU',
#  'A37RMDBOSPZG49',
#  'A38OKN8QAGRENA',
#  'A1JJYY622DGE5L',
#  'A4H1T35G1RHI3',
#  'AU6X92Y30ALJY',
#  'A2NVO55DO76R80',
#  'ABVYNKCG6HU4R',
#  'A37RMDBOSPZG49',
#  'A3R2EH58I8Q4YI',
#  'ACUPJ84DZ037N',
#  'A3RKPAQ8P9F3HW',
#  'A3SBR6IJQRCSPV',
#  'A11SKEBNP69NEH',
#  'A19PO2S1CDNJMQ',
#  'A2WNETMZ039ZEZ',
#  'A1B8QUOSZEH4S1',
#  'A3J4YYW1M62T39',
#  'A1I91OUDL75HZR',
#  'A3S3T7941MO2TC',
#  'A1WT03BP7QHTZZ',
#  'A3P41MYFVUJVDG',
#  'AFYIL9DFX6BFO',
#  'AQ72I9YDIQK2K',
#  'A1RKGN3VY39TM1',
#  'A2W3KKNN3CAY66',
#  'A39OX2275DREWX',
#  'A3QUC7F5K52EF6',
#  'A3UA50A6GKNAMR',
#  'A1T10I5ZOOWH8R',
#  'A34SHVXJXDB8SQ',
#  'A14RXHR3LV6HD0',
#  'A16LFEFTDWJ5M4',
#  'AHJC56KSSXTIX',
#  'A3253Y8PCTZD2T',
#  'A37GPEF28AUCRO',
#  'A1H198MRIM37T1',
#  'AKPQABK355ZRA',
#  'A1QDEYCJK9WLV6',
#  'A3SETW6ELRDABV',
#  'AYFNEVUBL6C3U',
#  'A1PS8FTSVOJ4PB',
#  'A8R24ZO89Y9JL',
#  'AUL5G0SQDNAB4',
#  'AY4E884XE9P1H',
#  'AUJ4LI3U3F5KP',
#  'AM60DFH3IWY61',
#  'AM64GU7LGD95S',
#  'A320QA9HJFUOZO',
#  'AE68XSMXAYPWQ',
#  'A1Y3JL53XAO7QV',
#  'A2S9A5Z7CNE85H',
#  'A2TUYGXQ15U6GO',
#  'A2S9A5Z7CNE85H',
#  'AQCZJ81IS07OK',
#  'A3DTG2QEFWI2II',
#  'AMOBC1D09Q381',
#  'A2HJKL3641S7R',
#  'A1VRG5HKZC0H0C',
#  'A34WQ0OT0BH5H8',
#  'A2JMUV03Y7WLMK',
#  'AE68XSMXAYPWQ',
#  'A2HY3P2X27JDPJ',
#  'A2UJ9GDNVPX99C',
#  'A3KPBZ6F79334Y',
#  'A1RQ9S6WXZBNRT',
#  'A3KKWOUZ07G9WP',
#  'AOHS348RVOF6D',
#  'A2MSUZAK2Z9U88',
#  'A23GMTE06W7ASR',
#  'A37GPEF28AUCRO',
#  'A1QW2XUJ7KZCV5',
#  'AD6DHC6L39T93',
#  'A2ZDWWWAZUYHFT',
#  'A2MNSQ78CI0ASZ',
#  'A2NXZIK5NTML18',
#  'A158DJDP2AM46C',
#  'A1WMPXACESD2U4',
#  'A1PHDT66U6IK4Q',
#  'A1DUPOUC9RNU4L',
#  'A3EHSE72YO5P4U',
#  'A11BAIN13IGWCW',
#  'A34DYM8J0X5VK',
#  'A3UMTOQOGO7TE0',
#  'A10JXOU89D5RXR',
#  'AMHUDJ44HF1ZH',
#  'A2S9A5Z7CNE85H',
#  'A1SHLWKA0UH1IS',
#  'APVZGZM1RA3AZ',
#  'A1GKD3NG1NNHRP',
#  'A16QKOP6SK781C',
#  'A21HKKY734LWFV',
#  'A3KVKK1XLBTSN3',
#  'A2S9A5Z7CNE85H',
#  'AHW8VQZD6IUJE',
#  'A1KWIJXTC47YWE',
#  'A34BAS2ZIJU5HF',
#  'A1QUN55HKPGNVT',
#  'A133K3I5MRCJLN',
#  'A319K0FNHMV2PA',
#  'A489K1IFOM4JW',
#  'A2S9A5Z7CNE85H',
#  'A2QXWED78VRCMQ',
#  'AE68XSMXAYPWQ',
#  'ABBP9JASL9AGK',
#  'A1QRIZY9WJW3R1',
#  'AKJN72HW14WTR',
#  'A2GDP2A4JZ9W1G',
#  'A3S5ZK75DW9RL4',
#  'A2VM35YB03X6U',
#  'A14OQ52EFQAN2W',
#  'AS787OL64GYWX',
#  'A2A22YTFKJ087P',
#  'A2ASWA01M4JZOK',
#  'A3DI1J4TY77LC0',
#  'A3COKL7K5AYZGG',
#  'ALUP4ZKEXJFYL',
#  'AOUMBJ947AOIH',
#  'A222GZB608T1B8',
#  'ALUP4ZKEXJFYL',
#  'A3QUC7F5K52EF6',
#  'A2F06TCLNQ33LI',
#  'AB5WBMZGLX57B',
#  'A3PYD7EU2WFST6',
#  'A2QXG8VJRBZ2Z3',
#  'A26GTSC1T6RFFK',
#  'A1KGUJMWDCPSYG',
#  'A7ICWE63PPIH3',
#  'A17KUG7M9BQVPC',
#  'AEOAO9KFNSOY2',
#  'A1PX4CR15QC57J',
#  'AE68XSMXAYPWQ',
#  'A3VV90KUTGBIN1',
#  'AEJU0MCYOQC77',
#  'A2UGM73EHLK6XI',
#  'A27HVVLSZZ13XK',
#  'A3HQTF6HZUPMT2',
#  'A1YHIQHLLLQIIQ',
#  'A3FR700NRB419O',
#  'A3IVMXS41NL0IX',
#  'AU849EHZNGV2Z',
#  'AUL5G0SQDNAB4',
#  'A2ZGNQB9CFAODO',
#  'A2Z2WC3DJQ38RH',
#  'A2XHD64QUKA5Z6',
#  'A3MWLHSW9B9RHU',
#  'A3HY9H1ATZW26A',
#  'AH0NG7PISCRNQ',
#  'AUAN582MLI96N',
#  'A2OETAZM3SMWDG',
#  'A20X6V1AAXZGNZ',
#  'A1MDIJ01QRX4WW',
#  'ASZFR1M9LX14R',
#  'A2E41JCN5F4JYM',
#  'A30CKD84V82EH2',
#  'A225J5T6WHO2MG',
#  'A2EHH2ZFIRF1BF',
#  'A3YG4NM3FQQQY',
#  'A209KMZQTLEZZC',
#  'A2HMWCWV060NFO',
#  'A1QC1K71RGKZBI',
#  'A1MGSRTTYYD5AJ',
#  'A1N8TKTLXV92QR',
#  'A3IMM3YOEK9D3H',
#  'AHWX1CVVMZZTI',
#  'A1IKAI6PWMJIPN',
#  'A1C5SQZ045W0L5',
#  'A1EU5WEVXH6AZ0',
#  'AJVIG3GTWRQ2E',
#  'AHWX1CVVMZZTI',
#  'A1FWHWZONTCAEN',
#  'A2NQR8NLH5P3IH',
#  'AMDLKML019HT1',
#  'A256QIR5XUIP8K',
#  'AOQP9IL4MK3ZQ',
#  'A1AOESAIFG8K9Y',
#  'A3OUAR84WQO03Y',
#  'A2AQHNDSH2TG3C',
#  'A2ISLV6X3Q81MS',
#  'A1338G6KF4JUFI',
#  'A3AY0315YWWNXY',
#  'AFJFYJZ849YOZ',
#  'A3D1F7PGBYEA5F',
#  'A2JDUV4XMJSN55',
#  'A3521EZSIHMVZV',
#  'A1FMVUYV72MUO3',
#  'A28QZ8YDI84V0R',
#  'ASVRLMDNQBUD9',
#  'A384KX8MUIJSTJ',
#  'A8GLGHP1KIF9X',
#  'A2IHXTGWRC8SVQ',
#  'A3BZH91MITQA5X',
#  'A2H8PEGI28NKZD',
#  'A21ZT1N7WFR1KH',
#  'A1ST0FIJXMNPPW',
#  'ALDWKDNI1KS69',
#  'A175766N4ZEO2R',
#  'A1SEI7LVSP35BI',
#  'AJVLNHSG2YU23',
#  'A36SM7QM8OK3H6',
#  'A3QPVH0DRW0ZQV',
#  'AUR7WEK868Y2B',
#  'A2PSR3CMNR1R9X',
#  'A19DHVVUJJCUX4',
#  'A3QNCW3LR2AVOV',
#  'ATZALLLXA7YUH',
#  'AMQ1TPD2W5PIN',
#  'A1B81RS0ELC70N',
#  'A2BIB03B8PIC0',
#  'A1T6QVMIXF74FF',
#  'A39SK1E6IMQBD5',
#  'A17IPELR5NC2LZ',
#  'A3P5WIW36V70AI',
#  'A3C8NUIBNZYMT2',
#  'A2KW26KE43UBRS',
#  'A3I65SDKOXEG8Q',
#  'A1NQ2A0UDW719R',
#  'A1EYMT1R73LE02',
#  'ASC9DUCC64M3P',
#  'A304UJAE051J89',
#  'A1UJRE4S5E8RM8',
#  'A8V0L2YF8U6OX',
#  'A21MIT8A34SU6R',
#  'A20K99JZE0L8HU',
#  'A150XGQ7KWLBWN',
#  'AS4NIEQJWCG3M',
#  'A5V1DUOOKE1O7',
#  'A2KRPK3GQR0GA9',
#  'A38I55GISTO61M',
#  'ANEVIDK1EVP9V',
#  'A2Q03D83LCCJNN',
#  'A2TSPXWH2Q6XX7',
#  'A2PF6UAA5SUVD0',
#  'A1F1TBDHPYAAXT',
#  'A2ZWLEDD3WZQH5',
#  'A3RHJEMZ4EGY2U',
#  'A37GOI3N77WX21',
#  'A345ZKNQSVPJ6G',
#  'A3PBA2ZHVZFGA3',
#  'AP4B1GJIT3HYF',
#  'A1BG1RLKK0V30S',
#  'A1XT18HD14FKF3',
#  'A3MNL6RIME0845',
#  'A1IBY7KXFHJ2U2',
#  'AIHIOO54ER5U4',
#  'A18N73E0G2H2DT',
#  'A3PJWT1Z1FHYCJ',
#  'A1IMBZEOTAZH36',
#  'ARGB9ZW3K0JA6',
#  'A5EJ10KD1ELO4',
#  'AJVLNHSG2YU23',
#  'A1ZHKHFLN8A1XX',
#  'A2GM1ZIBRBHBK7',
#  'A3BN69Q9D7RQGR',
#  'AKWAO862UBFU1',
#  'ANKDLLQHHM2OH',
#  'A33GZS6SU4O20M',
#  'A1ROEDVMTO9Y3X',
#  'A70E1IDLQXLCR',
#  'A1K6ZE1UVDPWH',
#  'A19W20MG7V94UC',
#  'A1778IAJQM9EFI',
#  'A2VR9O234UCT9T',
#  'A1IAMR0PW3L68Z',
#  'ANBWJZYU2A68T',
#  'A3I9743KVD971V',
#  'A1WRZX4HNRMVG1',
#  'AKIT35WR8HEQ3',
#  'A3U2UNSYDPS933',
#  'A3HFB277V5OXY0',
#  'A6Y7SZU9L301W',
#  'APRZ7BR8C0ZMQ',
#  'A3MZUG72V5PSN6',
#  'A2ZT2Z0LQ05EGZ',
#  'AJT7C07A187KA',
#  'AJ9IY4IHOGB8',
#  'AXTZU0PO55S3S',
#  'A4ANRSA55IW5Q',
#  'ASGPEZJBT5XL1',
#  'A2S64AUN7JI7ZS',
#  'A161VPQSXLLV8U',
#  'A24ZP6TOKYBSQS',
#  'A2K08PIXXDQLU0',
#  'A2DQ0OE2TBY9E0',
#  'A29EHRCM8MT04O',
#  'A25CZJEFKXF4UV',
#  'AMPR904VJJFZY',
#  'A2F02S5813Y88Y',
#  'AF3YJOJWCSJH2',
#  'A2E8PL8ZWIZVJ0',
#  'A2J1ANUL0BYKUK',
#  'A28ZPY6D5AS7GZ',
#  'AQAHBOI7F89RS',
#  'A3E50NZCJNLDG1',
#  'ALY0MSI8P4OY2',
#  'A2NQRZ6SUEVU6F',
#  'A3EPGICC2GJ4E1',
#  'A83IAKZR4HBSJ',
#  'A32S8F6DJQWNEW',
#  'AP9WIQ4P78XLH',
#  'A1RC4Y575PV6EG',
#  'A26F7OWQB4H0CH',
#  'ANPCXN619ACW9',
#  'A3QAL3X23LHJRV',
#  'A1SLKRR55Q38IB',
#  'AR2BL2Q5E6VG2',
#  'A1ILCIHMXPNTMT',
#  'A281ASP4WWAN3E',
#  'A1YFFKN3QVV54D',
#  'AV3NMCN13C6RM',
#  'A3OYUJ6E6BJS4H',
#  'A262M5VGNQWDWN',
#  'A3ET5RWBP1Y4AS',
#  'A3N3F3JSOX6R8N',
#  'A3LVLZS8S41ZD7',
#  'AEMOH1QUKXF30',
#  'AUBKB2XCGMMGQ',
#  'A2YP60DM1HYTH8',
#  'A1GRPIBHW72HDU',
#  'APFIMQRTK6ZKF',
#  'A2D1S77G7DNC54',
#  'A3JJXDML3XNSQP',
#  'A1DZMZTXWOM9MR',
#  'A3E53WAR22AMQE',
#  'AE1YA7Q3UKPRI',
#  'A3EW15VNSO5ETM',
#  'AKWDZRXE69GDZ',
#  'A1BX8H3Z8REARA',
#  'A2Y0D217B4JP6I',
#  'A3B8E6GBXK1PTC',
#  'ACF6USGTSNNXC',
#  'A3QSSPYCKPOVFA',
#  'A49MH7IW4LBF2',
#  'A3U8LNGMQCTDWM',
#  'A3K1X90ANB3LLA',
#  'A2GWQ4Q0FM2FG2',
#  'A2X504PZFG8CZ4',
#  'A2P9XYDUCQBXWD',
#  'A41APS6V2Z1FJ',
#  'A2QOAXQSUU7FJU',
#  'A2DVDC9AM2E9ZG',
#  'A1F6E5PY1CFLOU',
#  'AYJGQBBK6KXZ7',
#  'A28P7V6WDT9UN1',
#  'A3A189KXWG4FCC',
#  'A3GU499FNULYO4',
#  'AGQ38QZYDWFO8',
#  'A28T38MOUG43YD',
#  'A32EI0CIDZ9Y4Z',
#  'A11KAZJGSOI573',
#  'A19QYNI3MKP596',
#  'A3SFVRSWTPTI0Z',
#  'A1UNBT94I82S8V',
#  'ALCPF5NANBDSZ',
#  'A12UVATD5QVM9D',
#  'A18ETK32CHC9SW',
#  'A1RQ8PX7A0CH3C',
#  'A3NS31CYXLXTDA',
#  'A29GSA76584SDW',
#  'A27V2X7J8UB0D6',
#  'A1TARNH07A75CG',
#  'A2ASTDMWBCFIP0',
#  'A1S6USUGXW9P64',
#  'A3D4ZHM3ABM5Z3',
#  'A1KZG9HWOQ37O7',
#  'A2RVYHVHA7R8K7',
#  'APFU7910K4Q1L',
#  'ANFTCHPCCM1EK',
#  'A3LDN70TZX0BID',
#  'A28WG7JHEK2E6D',
#  'A34U4186EW0B9X',
#  'A2QNV9X7MBBS2L',
#  'A3QJ0LIK6SS3PG',
#  'A6F5YYYKILYBO',
#  'A3R365XR78WL9P',
#  'ABIQZEIRUG8QV',
#  'A1439J8JQICLBM',
#  'A2ILUP6FN8HKKC',
#  'A1WM3INNDW2776',
#  'A3R365XR78WL9P',
#  'A2CDR7S8UVQW23',
#  'A2QCQGZD7T1QNL',
#  'A3FSDH6HUZPNQ8',
#  'A1LJDITM8FGL5U',
#  'A2GJB2BS2M51JP',
#  'A2Z58PTI5RFDKK',
#  'A1OAZCVZRC00F0',
#  'A2MCG5W6LHSRG9',
#  'AERUGBNS48Z4N',
#  'AYVKWUHE8VHQ1',
#  'A3CWEIEY3TGJFX',
#  'A3LB1WIJ645EL8',
#  'A1TLNLB9D87H6',
#  'AMZKUA5AFL4YM',
#  'A1MTRZDRKNB9GV',
#  'A36FOHCO9QTZ0H',
#  'A34MGGU0MWL82E',
#  'A50K26F2IS94U',
#  'A3BI98I9V2FL0T',
#  'A392WSCAS81ZMT',
#  'A2FAA1LR6UERGL',
#  'A3TI4G63J6VCKV',
#  'A3LOBI8KGKM59C',
#  'A22UMPYYQBXT0F',
#  'A2Z6NL0CTXY0ZB',
#  'ATDUJ4FA1HP9Y',
#  'A32VLTWRJ1EP5T',
#  'AMLE1FC3SQVL8',
#  'A3JGVZEXXELM3C',
#  'A3OZHKAI24FEIE',
#  'A1AXN8VOE1LBL3',
#  'A14WLAP6TCEKO0',
#  'A1MT4FMXL4WRAF',
#  'AYVKWUHE8VHQ1',
#  'A2F1AA15HG0FRU',
#  'AAS6JE0EH82SO',
#  'A3LVI3GY17D0MG',
#  'A2PI8JNEQCROH0',
#  'A30URLCYHH9B8K',
#  'AS7SMJ3H6RHJ9',
#  'A2L18Q7871EONK',
#  'A3LNJ12VR8U4HJ',
#  'A151XA53WYXVD7',
#  'AKU2ZIEPST9Z9',
#  'A2QC0G0AG2YKVO',
#  'A20YC1JBE6C4PQ',
#  'A31AXVT3JPBHIH',
#  'ACFPXI6LMHSZU',
#  'AWRY5SC68T0DC',
#  'A31IJKXHV4ARTZ',
#  'A3SKEW89V5S0DI',
#  'A2M183CETUMR96',
#  'A1NFRIHID90D7C',
#  'A3URPJYLG67HCR',
#  'ANYOKF2ZV1IVA',
#  'A2PUL3ZDXOW0VZ',
#  'AXXMP64R9ZMRF',
#  'A8HSR43LHHFWT',
#  'A1122EUMFXHF38',
#  'A2W3GBKJYNLW7O',
#  'A3BQYS7OELRU7T',
#  'A36MLR2TDLF0TF',
#  'A2MJK9S19791KM',
#  'A20YC1JBE6C4PQ',
#  'A13H9NI9SOJ868',
#  'A198IS4YAP88O1',
#  'A31SZFE8M7YK0S',
#  'AGLBK0AXSIVOA',
#  'A1W7T8V97ZPUH0',
#  'A40UXIF3STW15',
#  'A12GXK6SUCASW0',
#  'ARUXG5FD1Q76F',
#  'ATDOFOKFEG3CI',
#  'A80WPJSYIU9LT',
#  'AV8T375ESPPPS',
#  'A3U27ZHUGOPIAN',
#  'A2XKYFL9JP11RM',
#  'A2H8HVANGF4A58',
#  'A2YHOJLEZR8663',
#  'A1MRAER66G6Y5S',
#  'A3K3X760JHG1T2',
#  'A24APGD3ZKM9UP',
#  'AK2PMO5I7OCEK',
#  'A2JL7FGOIPBZQN',
#  'A2VTSIPX9JWZ5W',
#  'A3IDTSOSHDX6JK',
#  'A2ZDEERVRN5AMC',
#  'AZCGSVDT79E6X',
#  'A3OZ8KF0HWSVWK',
#  'A19ID9IS6LTJEQ',
#  'A1SCF3L6LTFQHF',
#  'A22Y2MFWJG8MXV',
#  'A6OF4Z1C2KZ3L',
#  'A1QYBBI0XHD0PZ',
#  'AVKE1NOI9TX8Z',
#  'A43T3NUEIVVVO',
#  'A3EPFODD53XUT7',
#  'A3VOGZQVZ39K7H',
#  'A3BH6KFP6WG3D6',
#  'AFFXVHHBUWW4D',
#  'A62CCYZFP6TRD',
#  'A2I13H97TTVMRG',
#  'APT42OCCATUAI',
#  'A30C7RIGMJ7QPD',
#  'A2UWSCCI7BJRDK',
#  'A1QFICAD5GZJ5U',
#  'A1F1BIPJR11LSR',
#  'A3MYPYBVHX7FQ2',
#  'A25S9Y5DZ9OR16',
#  'A1KMCD8IBHFO6Y',
#  'AIFG3RMDII8UF',
#  'A3NA1QLD3G3195',
#  'A1GRIH7E84XB65',
#  'A1KJZ9QF86TSA7',
#  'AZG7LNQUXYW8V',
#  'A2LZ2T3TBRUJB1',
#  'A1FYXDL61S1NVM',
#  'A2VO0CD0Z21DE4',
#  'A35576TFDI99QF',
#  'AIBHSWRLG02R2',
#  'A3BHCB6JP16D72',
#  'AL1GOCVKQNC9G',
#  'A165L5XWZ92MD5',
#  'A1OJKLCV9DCXFM',
#  'A11QHIG14ITTSN',
#  'A1B69BRKVU9VMB',
#  'A1B5BJ4LAEGC65',
#  'AB8CA0YM87V75',
#  'A1MSLXH2B3V9FX',
#  'A3UE8ANAIM7F15',
#  'AZ5ZYUCAQ0XDL',
#  'A1T9LDO7ERQOX4',
#  'A1VHK9OFD7H8ZH',
#  'A1J2ZU4AH7V6N6',
#  'A2IGW34Y713OZ5',
#  'ADA4EGNNPKVSX',
#  'A2KHR0GTA0DBWI',
#  'A3AY97QC71IJ9C',
#  'A3ELH8DGVLE6TL',
#  'A87D3K9YVKTQ7',
#  'A2XMRJKCNKLL4E',
#  'ADMUMZBDCEENR',
#  'A2NAKIXS3DVGAA',
#  'A2IK3H6MQ1QV6E',
#  'A3L4JI1S352HB8',
#  'A22V2N2DVR3UHD',
#  'A2BUHMLNE3LUU0',
#  'A2OT8DKBKWRWUW',
#  'AS79UKP2Q7NWJ',
#  'A3G3TIX6FEMN8R',
#  'A1RTT6POOH0A98',
#  'A3MMTARX191R7Y',
#  'AS6722MRUN7AH',
#  ...]

# %% [markdown]
# ## Get all Worker IDs from Data Files

# %%
datapath = '/Users/prachimahableshwarkar/Documents/GW/FacialAge/FacialAge_MTurk/BNav_EC2/DepthDuration/v2_depth_duration_MTurk/data'

worker_ids_from_data = []

for file in os.listdir(datapath):
    if 'csv' in file:
        path = datapath + "/" + file
        df = pd.read_csv(path, index_col=None, header=0)
        worker_ids_from_data.append(df.workerId.unique()[0])

worker_ids_from_data
# Out:
# ['A2JDYN6QM8M5UN',
#  'A2YP60DM1HYTH8',
#  'A3RE6BNYBWY42N',
#  'A34BAS2ZIJU5HF',
#  'AX8D3L76H0JR7',
#  'A2SN83HIW24DO2',
#  'ADS6ONEBLIK43',
#  'A1SEI7LVSP35BI',
#  'A1ZHKHFLN8A1XX',
#  'A2OOS7IXSKJFFI',
#  'A1NOUBYTTZNNAZ',
#  'A2NAKIXS3DVGAA',
#  'AE68XSMXAYPWQ',
#  'A1439J8JQICLBM',
#  'ALUP4ZKEXJFYL',
#  'A8C3WNWRBWUXO',
#  'A1JXSNKXAXT9OU',
#  'A2IQW7R7L2RZAW',
#  'A2KTCMHEPI895V',
#  'A3UBS6ZMNOF8O9',
#  'A17WB66BXX4R0J',
#  'A1HWX2INOUOPS9',
#  'A2XMRJKCNKLL4E',
#  'A9Z4JCJJ9X7NK',
#  'A1QT3YA7G8MO63',
#  'AAS6JE0EH82SO',
#  'AUZNL6ARA1UEC',
#  'A168NQV5RKT0GV',
#  'A26M997VYVK0E6',
#  'A2E5PV1BHNG67N',
#  'A1V0QQXL4GNB39',
#  'A3VV90KUTGBIN1',
#  'A1T9LDO7ERQOX4',
#  'A3MMTARX191R7Y',
#  'A3KVTIUSN94511',
#  'A1SHLWKA0UH1IS',
#  'A3HFB277V5OXY0',
#  'A1DKVUTOBPQH11',
#  'A367HZKP3V2WR',
#  'AICBYPYVA7NJ5',
#  'A7QBBXOG4ERRC',
#  'A34AZLYRHH6JJA',
#  'A3UZYBO3EGBDWR',
#  'AU849EHZNGV2Z',
#  'A1YFL5HXPZ7MVV',
#  'A3LO255HM94WIU',
#  'A20X6V1AAXZGNZ',
#  'A1AMGHYG5PT0L2',
#  'A3LXARU55PR281',
#  'APPR35OCKA8MC',
#  'A2XHD64QUKA5Z6',
#  'AQP4PHYDXRBPI',
#  'A3IQZGY36P090H',
#  'A3AT790ZBYOSQY',
#  'A12L0CZ2CLNSMY',
#  'A39B6A084FBJM7',
#  'A3ATU3VULAB7K2',
#  'A3UE8ANAIM7F15',
#  'A2INXY39KBM92F',
#  'A3EVLXA6P3XRBU',
#  'A22GYYJXTS5KBH',
#  'A159OU5KA18IVH',
#  'A1FHC4Z6QXDQSS',
#  'A1561P9VVA3C1C',
#  'A3EPGICC2GJ4E1',
#  'AUBKB2XCGMMGQ',
#  'AOHS348RVOF6D',
#  'AU566WRASK7Z0',
#  'A3HQTF6HZUPMT2',
#  'A2L18Q7871EONK',
#  'A4ANRSA55IW5Q',
#  'AXFCUZ1WQC2WY',
#  'AG1ZB9IJR4KD4',
#  'A2CWJRAEFZ44HU',
#  'A24APGD3ZKM9UP',
#  'AVN33U74UUIT0',
#  'AG2YM9OWQP690',
#  'A11LNK1U3DT08V',
#  'A4JW28RGI8JV6',
#  'A1J2ZU4AH7V6N6',
#  'A1OOCYEFLAJD98',
#  'AJPB9XHN9HI8I',
#  'A31AXVT3JPBHIH',
#  'A2CNWM7VG2VGTU',
#  'A27HVVLSZZ13XK',
#  'A2GJB2BS2M51JP',
#  'A37R0JYAB3QEX9',
#  'ASC9DUCC64M3P',
#  'AAQREZOK13OV7',
#  'A6KOTWP7N7RLU',
#  'A319K0FNHMV2PA',
#  'A16N2JY89NKZN0',
#  'A2ICS8FOBVLLRP',
#  'A1TR2AOKWGQ78A',
#  'A3JGB3OMTOWR6I',
#  'A2KHR0GTA0DBWI',
#  'A314KKX6ONDO9O',
#  'A2K0L9M1ZZO5C9',
#  'A2R99OKTW7QVER',
#  'AGB6853RIDWJ8',
#  'A1QMJNJ5FGC09',
#  'A3PNXQ5459AZI1',
#  'A3FR700NRB419O',
#  'A26UWOGD1C89EO',
#  'A3G3TIX6FEMN8R',
#  'A2QC0G0AG2YKVO',
#  'A53MOLGRRDHA4',
#  'A2ZGNQB9CFAODO',
#  'A2I43BDUPAM00C',
#  'A3MWLHSW9B9RHU',
#  'AHZCC2V399WUN',
#  'A5V1DUOOKE1O7',
#  'AQ72I9YDIQK2K',
#  'A2H8PEGI28NKZD',
#  'A3PBA2ZHVZFGA3',
#  'A3EPFODD53XUT7',
#  'A2QSDRN8758Z1C',
#  'A2VTSIPX9JWZ5W',
#  'AG053ALQ5ZNCU',
#  'AOUMBJ947AOIH',
#  'A2I2VRN2PLOU7T',
#  'A28RL79ONUXTET',
#  'AJ9IY4IHOGB8',
#  'A1FYXDL61S1NVM',
#  'A150XGQ7KWLBWN',
#  'A1XCIN7E0QP1T8',
#  'A1F1TBDHPYAAXT',
#  'A3R365XR78WL9P',
#  'A3QK8YZIOP3LFB',
#  'A1WSW7HWIF100A',
#  'A3LMWQON9V2647',
#  'A3U2UNSYDPS933',
#  'A2POZSQDZE5C10',
#  'A2AZYU1CT24O0K',
#  'A1KJZ9QF86TSA7',
#  'A1Z1O6MMOB3UWW',
#  'AIA7RZSAONU5M',
#  'A2792CL1I7J298',
#  'A3CZCT3O24OHLM',
#  'APVZGZM1RA3AZ',
#  'A28QZ8YDI84V0R',
#  'AT7ZGRWE6IORC',
#  'ALVDC8JPRXPF9',
#  'A1KMCD8IBHFO6Y',
#  'A20JRQKVMEPHN3',
#  'ADL9KYXZGHUFO',
#  'AKAM01E1R4KAF',
#  'A3UA50A6GKNAMR',
#  'A122R62XGKRFDF',
#  'A1CKCZT9MAJ223',
#  'A2LQO0696YYC1Q',
#  'A19X8IA9EKC3XH',
#  'A1AOESAIFG8K9Y',
#  'ARUXG5FD1Q76F',
#  'A3KPBZ6F79334Y',
#  'A3ELH8DGVLE6TL',
#  'A3U8LNGMQCTDWM',
#  'AN1KXPXUDQFCQ',
#  'A22HIX1M4QXZBB',
#  'A150QX2OXHGK8P',
#  'A1IAMR0PW3L68Z',
#  'ACVWP0MRAU69A',
#  'A2VR9O234UCT9T',
#  'A2U5OFMW8H30PC',
#  'A15PS12R80CWTU',
#  'ASNNAP90D5R1Z',
#  'A45QRE7ZGA20L',
#  'AXOJYPR75TD9X',
#  'A1OJKLCV9DCXFM',
#  'A002160837SWJFPIAI7L7',
#  'A2POU9TTW177VH',
#  'A2QHI85LQPJZYP',
#  'AMJ5KVUCSZGGB',
#  'AQPFTUIJ0PW2N',
#  'A166U1L1KVMPCL',
#  'ADV2MIPVVJBYT',
#  'A3KQ0JO0Z1JCKW',
#  'A2866TYG0D96LM',
#  'A1QUBLZCONL4QD',
#  'AL42QQ0WUTNJY',
#  'A1778IAJQM9EFI',
#  'AH0NG7PISCRNQ',
#  'A3L5PJVWSIAAPB',
#  'AERUGBNS48Z4N',
#  'A2TSPXWH2Q6XX7',
#  'A3C8E7YVLNEQKA',
#  'A36O3E1S5G5PAF',
#  'A1FMVUYV72MUO3',
#  'ATP0UFAVIANFL',
#  'A26F7OWQB4H0CH',
#  'A2ATPVV665TR66',
#  'A1B8QUOSZEH4S1',
#  'A151XA53WYXVD7',
#  'A3D1F7PGBYEA5F',
#  'AFK9ALQK5GPNG',
#  'A1VRG5HKZC0H0C',
#  'A304UJAE051J89',
#  'A87PV9R9JDDYK',
#  'AN9VXAIAT6DWF',
#  'A25V9A343COS6F',
#  'AY1AFPZSEV5E2',
#  'A2FAA1LR6UERGL',
#  'A3MNL6RIME0845',
#  'AS79UKP2Q7NWJ',
#  'AURYD2FH3FUOQ',
#  'A10V73ANM5HV2A',
#  'A1BG1RLKK0V30S',
#  'A3A5IVJ55VFNIG',
#  'A2Z6NL0CTXY0ZB',
#  'AEE63S661IS42',
#  'AR2BL2Q5E6VG2',
#  'AYFNEVUBL6C3U',
#  'A2615YW1YERQBO',
#  'AH0HAT2K4YNWA',
#  'A1A716FZ4WDCCP',
#  'AS787OL64GYWX',
#  'A1KWIJXTC47YWE',
#  'A4T4577P6JL6R',
#  'AOQP9IL4MK3ZQ',
#  'A2I1WSRFJAPQAT',
#  'A2R6KLBXVM5ANW',
#  'A217DANTQBBTW9',
#  'A3L4JI1S352HB8',
#  'A2OT9ZJC4MQBS8',
#  'A1QC1K71RGKZBI',
#  'A1CI6CBNEE7P83',
#  'AD1ILDUXZHASF',
#  'A3LNJ12VR8U4HJ',
#  'A3UKRC3LBM1LEW',
#  'A2DBHKZHJL03AJ',
#  'A2P8V5SKYLL5I4',
#  'A1B81RS0ELC70N',
#  'A20YC1JBE6C4PQ',
#  'ASVRLMDNQBUD9',
#  'AIH1A74CGJNB3',
#  'A2D84R95NDZ2NM',
#  'A345ZKNQSVPJ6G',
#  'A3IVMXS41NL0IX',
#  'AHFD9YY3HJG3B',
#  'A14HW0XMI4R2ON',
#  'A3AY0315YWWNXY',
#  'A28AXX4NCWPH1F',
#  'A6Y7SZU9L301W',
#  'A1B973PG17H746',
#  'APRZ7BR8C0ZMQ',
#  'A3HQEQ3BYIWR74',
#  'A2VO8C41JJIQY9',
#  'A2Z46Q1JXM6LEP',
#  'AEDTHPXU0NCS5',
#  'A1IBY7KXFHJ2U2',
#  'A7N7RA5KJRS57',
#  'A2QRJKXTK4JDD8',
#  'A1Y3JL53XAO7QV',
#  'A22DVMN2Y3XHWA',
#  'AD6DHC6L39T93',
#  'A16QKOP6SK781C',
#  'A1122EUMFXHF38',
#  'A1RC4Y575PV6EG',
#  'AJT7C07A187KA',
#  'A2A6FH0F7LD9ND',
#  'A2VXT33Y2TQPOQ',
#  'AS7SMJ3H6RHJ9',
#  'AUZP4FPD6UTNU',
#  'AEOAO9KFNSOY2',
#  'A9MJVJAMLCDMV',
#  'A23GMTE06W7ASR',
#  'A2R28I9SM3G0YL',
#  'A1FWHWZONTCAEN',
#  'ANKDLLQHHM2OH',
#  'AREQ43Q0T8ENT',
#  'A1BNTJB3GL8PQL',
#  'A2LZ2T3TBRUJB1',
#  'A3O8GRC06KG44S',
#  'AMHUDJ44HF1ZH',
#  'A2XZS401Q3PCH',
#  'A11MVD34RTPNBN',
#  'A3SETW6ELRDABV',
#  'A1QT3YA7G8MO63',
#  'A2U556B3L5HSRO',
#  'A1W9J3UXKDM3DN',
#  'A1DZMZTXWOM9MR',
#  'A2JL7FGOIPBZQN',
#  'AZ5KAKZR0CVR',
#  'A3BHCB6JP16D72',
#  'A2VM35YB03X6U',
#  'A3TI4G63J6VCKV',
#  'A2NQR8NLH5P3IH',
#  'A2VSU26KNST3VK',
#  'A2PF6UAA5SUVD0',
#  'A22XQLIO9XK0LX',
#  'AIBHSWRLG02R2',
#  'A26WG74M652I3P',
#  'A2HY3P2X27JDPJ',
#  'AIFG3RMDII8UF',
#  'A1F9Y1M4EA0JWE',
#  'A1T72Z8APOX4ZE',
#  'A2B7SPYBPF7H8I',
#  'A2GV9WSNSPX53',
#  'A3EHSE72YO5P4U',
#  'A2PSR3CMNR1R9X',
#  'A2MJQG58XN41OW',
#  'A39SK1E6IMQBD5',
#  'A6WYBPPG8Y2Q4',
#  'A1KMCD8IBHFO6Y',
#  'A2HP2YBJF23XCY',
#  'A2JM5TNLFXS4ZV',
#  'A43T3NUEIVVVO',
#  'A3OZHKAI24FEIE',
#  'A3B8E6GBXK1PTC',
#  'A1L2F0RO9LFKF0',
#  'A3FSDH6HUZPNQ8',
#  'A2M183CETUMR96',
#  'ARWF605I7RWM7',
#  'A2OW2CIT4H7364',
#  'A2H1QUGX0SOUMH',
#  'A28DX4SKQRH8UY',
#  'A34IPEKX5WXJIN',
#  'AKWDZRXE69GDZ',
#  'AEJU0MCYOQC77',
#  'A1DBR498DU038O',
#  'A3ET5RWBP1Y4AS',
#  'A3LGUYS3JU2C1T',
#  'A2U8QOJRKUCTWG',
#  'A1DS5O8MSI3ZH0',
#  'A2K08PIXXDQLU0',
#  'A2IGW34Y713OZ5',
#  'A3I40B0FATY8VH',
#  'A2OT8DKBKWRWUW',
#  'A222GZB608T1B8',
#  'A2EAJ7834XI2IT',
#  'A392WSCAS81ZMT',
#  'A1KGUJMWDCPSYG',
#  'A1Q0495NMQY3V0',
#  'A12T55B08JJYYV',
#  'A16335MOISDG1F',
#  'AZ8AOL78L8C84',
#  'A5P12YJP805RG',
#  'A3K1X90ANB3LLA',
#  'A1PHDT66U6IK4Q',
#  'A1UTNAK70QH9JS',
#  'A10JXOU89D5RXR',
#  'APDGHS08BD9J8',
#  'A3R6Q6GOWTX7TH',
#  'A2PI8JNEQCROH0',
#  'A34K78HC5PDZU',
#  'A8CD2WIF5DT1J',
#  'A12GXK6SUCASW0',
#  'A1RQ9S6WXZBNRT',
#  'AT80V0Q1U2LCI',
#  'A20VDJXO3FJUVT',
#  'A3LVI3GY17D0MG',
#  'A2OVWCQ4B9AHFY',
#  'A2WXZL2CB67AJH',
#  'A1QUQ0TV9KVD4C',
#  'A1RTT6POOH0A98',
#  'A29EHRCM8MT04O',
#  'AE33JO53WTHZQ',
#  'A25FH7PXC446RG',
#  'A3V7HHS20YFRT4',
#  'A21ZT1N7WFR1KH',
#  'A11BAIN13IGWCW',
#  'AYYSG3O9FNU15',
#  'A2IV3SSVTU90BN',
#  'A3BZH91MITQA5X',
#  'A1VSEDABJFNUVQ',
#  'A3QS7DY7B9K2B3',
#  'A3PJWT1Z1FHYCJ',
#  'A3QNCW3LR2AVOV',
#  'AMOBC1D09Q381',
#  'A3AV3TDN90GETD',
#  'A2VFEDAK5C1E1O',
#  'A3QDDYBRNDFRXX',
#  'A3AS8T11F9Y610',
#  'A40UXIF3STW15',
#  'AP9WIQ4P78XLH',
#  'AEMOH1QUKXF30',
#  'A19TD2J8506A4Y',
#  'A1TLNLB9D87H6',
#  'A3FNC8ELMK8YJA',
#  'A1C0R9LZ0K51N0',
#  'A1YFFKN3QVV54D',
#  'A349GKM2SNSQ6S',
#  'A2325LZL2NO9BI',
#  'A2B9FATIOQ6WIO',
#  'AL9SYQEUTNJXT',
#  'AMQ1TPD2W5PIN',
#  'A38HSRH587F94K',
#  'A2NQRZ6SUEVU6F',
#  'A3COKL7K5AYZGG',
#  'A4U30E8MK1F4J',
#  'A24GX1OZE6AY04',
#  'A3URPJYLG67HCR',
#  'A2Q03D83LCCJNN',
#  'A384KX8MUIJSTJ',
#  'AZBM9ZNBJC3VM',
#  'A3OGL1QQ4S6FH8',
#  'A34SHVXJXDB8SQ',
#  'A2ILUP6FN8HKKC',
#  'A2OETAZM3SMWDG',
#  'A2I6HVUDBTGD1',
#  'ALY0MSI8P4OY2',
#  'A130X6CF795CQ5',
#  'AZ7JRE9HNBKLJ',
#  'A13WTEQ06V3B6D',
#  'A3QSSPYCKPOVFA',
#  'AM64GU7LGD95S',
#  'A1UJRE4S5E8RM8',
#  'A2ZDEERVRN5AMC',
#  'A3K3X760JHG1T2',
#  'A2G4E4KLMHG03S',
#  'A6G80VHTBZKXM',
#  'A1AD2BDQYTTJIL',
#  'AG1ZB9IJR4KD4',
#  'ALT6TQMZJKSFQ',
#  'A3AGXTSAHA2AFL',
#  'AN7Z42U38BCQT',
#  'A1BT6QJIRC46BB',
#  'A26LOVXF4QZZCO',
#  'A3QDDYBRNDFRXX',
#  'A3KKWOUZ07G9WP',
#  'A50UY1556VDIA',
#  'A3VXBCD5SCIMLP',
#  'APFIMQRTK6ZKF',
#  'A1C5SQZ045W0L5',
#  'A16N2JY89NKZN0',
#  'A1CA6ZXKK09ZRI',
#  'A3P41MYFVUJVDG',
#  'A1QUN55HKPGNVT',
#  'A11YY2CO8ZR6RJ',
#  'A28LVKN22K756',
#  'A2N4OJ2EQ6JNH2',
#  'A37GPEF28AUCRO',
#  'A3QPVH0DRW0ZQV',
#  'APVLR2LNLMHII',
#  'A3UQ5DF8VVD975',
#  'A1PX4CR15QC57J',
#  'A2C9OFEV72G568',
#  'A3NTGJUQJIG4N5',
#  'A2BVVFXMQU8AC7',
#  'A3E53WAR22AMQE',
#  'A3I9743KVD971V',
#  'AP4B1GJIT3HYF',
#  'A2X2DE9X949ECT',
#  'ACFPXI6LMHSZU',
#  'A16LFEFTDWJ5M4',
#  'A87D3K9YVKTQ7',
#  'A2GOYSTIL3LOV1',
#  'AT1JIRG16U42',
#  'A12MUH7GQDNCLP',
#  'AGGSZSOV7LQP7',
#  'A3I65SDKOXEG8Q',
#  'A1YHS6MUJAY11X',
#  'ARRDHASPCGP4L',
#  'A30CKD84V82EH2',
#  'A2UJ9GDNVPX99C',
#  'AF3YJOJWCSJH2',
#  'AVKE1NOI9TX8Z',
#  'A1XIXGOB9KUMPJ',
#  'A2BABL5AHUOYC7',
#  'A3BH6KFP6WG3D6',
#  'A2J1ANUL0BYKUK',
#  'A1ST0FIJXMNPPW',
#  'A1UZXOMO6BS6I2',
#  'A2EHH2ZFIRF1BF',
#  'A3K36KLBGNV2HX',
#  'A20YC1JBE6C4PQ',
#  'A3H1A5PGLBBWR0',
#  'A2U5OFMW8H30PC',
#  'AKU2ZIEPST9Z9',
#  'A3BQYS7OELRU7T',
#  'AGANKP4PUZ4NC',
#  'A17SPG1FUPJN8E',
#  'AKJN72HW14WTR',
#  'A3RKPAQ8P9F3HW',
#  'AHWX1CVVMZZTI',
#  'A2JGXBZNNX65ZS',
#  'A36SM7QM8OK3H6',
#  'A17IPELR5NC2LZ',
#  'A2GG7HIO2OIXUR',
#  'A25VPV47HCP6DX',
#  'ANBWJZYU2A68T',
#  'A3TUJBPLJGTI5',
#  'A34YDGVZKRJ0LZ',
#  'A2TYVYRGXYSXJA',
#  'A2M5S1RXUCVE7L',
#  'A1Q17AURTUSKIT',
#  'A14NGT8WVKVENT',
#  'A3B2YRSMSC2J3T',
#  'AY4E884XE9P1H',
#  'A1S5SPI4NQPGSI',
#  'A2KW87ZD2ELYNG',
#  'A16N2JY89NKZN0',
#  'AHW6DCVVMZZTI',
#  'A11SKEBNP69NEH',
#  'A281ASP4WWAN3E',
#  'A174SEDH0AZG4H',
#  'AROBXX0BPY0HZ',
#  'A11FRLH5KWRLBV',
#  'A30RZC1AY4SCU',
#  'ALTJ8ONS93XVL',
#  'A256QIR5XUIP8K',
#  'A165L5XWZ92MD5',
#  'ANEVIDK1EVP9V',
#  'A161VPQSXLLV8U',
#  'ADQB1CIQFO2V9',
#  'ATPW1MWLW7RBL',
#  'A3H59EYYMBXQL',
#  'A6F5YYYKILYBO',
#  'A27QXQ22F9ODSP',
#  'A2S64AUN7JI7ZS',
#  'ASZFR1M9LX14R',
#  'A2V1TRRRG3IH54',
#  'ANZ4YBNNFVANB',
#  'A8GLGHP1KIF9X',
#  'AL1GOCVKQNC9G',
#  'AX030GX2193N7',
#  'A3J4YYW1M62T39',
#  'A24LLJNSDBFVET',
#  'A3JDWMS5QJHREI',
#  'AAD89SBCG803P',
#  'AFFXVHHBUWW4D',
#  'ACF6USGTSNNXC',
#  'A1C2TCLM2AT8LR',
#  'A2GDP2A4JZ9W1G',
#  'A3VLYXEJ44AA4K',
#  'A2GIKDMPOC253Z',
#  'A3PYD7EU2WFST6',
#  'AJI75GZM88W8X',
#  'A9LSEP71DNP4O',
#  'A3QUC7F5K52EF6',
#  'A175U4Y051W1UB',
#  'AY7LRW5Q88WL7',
#  'A2ASWA01M4JZOK',
#  'A1PTX4IB9R34LI',
#  'A3MYPYBVHX7FQ2',
#  'A1MSLXH2B3V9FX',
#  'A38OPVI04AH4JG',
#  'A83IAKZR4HBSJ',
#  'A14OQ52EFQAN2W',
#  'A1MRAER66G6Y5S',
#  'A38KCCSGBFR26L',
#  'A2Y0D217B4JP6I',
#  'A2QXG8VJRBZ2Z3',
#  'A3VOGZQVZ39K7H',
#  'A1W7T8V97ZPUH0',
#  'A1ZFXY30B31DSJ',
#  'AV7UX8QQXABSK',
#  'A2NLR3S7WBULAK',
#  'ACUK17I51KVXF',
#  'AJVLNHSG2YU23',
#  'A1TVTGQOTEMGN3',
#  'A3RCX3IQ8L6HHW',
#  'AUADIKCBMKJY9',
#  'AJZ6XER6DE8EE',
#  'AFYIL9DFX6BFO',
#  'AE68XSMXAYPWQ',
#  'A37GPEF28AUCRO',
#  'A2DSTHSND3PKN4',
#  'A146QN6EU8LAEI',
#  'A2T675UCHNTSSW',
#  'A22CWNSGO4UVGO',
#  'A290HFZXIMBJ6W',
#  'A2F1AA15HG0FRU',
#  'A1IKAI6PWMJIPN',
#  'A3OFMEOMELZBBC',
#  'A19DHVVUJJCUX4',
#  'AGLBK0AXSIVOA',
#  'AIHIOO54ER5U4',
#  'AHW8VQZD6IUJE',
#  'A1P7VQXX8GBM18',
#  'A2I13H97TTVMRG',
#  'A19W20MG7V94UC',
#  'A3UUK65H63DHFX',
#  'A2ZDWWWAZUYHFT',
#  'AN0LMTB0P5DYZ',
#  'A1FVZ9R0G7ULVS',
#  'A35UWTV3KR42YN',
#  'A16VHI5W655JWW',
#  'A3RHJEMZ4EGY2U',
#  'A1338G6KF4JUFI',
#  'A1IMBZEOTAZH36',
#  'A1I91OUDL75HZR',
#  'AND0QB9HN2WO4',
#  'A3NXXMACEGVNIO',
#  'A3SBR6IJQRCSPV',
#  'AXTZU0PO55S3S',
#  'A1NZFJHVJ9CNTO',
#  'A1AF2XEWM0KZ87',
#  'A2FP41BSPG0Y4A',
#  'A30GCTXJ17JC3I',
#  'A3E50NZCJNLDG1',
#  'A3RC6TFQ9QHMXI',
#  'A2W5MSZP0O4Y2P',
#  'AE9KNJZWDCDSE',
#  'A6WXIKRYMXNIN',
#  'A2PPTQXFVA9H38',
#  'A26GTSC1T6RFFK',
#  'A3IMM3YOEK9D3H',
#  'A1Q0495NMQY3V0',
#  'A3JJXDML3XNSQP',
#  'A3NRIEMOJVVX4A',
#  'ABBP9JASL9AGK',
#  'A3NA1QLD3G3195',
#  'AO3PSTU0XHXJ',
#  'A1F1BIPJR11LSR',
#  'ADAPUMS9XU8FU',
#  'A1T10I5ZOOWH8R',
#  'A1NFRIHID90D7C',
#  'A25CZJEFKXF4UV',
#  'A2OG7XGWOX5ZEF',
#  'ACUPJ84DZ037N',
#  'A12KEVAHN5P4WU',
#  'A23AIRWHYDPJON',
#  'A2LHZMUV3Q81X0',
#  'ABB8ZELZME1KZ',
#  'AZPXDIOTEH989',
#  'A3KF6O09H04SP7',
#  'AHJC56KSSXTIX',
#  'A3V24QUVVYM6C2',
#  'A2IK3H6MQ1QV6E',
#  'A4LR95YJIE5IK',
#  'A1HTR3THFK84RM',
#  'A1WM3INNDW2776',
#  'A3QXY8LOG924BF',
#  'A7GT7BIC7ERWE',
#  'A2HJ7MJSOKRC6K',
#  'A2JMUV03Y7WLMK',
#  'A159XL8NQQPGVK',
#  'A2E8PL8ZWIZVJ0',
#  'AYVKWUHE8VHQ1',
#  'AFB3HRG78PD9H',
#  'A2FOUSWQDYHIE0',
#  'AM8ZEA3RDPGSA',
#  'A3VHDQR8A9JJ4F',
#  'A2DQ0OE2TBY9E0',
#  'ABLZE51NE44U8',
#  'AR3MFFPQ39IXF',
#  'A3OZ8KF0HWSVWK',
#  'A16N2JY89NKZN0',
#  'A2UYZFH5VT5R3H',
#  'A3BN69Q9D7RQGR',
#  'A2PP6W7AW3NMFY',
#  'A22DF0EWILGRLV',
#  'A1MGSRTTYYD5AJ',
#  'A2GM1ZIBRBHBK7',
#  'A10A7EZUXBD0II',
#  'A18T7E73TNGOKP',
#  'A2Z58PTI5RFDKK',
#  'A2MCG5W6LHSRG9',
#  'A32S8F6DJQWNEW',
#  'A36MLR2TDLF0TF',
#  'A1QIJ94TJ6FZ2W',
#  'AB1UHU4WQ9HFT',
#  'A2ZT2Z0LQ05EGZ',
#  'A3L0DCUXI7X3A9',
#  'AJVIG3GTWRQ2E',
#  'AKPQABK355ZRA',
#  'A2Z2WC3DJQ38RH',
#  'AKWAO862UBFU1',
#  'A3UM7UQT975UZJ',
#  'AUR7WEK868Y2B',
#  'AV8T375ESPPPS',
#  'A2HCPC2V4OYFDV',
#  'A2BIB03B8PIC0',
#  'A1N8TKTLXV92QR',
#  'A24LUXW1DB1QI5',
#  'A1P6OXEJ86HQRM',
#  'ATZALLLXA7YUH',
#  'A133K3I5MRCJLN',
#  'A1Q0495NMQY3V0',
#  'A3OZ3ZUUGTX29P',
#  'A1WCNRUU7H9UIF',
#  'A3CWEIEY3TGJFX',
#  'AQKRSW854ATWI',
#  'A1LJDITM8FGL5U',
#  'A2W3KKNN3CAY66',
#  'A38FPN0648O3XJ',
#  'A3253Y8PCTZD2T',
#  'A3MJQ51KN9CMQ4',
#  'A1I7H6RDJS4EKN',
#  'AJ7JFYKBG85ZV',
#  'A3QAL3X23LHJRV',
#  'AV3NMCN13C6RM',
#  'A22Y2MFWJG8MXV',
#  'A2TXZVXQU5FQZ9',
#  'A2ZWLEDD3WZQH5',
#  'A1QRIZY9WJW3R1',
#  'AS6722MRUN7AH',
#  'A2I5G9ES6TS73M',
#  'A3QUC7F5K52EF6',
#  'A2J4Y484J54JUA',
#  'A1ONILGBGJ8Y5K',
#  'APF8F1M25DW76',
#  'A2AQHNDSH2TG3C',
#  'A11KIP43XQNINW',
#  'A3LB1WIJ645EL8',
#  'A606GB0TAI3WV',
#  'A8HSR43LHHFWT',
#  'A2IHXTGWRC8SVQ',
#  'AH4LSAYFLV68I',
#  'A3KVKK1XLBTSN3',
#  'A222EOOD8O2IC9',
#  'ANPCXN619ACW9',
#  'A2TUYGXQ15U6GO',
#  'A2TTFF5SJ4KNRM',
#  'A21AOJ6CWLKOME',
#  'ACSS93E03ZUGX',
#  'A3YG4NM3FQQQY',
#  'AS4NIEQJWCG3M',
#  'ADP3FQJ88ATS0',
#  'A51TGVVYJF7T0',
#  'ASTDVO244GVE4',
#  'AXCDKBG1R43GE',
#  'AYW62R027PUT1',
#  'A1ILCIHMXPNTMT',
#  'A1QDEYCJK9WLV6',
#  'A209KMZQTLEZZC',
#  'ARR9GKAG3JFE5',
#  'AE68XSMXAYPWQ',
#  'AE68XSMXAYPWQ',
#  'A1DUPOUC9RNU4L',
#  'A30C7RIGMJ7QPD',
#  'A1901T07YJX1OD',
#  'A17KUG7M9BQVPC',
#  'A1BWNJPFNA1U1A',
#  'A2NDII2PZFIF5F',
#  'ANYOKF2ZV1IVA',
#  'A16N2JY89NKZN0',
#  'A3N15463MQO5VF',
#  'A3SKEW89V5S0DI',
#  'A3OUAR84WQO03Y',
#  'A2MSUZAK2Z9U88',
#  'A1MDIJ01QRX4WW',
#  'A1J5OW12TRQSOW',
#  'A1GRPIBHW72HDU',
#  'A2ISLV6X3Q81MS',
#  'A27Y2GMAKJ5OWE',
#  'A39OX2275DREWX',
#  'A2JRMX2O50M439',
#  'AD16ZVR7DUHWB',
#  'AUKELYOG4B7AW',
#  'A158DJDP2AM46C',
#  'A3VWJ8N2PEFJCY',
#  'AM60DFH3IWY61',
#  'A3CVY8G619MGTI',
#  'A1FYZPVWWC808I',
#  'A2SB21YR0U8T89',
#  'A13EXIOBU0UVX4',
#  'A31IJKXHV4ARTZ',
#  'A1PS8FTSVOJ4PB',
#  'A1SCF3L6LTFQHF',
#  'ABIQZEIRUG8QV',
#  'A2UGM73EHLK6XI',
#  'A1CJWQO46J59ZE',
#  'A16N2JY89NKZN0',
#  'A1F0VEHWK3IAF4',
#  'A1FVZ9R0G7ULVS',
#  'AABZGLZ5QWCG0',
#  'A3BMOVHOZDKX8T',
#  'AKP66RIZ3LQVX',
#  'AHZP05WVFXXCG',
#  'A1198W1SPF1R4',
#  'A9T24X9NZQ0XH',
#  'A3UMTOQOGO7TE0',
#  'A1BGJG22X6REWU',
#  'AAAWYYHUPGICY',
#  'A1TW2BZRRS874Z',
#  'A1PNC3NZ8PQJUI',
#  'A2V4L6EO0C9MO9',
#  'A3MZUG72V5PSN6',
#  'A2JSG2JIAQQNGA',
#  'A24LB89P1BPKKF',
#  'A4W9APAHFWVLO',
#  'A13H9NI9SOJ868',
#  'ATDOFOKFEG3CI',
#  'A3GTQ61TA3K2S3',
#  'A196XR61DIW5GU',
#  'AU6XJ4UHHVY3',
#  'AGJC17U0NL98Q',
#  'A1N35VV9QURKHX',
#  'A2XS49LRNX8PD4',
#  'A2OVX9UW5WANQE',
#  'A18N73E0G2H2DT',
#  'A32VLTWRJ1EP5T',
#  'A1ZD9SJXQ9C6EW',
#  'A248QG4DPULP46',
#  'A2CA811M94B7NX',
#  'A3QJ0LIK6SS3PG',
#  'A1K2MYLLWDO4SX',
#  'AXPZAP62ZYWP8',
#  'A3L9EN8YL1HZWF',
#  'AR8WYVS06UUYG',
#  'A1O7AO7GD0SO9W',
#  'A1WMPXACESD2U4',
#  'A1K6ZE1UVDPWH',
#  'A362L2LXXY4KZ6',
#  'AK2PMO5I7OCEK',
#  'A3G5OWGKHW6OL5',
#  'A2G0LXNAKZWXGA',
#  'A33GZS6SU4O20M',
#  'A1U4WS9KJMADV',
#  'A1SGTL6LGLW4DK',
#  'A2J1QH8F9ELL2P',
#  'A3DKSG1VT6L74U',
#  'A3ROYCIEAFHRCV',
#  'AXY0D2AMLKE2A',
#  'AWDU600NXZ26L',
#  'ALU19ABETSAY5',
#  'A2EPNHL2SYUUHY',
#  'A3U27ZHUGOPIAN',
#  'AGP7ZC1UU2AA9',
#  'A2JDUV4XMJSN55',
#  'A34MGGU0MWL82E',
#  'A3AY97QC71IJ9C',
#  'A2VNSNAN1LZBAM',
#  'AKIT35WR8HEQ3',
#  'A1RKGN3VY39TM1',
#  'A1XT18HD14FKF3',
#  'A2L0J2NQ0NDJQK',
#  'A15V9BXNJXZXZX',
#  'A225J5T6WHO2MG',
#  'A1SLKRR55Q38IB',
#  'A70E1IDLQXLCR',
#  'ALDWKDNI1KS69',
#  'A2F02S5813Y88Y',
#  'ACXXK6ZT45LCD',
#  'AQCZJ81IS07OK',
#  'A2NXZIK5NTML18',
#  'A3VG22WR5I4UG2',
#  'A2TZVJFRJ5I61B',
#  'A199NXLVGW1VJF',
#  'AZG7LNQUXYW8V',
#  'A3DTG2QEFWI2II',
#  'A2FQJCE190UHGQ',
#  'A3E2NJU0V1O57Z',
#  'A2EK1HDV4I4GSK',
#  'A2B1YSMEHN1G2K',
#  'A7TI4X4LRGQA0',
#  'A198MSVO1VTAT5',
#  'A3LOBI8KGKM59C',
#  'A1Q6ZK8NKT4I93',
#  'A2IWZJPO67CAJ3',
#  'A3P7AXWF57BHNX',
#  'A1202VV9WS418S',
#  'A1B5BJ4LAEGC65',
#  'A3QXN14FLZW82W',
#  'A20K99JZE0L8HU',
#  'ATNY69UI91LMQ',
#  'A1QWXHF5EY3Q2O',
#  'AXXMP64R9ZMRF',
#  'A2E5CA83JIWPLF',
#  'A8R24ZO89Y9JL',
#  'A2GVKAY7YO312H',
#  'A1W7QIHUF3MK9O',
#  'A3GO1DF6EIHJTL',
#  'A2MJK9S19791KM',
#  'AUG6ZXYNR9TYB',
#  'A204Q4T20BP8V',
#  'A1QW2XUJ7KZCV5',
#  'A1IQMLM2LGOKJ0',
#  'A262M5VGNQWDWN',
#  'A36QBKROJ4J9EJ',
#  'A3G8XCOSTGW1CZ',
#  'A18AFIIAQOVC1B',
#  'A1EYMT1R73LE02',
#  'A31SZFE8M7YK0S',
#  'A3UV55HC87DO9C',
#  'A3P5WIW36V70AI',
#  'A1O57XVTTB1PNZ',
#  'A1BX8H3Z8REARA',
#  'A1YRYQBQGQRY1Q',
#  'A1QYBBI0XHD0PZ',
#  'A175766N4ZEO2R',
#  'A3KQIZEPJJ7HV9',
#  'AWRY5SC68T0DC',
#  'A1AXN8VOE1LBL3',
#  'A3HY9H1ATZW26A',
#  'ADMUMZBDCEENR',
#  'A1RK093GG6Y1C9',
#  'A3N3F3JSOX6R8N',
#  'A1GEO1VUUQQ9K2',
#  'A1MTRZDRKNB9GV',
#  'A1MG8KNVSVZ365',
#  'AMLE1FC3SQVL8',
#  'A489K1IFOM4JW',
#  'A2TTFF5SJ4KNRM',
#  'A2T0P6DJFRIYJV',
#  'AB8CA0YM87V75',
#  'A2HJKL3641S7R',
#  'A2P1RC5XE7YQHJ',
#  'A1J4TXVBRW33KN',
#  'A43Z9G68U5GAF',
#  'AE1YA7Q3UKPRI',
#  'A2YTO4EY3MNYAJ',
#  'A1H198MRIM37T1',
#  'A36FOHCO9QTZ0H',
#  'A1VLH6ZN45VELT',
#  'AOOU57BC3GK9J',
#  'A2I8K0FSEOYDIN',
#  'A3R7L46Y85VBQK',
#  'A2S9A5Z7CNE85H',
#  'A1WT03BP7QHTZZ',
#  'A3A448MW1VKCV',
#  'A1NN61ZAXV9FR0',
#  'A1ROEDVMTO9Y3X',
#  'A3SLT6KVF0NXPH',
#  'A6MWJK1YEY5L2',
#  'A3EW15VNSO5ETM',
#  'AD8TLR54GV71W',
#  'A1EU5WEVXH6AZ0',
#  'A1GKD3NG1NNHRP',
#  'AZ5ZYUCAQ0XDL',
#  'A1OAZCVZRC00F0',
#  'A230VUDYOCRZ4N',
#  'A3AKL0KTXI947R',
#  'A166BS4L4QUBR9',
#  'A38I55GISTO61M',
#  'A12HZGOZQD5YK7',
#  'ANK8K5WTHJ61C',
#  'AOCQ83IC3FRUQ',
#  'A2W6ZXKME2YVEC',
#  'A1ZI4VU6650Q8B',
#  'A2YHOJLEZR8663',
#  'A1VHK9OFD7H8ZH',
#  'A165L5XWZ92MD5',
#  'A2UWSCCI7BJRDK',
#  'A22SMU2MZ4FXYV',
#  'A1GRIH7E84XB65',
#  'A2M3FPQF852HW4',
#  'AEWPAZBYA7XE',
#  'A3JBQDUICDRA14',
#  'A22V2N2DVR3UHD',
#  'A2NZ783AY1LBPW',
#  'AFCMHQWCV6N02',
#  'A1T6QVMIXF74FF',
#  'A1OPD2QAX5XK85',
#  'AGVWCR12FX0GI',
#  'A1YHIQHLLLQIIQ',
#  'A32OTBQ9Y8ZJUP',
#  'A3ROADR7T6811',
#  'A2QATEH8PN2ZM8',
#  'AGILQEFEPEK7N',
#  'A2QCQGZD7T1QNL',
#  'A2XMLU7CW34MWT',
#  'A1I9RLJQ0BYN21',
#  'A1J9N4GV8AD6FH',
#  'A2FFCQ9WU6R764',
#  'A8V0L2YF8U6OX',
#  'A18D69774I4CP8',
#  'A320QA9HJFUOZO',
#  'A2RDRBB3EHQQN8',
#  'A3NRYEZ6FPJ59P',
#  'A1T7N4ZRWIQH71',
#  'A20XDCBFKG4TEE',
#  'A32IA0BBKKXZNK',
#  'A2F06TCLNQ33LI',
#  'A2HMWCWV060NFO',
#  'AFJFYJZ849YOZ',
#  'A2KW26KE43UBRS',
#  'AR5M3HHTQV9QY',
#  'A34WQ0OT0BH5H8',
#  'A2BUHMLNE3LUU0',
#  'A1S56RBP0Q3BT',
#  'A2D1S77G7DNC54',
#  'A2OZGNW6THEMJ',
#  'A1WNDP6AX6HWRT',
#  'A30GJ0HHLO16E8',
#  'A1QFICAD5GZJ5U',
#  'AQAHBOI7F89RS',
#  'A1VVZ9XJIL1C0S',
#  'A4VUQ6627RJX8',
#  'A2R0YYUAWNT7UD',
#  'A31RYDHVOIJ37C',
#  'A3JGVZEXXELM3C',
#  'A2ZDXFFGSPHGBE',
#  'A1IS0218RVG60K',
#  'A1S05Q05GCT274',
#  'A1KVU6F3AVWW3A',
#  'A14WLAP6TCEKO0',
#  'AGKCK081EU63R',
#  'A1Q0WX3HQVQIUD',
#  'COPIEDA19PO2S1CDNJMQ',
#  'A1SSU9086VGUC5',
#  'AQJWO4YPR3LUQ',
#  'ADA4EGNNPKVSX',
#  'A3LVLZS8S41ZD7',
#  'A5EJ10KD1ELO4',
#  'A3C8NUIBNZYMT2',
#  'A3GVUYY3TWRPZT',
#  'A13TDL9QXTVW5U',
#  'A3OU2PDA0ZTT4P',
#  'A2JL1YKDCQ9Y1C',
#  'ABVSR4GA6S3U3',
#  'AD9QQRANGJBO1',
#  'A25R2OI9L2Q1OW',
#  'A2WZQIWNVLHBUO',
#  'A20N1NK5X5S88F',
#  'A14RXHR3LV6HD0',
#  'A2XK59FYAFO9EX',
#  'AIPLQYDLUSJM5',
#  ...]

# %%
set(worker_ids_from_data) == set(all_batch_worker_ids)
# Out:
# False

# %%
# get the worker IDs that are in the data but NOT in the batch data
# these data files should be moved to an archive and NOT analyzed
batchdata_workerIDs = set(all_batch_worker_ids)
missing_wid = [wid for wid in worker_ids_from_data if wid not in batchdata_workerIDs]
missing_wid
# Out:
# ['AHW6DCVVMZZTI', 'A3JBQDUICDRA14', 'COPIEDA19PO2S1CDNJMQ']

# %% [markdown]
# # Participant Exclusion

# %%
def combineCSVs(datafolder):
    """
    Combine all participant data into one pandas df
    OR 
    Create df for single participant file 
    """
        
    #checks if path is a file
    isFile = os.path.isfile(datafolder)

    #checks if path is a directory
    isDirectory = os.path.isdir(datafolder)
    
    if isDirectory == True:
        data = []
        for filename in os.listdir(datafolder):
            if 'csv' in filename:
                path = datafolder + "/" + filename
                df = pd.read_csv(path, index_col=None, header=0)
                data.append(df)

        input_frame = pd.concat(data, axis=0, ignore_index=True)
        
    if isFile == True:
        if 'csv' in datafolder:
            input_frame = pd.read_csv(datafolder, index_col=None, header=0)
    
    print('Number of participants before cleaning: ', len(input_frame.subjID.unique()))
 
    return input_frame

def feet_to_meters(ft):
    """
    Args: ft = float value in feet 
        
    Returns: m = float value converted to meters 
    """
    m = ft * 0.3048
    return m

def getUnitConveredData(datafolder):
    '''
    Convert all responses given in feet to meters 
    '''
    input_data = combineCSVs(datafolder) # combine CSVs from all participants 
    
    for idx, row in input_data.iterrows():
        unit = row['unitSelection']
        # if estimate was made in feet, convert to meters 
        if unit == 'feet':
            estim_ft = row['depth_estimate']
            estim_m = feet_to_meters(estim_ft)
            # update depth estimates in existing dataframe
            input_data.at[idx, 'depth_estimate'] = estim_m
            # update units in existing dataframe
#             input_data.at[idx, 'unitSelection'] = 'meters'
    
    return input_data

def cleanAgeResponses(datafolder):
    '''
    Participants on MTurk must be over 18
    - If participants report they are < 18, exclude from analysis 
    
    NEED TO CHANGE HOW AGE IS COLLECTED
    
    '''
    input_data = getUnitConveredData(datafolder)
    exclude = []
    
    for idx, row in input_data.iterrows():
        age = row['age']
        # if year of birth was given, convert to age
#         if age > 1920:
#             actual_age = 2022-age
#             # update age in existing dataframe
#             input_data.at[idx, 'age'] = actual_age
        # participants must be over 18 so age reports below 18 are junk 
        if age < 18:
            # CHANGE THIS TO WORKER ID LATER 
            exclude.append(row['subjID'])
    print('Number of participants excluded due to age: ', len(exclude))
    return input_data, exclude

# %%
data_path = '/Users/prachimahableshwarkar/Documents/GW/FacialAge/FacialAge_MTurk/BNav_EC2/DepthDuration/v2_depth_duration_MTurk/data'

age_cleaned_data, exclude = cleanAgeResponses(data_path)
# Out:
# Number of participants before cleaning:  1119
# Number of participants excluded due to age:  164

# %%
def catchTrial_cleaning(df, correct_requirement, catch_stimuli, sequence_count, exclude):
    '''
    Participants complete 8 catch trials total to ensure that they are doing the task.
    If less than 6/8 catch trials are correct, the participant is excluded.  
    '''
    
    all_subjIDs = df.subjID.unique()
    remove = []
    subj_sequence = {}
    df2_list = []
    
    for subj in all_subjIDs:
#         print(subj)
        subj_df = df.loc[df['subjID'] == subj]
        cleaned_subj_df = subj_df.copy(deep=True) # prevent setting with copy warning
        subj_sequence[subj] = subj_df.sequenceName.unique()[0]
        
        count_correct = 0
        for idx, row in subj_df.iterrows():
            stim = row['stimulus']
            if type(stim) == str:
                if stim.split('/')[1] in catch_stimuli:
                    ####### VERSION WHERE CATCH TRIALS ARE ATTENTION CHECK: IMAGE HAS NO TARGET
#                     print(row['depth_estimate'])
#                     print(row['stimulus'])
                    if row["depth_estimate"] == 0:
                        count_correct += 1

                    # remove catch trial 
                    cleaned_subj_df.drop([idx], inplace=True)

        if count_correct < correct_requirement:
            remove.append(subj)
        else:
            sequence_count[subj_df.sequenceName.unique()[0]] += 1
        
        df2_list.append(cleaned_subj_df)
    
    df2 = pd.concat(df2_list)
    print("Number of participants that did not pass the catch trial check:", len(remove))
    print("Participants that were removed:",remove)

    for index, row in df2.iterrows():
        if row['subjID'] in remove:
            df2.drop(index, inplace=True)
    
    # add the list of participants to be removed to the existing list of excluded participants
    exclude += remove 
    
    return df2, exclude

# %%
sequences_path = '/Users/prachimahableshwarkar/Documents/GW/FacialAge/FacialAge_MTurk/BNav_EC2/DepthDuration/v2_depth_duration_MTurk/jsons'
sequences_count_dict = {}
for seq in os.listdir(sequences_path):
    if 'json' in seq:
        sequences_count_dict['jsons/'+seq] = 0

# %%
all_catch_stim = ['000375_2014-06-08_11-17-29_260595134347_rgbf000133-resize_2',
                  '000569_2014-06-09_22-51-47_260595134347_rgbf000141-resize_3',
                  '000787_2014-06-08_22-33-53_260595134347_rgbf000175-resize_1',
                  '002072_2014-06-24_21-48-06_260595134347_rgbf000115-resize_0',
                  '001170_2014-06-17_15-43-44_260595134347_rgbf000096-resize_6',
                  '001222_2014-06-17_16-24-06_260595134347_rgbf000073-resize_0',
                  '001498_2014-06-19_17-45-14_260595134347_rgbf000129-resize_4',
                  '001540_2014-06-20_17-01-05_260595134347_rgbf000086-resize_2']

# %%
catch_trial_cleaned_data, exclude = catchTrial_cleaning(age_cleaned_data, 6, all_catch_stim, sequences_count_dict, exclude)
len(exclude)
# Out:
# Number of participants that did not pass the catch trial check: 366
# Participants that were removed: [993293, 337855, 361118, 384084, 672587, 199719, 213165, 810569, 552070, 271282, 454653, 235866, 756315, 204178, 623759, 626250, 121796, 360771, 358793, 145368, 980305, 252260, 970492, 250584, 634447, 465507, 602927, 593754, 329190, 245150, 653026, 621633, 829661, 988435, 779298, 477725, 698532, 564687, 735548, 388835, 297316, 926551, 686124, 705460, 158127, 158205, 786056, 729944, 662848, 837088, 287484, 219796, 445032, 739896, 531988, 413923, 991770, 218701, 644462, 663587, 180648, 838264, 603293, 651729, 506066, 905663, 118627, 603376, 492147, 469479, 272047, 647678, 952653, 757584, 870425, 113882, 379933, 141370, 711133, 165253, 255119, 737436, 336867, 970981, 577956, 529889, 713343, 910393, 925395, 666910, 128865, 579336, 676615, 191373, 866086, 603735, 502526, 599477, 622232, 908721, 663932, 724385, 512637, 203565, 415111, 354578, 939925, 631043, 438570, 476295, 549075, 178999, 138942, 784533, 800178, 433234, 983798, 449004, 943714, 474252, 638287, 669037, 793228, 887257, 931948, 969341, 241740, 640450, 428881, 979077, 392029, 729709, 453024, 628645, 526714, 359992, 646735, 812610, 402343, 931391, 958879, 644201, 636347, 571519, 245117, 401821, 572329, 669386, 367249, 658248, 789736, 743554, 860188, 702396, 852495, 856289, 240096, 945121, 705900, 636755, 126667, 227151, 252951, 828865, 796821, 321135, 740754, 232259, 396020, 687829, 998354, 123935, 202019, 561067, 851081, 442083, 912472, 184299, 376446, 639021, 725146, 534552, 145257, 445873, 739048, 835528, 318552, 222615, 393300, 310372, 805728, 927450, 627311, 250416, 880565, 226853, 679854, 247521, 605251, 232630, 369540, 123268, 714896, 263804, 322366, 240085, 138483, 819793, 326049, 626727, 166671, 876757, 500788, 473972, 324625, 317199, 701497, 655437, 812736, 976033, 751527, 290496, 105636, 238763, 145792, 804396, 388013, 358364, 668301, 721406, 771771, 254234, 726595, 324072, 585509, 637876, 111908, 891077, 481815, 964443, 841555, 804456, 858876, 335106, 571596, 742016, 641151, 605617, 319604, 977488, 975469, 552384, 624901, 507720, 110496, 822051, 645545, 401046, 560512, 353461, 545096, 556968, 409500, 771408, 749000, 994489, 555092, 777408, 550146, 729318, 902311, 117428, 987560, 725003, 410379, 681743, 471013, 456982, 480328, 332849, 152298, 149886, 750531, 911881, 149639, 175604, 522070, 223311, 946823, 234372, 223712, 871293, 527750, 521117, 628501, 917970, 718954, 883022, 561433, 645473, 387613, 391365, 630830, 974329, 563676, 107774, 625078, 133484, 733185, 846070, 576730, 529234, 945231, 971348, 491548, 468031, 928490, 971887, 830612, 248093, 867338, 774263, 524441, 335898, 420820, 441122, 715693, 460362, 331300, 236276, 837031, 746280, 246490, 680594, 381681, 405990, 236494, 981546, 189617, 468932, 964000, 279337, 819331, 794856, 298143, 151160, 130344, 750246, 708772, 402334, 395305, 870813, 881071, 518650, 728200, 420331, 967750, 936578, 693109, 257064, 998058, 746638, 132622, 892576, 584982, 835910]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-26a68ded7296> in <module>
# ----> 1 catch_trial_cleaned_data, exclude = catchTrial_cleaning(age_cleaned_data, 6, all_catch_stim, sequences_count_dict, exclude)
#       2 len(exclude)
#
# <ipython-input-13-9cc2318bdedf> in catchTrial_cleaning(df, correct_requirement, catch_stimuli, sequence_count, exclude)
#      43     for index, row in df2.iterrows():
#      44         if row['subjID'] in remove:
# ---> 45             df2.drop(index, inplace=True)
#      46
#      47     # add the list of participants to be removed to the existing list of excluded participants
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3945             else:
#    3946                 new_axis = axis.drop(labels, errors=errors)
# -> 3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#    3949         # Case for non-unique axis
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3974         kwargs.pop("axis", None)
#    3975         kwargs.pop("labels", None)
# -> 3976         return super().reindex(**kwargs)
#    3977
#    3978     def drop(
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3862         if index is not None:
#    3863             frame = frame._reindex_index(
# -> 3864                 index, method, copy, level, fill_value, limit, tolerance
#    3865             )
#    3866
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3884             copy=copy,
#    3885             fill_value=fill_value,
# -> 3886             allow_dups=False,
#    3887         )
#    3888
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1311
#    1312         new_values = algos.take_nd(
# -> 1313             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1314         )
#    1315
#
# ~/opt/anaconda3/envs/defaultenv/lib/python3.7/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1719         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1720     )
# -> 1721     func(arr, indexer, out, fill_value)
#    1722
#    1723     if flip_order:
#
# KeyboardInterrupt:

# %%
def removeMissedTrials(df, exclude, num_trials):
    """
    Participants were told that if they missed a trial, to respond '0'.
    This function removes those trials, and keeps track of:
    (1) How many missed trials per participant
    (2) Number of missed trials per duration 
    (3) Number of missed trials per sequence 
    """
    
    missedTrials_participants = {}
    missedTrials_durations = {}
    missedTrials_sequences = {}
    
    
    for idx, row in df.iterrows():
        estimate = row['depth_estimate']
        if estimate == 0.0:
            subjID = row['subjID']
            duration = row['duration']
            sequenceName = row['sequenceName']
            
            if subjID not in missedTrials_participants:
                missedTrials_participants[subjID] = 1
            else:
                missedTrials_participants[subjID] += 1

            if duration not in missedTrials_durations:
                missedTrials_durations[duration] = 1
            else:
                missedTrials_durations[duration] += 1
            
            if sequenceName not in missedTrials_sequences:
                missedTrials_sequences[sequenceName] = 1
            else:
                missedTrials_sequences[sequenceName] += 1
                        
            # remove trials with depth estimate = 0 
            df.drop(idx, inplace=True)
    
    # remove participants data if the participant's missed trial count is 10% or more of num_trials
    threshold = math.floor(num_trials * 0.1)
    remove_ids = []
    for key in missedTrials_participants:
        if missedTrials_participants[key] >= threshold:
            remove_ids.append(key)
    print("Number of participants with 10% or more missed trials: ", len(remove_ids))

    for index, row in df.iterrows():
        if row['subjID'] in remove_ids:
            df.drop(index, inplace=True)
            
    exclude += remove_ids
    
    return df, exclude

# %%
# total number of meaningful trials (excludes catch-trials)
num_trials = 156

# %%
missed_trial_cleaned_data, exclude = removeMissedTrials(catch_trial_cleaned_data,exclude, num_trials)
len(exclude)

# %%
def RT_Cleaning(df, exclude, outlier_range, num_trials):
    #List unique values in the df['subjID'] column
    all_subjIDs = df.subjID.unique()
    
    remove = []
    df2_list = []
    for subj in all_subjIDs:
        count = 0
        subj_df = df.loc[df['subjID'] == subj]
        cleaned_subj_df = subj_df.copy(deep=True) # prevent setting with copy warning 
        # calculate subject's average trial RT 
        average_trial_RT = subj_df["trial_RT"].mean()
        std_trial_RT = subj_df["trial_RT"].std()

        for idx, row in subj_df.iterrows():
            RT = row["trial_RT"]
            if RT < outlier_range[0]: # outlier
                cleaned_subj_df.drop([idx], inplace=True)
                count += 1
            if RT > outlier_range[1]:
                cleaned_subj_df.drop([idx], inplace=True)
                count += 1
                
        threshold = math.floor(num_trials * 0.1)
        if count >= threshold:
            remove.append(subj)
        
        df2_list.append(cleaned_subj_df)
    
    df2 = pd.concat(df2_list)
            
    print("Number of Participants with 10% or more trials outside their RT range: ", len(remove))
    
    for index, row in df2.iterrows():
        if row['subjID'] in remove:
            df2.drop(index, inplace=True)
            
    exclude += remove
    
    return df2, exclude

# %%
RT_cleaned_data, exclude = RT_Cleaning(missed_trial_cleaned_data, exclude,[250, 10000], num_trials)
len(exclude)

# %%
def repeatResponses_Cleaning(df, exclude):
    """
    Some participants gave'junk data' - same number repeated for many trials 
    Count the frequency of unique responses entered by the participant. 
    If you look at the maximum number of repeats and/or the number of unique responses / 48 per participant you will find our vandals.
    """
    #List unique values in the df['subjID'] column
    all_subjIDs = df.subjID.unique()
    
    remove = []
    max_repeats_distribution = []
    num_unique_responses_distribution = []
    for subj in all_subjIDs:
        subj_df = df.loc[df['subjID'] == subj]
        # ideally, the max repeats and num_unique_responses should be ~ 48 since there are 48 imgs at each depth bin 
        count_depth_estimates = subj_df['depth_estimate'].value_counts()
        num_unique_responses = len(count_depth_estimates)
        num_unique_responses_distribution.append(num_unique_responses)
        max_repeats = count_depth_estimates.max()
        max_repeats_distribution.append(max_repeats)
        if num_unique_responses < 6:
            remove.append(subj)
    
    avg_max_repeats = np.array(max_repeats_distribution).mean()
    std_max_repeats = np.array(max_repeats_distribution).std()
    
    for subj in all_subjIDs:
        subj_df = df.loc[df['subjID'] == subj]
        count_depth_estimates = subj_df['depth_estimate'].value_counts()
        max_repeats = count_depth_estimates.max()

        outlierrange = [avg_max_repeats - (3*std_max_repeats), avg_max_repeats + (3*std_max_repeats)]
        if max_repeats < outlierrange[0]:
            if subj not in remove:
                remove.append(subj)
        if max_repeats > outlierrange[1]:
            if subj not in remove:
                remove.append(subj)
                
    print("Number of participants removed: repeat responses: ", len(remove))
    
    for index, row in df.iterrows():
        if row['subjID'] in remove:
            df.drop(index, inplace=True)

    exclude += remove
    
    return df, max_repeats_distribution, num_unique_responses_distribution, exclude

# %%
repeat_resp_cleaned_data, max_repeats_distrib, num_unique_distrib, exclude = repeatResponses_Cleaning(RT_cleaned_data, exclude)
len(exclude)

# %%
def finalTrialCountCheck(df, exclude, num_trials):
    """
    If more then 10% of a participants data is missing, remove the participant
    """
    #List unique values in the df['subjID'] column
    all_subjIDs = df.subjID.unique()
    
    remove = []
    for subj in all_subjIDs:
        subj_df = df.loc[df['subjID'] == subj]
        count_trials = len(subj_df.index)
        threshold_trials_remaining = num_trials - math.floor(num_trials * 0.1)

        if count_trials <= threshold_trials_remaining:
            remove.append(subj)
            
    print("Number of Participants with >= 10% trials removed: ", len(remove))
    
    for index, row in df.iterrows():
        if row['subjID'] in remove:
            df.drop(index, inplace=True)
            
    exclude += remove
        
    print("Number of participants left: ",len(df.subjID.unique()))
    return df, exclude

# %%
cleaned_data, exclude = finalTrialCountCheck(repeat_resp_cleaned_data, exclude, num_trials)
len(exclude)

# %%
def get_sequences_for_replacement(exclude, datafolder):
    
    og_data = combineCSVs(datafolder)
    
    seqs_to_be_replaced = []
    for subjID in exclude:
        subjdf = og_data.loc[og_data['subjID'] == subjID]
        seqs_to_be_replaced.append(subjdf.sequenceName.unique()[0])
    print('Number of Sequences to be replaced:', len(seqs_to_be_replaced))
    return seqs_to_be_replaced

# %%
sequences_to_replace = get_sequences_for_replacement(exclude, data_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-28ce79e4884d> in <module>
# ----> 1 sequences_to_replace = get_sequences_for_replacement(exclude, data_path)
#
# NameError: name 'exclude' is not defined

# %%
counterbalancing_path = '/Users/prachimahableshwarkar/Documents/GW/FacialAge/FacialAge_MTurk/BNav_EC2/DepthDuration/v2_depth_duration_MTurk/counterbalancing.csv'
counterbalancing_df = pd.read_csv(counterbalancing_path)
counterbalancing_df

# %%
sequences_to_replace[0]

# %%
url_fragments = []
for sequence in sequences_to_replace:
    url_fragments.append(counterbalancing_df.index[counterbalancing_df['Path']==sequence][0] + 1)

# %%
# number for the NEXT batch 
batch = 1

# %%
dest_variables_csv = '/Users/prachimahableshwarkar/Documents/GW/FacialAge/FacialAge_MTurk/BNav_EC2/DepthDuration/v2_depth_duration_MTurk/mturk_batch_variables/'

base_url = 'http://54.235.29.9/FacialAge/BNav_EC2/DepthDuration/v2_depth_duration_MTurk/v2_DepthDuration_HTML.html#'

variables = {'experiment_url': []}

for fragment in url_fragments:
     variables['experiment_url'].append(base_url + str(fragment))

variables_df = pd.DataFrame(variables)

# %%
variables_df.to_csv(dest_variables_csv + 'depth_duration_variables' + '_' + str(batch) + '.csv', index=False)
