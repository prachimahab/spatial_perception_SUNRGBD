# %%
import numpy as np
import pandas as pd
from scipy.stats import stats
from sklearn.linear_model import LinearRegression
import random
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from time import process_time

# %% [markdown]
# # Load in z-scored VE data

# %%
_dir = '/Users/pmahableshwarkar/Documents/Depth_Project'

VE_data_125_path = _dir + '/verbal_judgement_analysis/data/finalVEMatched/z_scored/z_scored_125_data.csv'

VE_data_250_path = _dir + '/verbal_judgement_analysis/data/finalVEMatched/z_scored/z_scored_250_data.csv'

VE_data_1000_path = _dir + '/verbal_judgement_analysis/data/finalVEMatched/z_scored/z_scored_1000_data.csv'

VE_data_125 = pd.read_csv(VE_data_125_path)
VE_data_250 = pd.read_csv(VE_data_250_path)
VE_data_1000 = pd.read_csv(VE_data_1000_path)

# %%
rm = ['Unnamed: 0', 'workerId', 'experimentName', 'versionName',
       'sequenceName', 'url', 'selected_row', 'windowWidth', 'windowHeight',
       'screenWidth', 'screenHeight', 'startDate', 'startTime', 'trial',
       'log_sceneDuration', 'unitSelection', 'seq_filepath', 'experimentTime',
       'totalTime', 'age', 'gender']

# %%
VE_data_125.drop(columns=rm, inplace=True)
VE_data_250.drop(columns=rm, inplace=True)
VE_data_1000.drop(columns=rm, inplace=True)

# %%
def get_stimuli(duration_df):
    """
    Args:
        duration df 
    Returns:
        all_stimuli
    """
    
    return list(duration_df.stimulus.unique())

def rand_data(duration_df, proportion):
    """
    Args
        Data post outlier removal: i.e. cleaned_data 
        proportion - amount of data in each split (0.5 for 50/50 split)
    """
#     start_time = process_time()
    
    stimuli = get_stimuli(duration_df)
    
    rand0_y = []
    rand0_std = []
    rand0_ste = []
    rand0_stim = []
    
    rand0_all_ys = []
    
    rand0_subjIDs = []
    
    rand0_RTs = []
    
    rand1_y = []
    rand1_std = []
    rand1_ste = []
    rand1_stim = []
    
    rand1_all_ys = []
    
    rand1_subjIDs = []
    
    rand1_RTs = []
    
    rand0_stim_dfs = []
    rand1_stim_dfs = []

    grouped = duration_df.groupby(duration_df.stimulus) 
    for stim in stimuli:   
        stim_df = grouped.get_group(stim)
        stim_df_estimates = stim_df['depth_estimate'].tolist()
        stim_df_RTs = stim_df['trial_RT'].tolist()
        stim_df_subjIDs = stim_df['subjID'].tolist()
        
        # Shuffle two lists with same order
        # Using zip() + * operator + shuffle()
        temp = list(zip(stim_df_subjIDs, stim_df_estimates, stim_df_RTs))
        random.shuffle(temp)
        random.shuffle(temp)
        shuffled_subjIDs, shuffled_estimates, shuffled_RTs = zip(*temp)
        # res1 and res2 come out as tuples, and so must be converted to lists.
        shuffled_subjIDs, shuffled_estimates, shuffled_RTs = list(shuffled_subjIDs), list(shuffled_estimates), list(shuffled_RTs)
        
        rand0_all_ys.append(np.array(shuffled_estimates[0:int(len(shuffled_estimates)*proportion)]))
        rand0_subjIDs.append(np.array(shuffled_subjIDs[0:int(len(shuffled_subjIDs)*proportion)]))
        rand0_RTs.append(np.array(shuffled_RTs[0:int(len(shuffled_RTs)*proportion)]))
        
        estim_avg_df0 = np.mean(np.array(shuffled_estimates[0:int(len(shuffled_estimates)*proportion)]))
        estim_std0 = np.std(np.array(shuffled_estimates[0:int(len(shuffled_estimates)*proportion)]))
        estim_ste0 = stats.sem(np.array(shuffled_estimates[0:int(len(shuffled_estimates)*proportion)]))
        
        rand0_y.append(estim_avg_df0) 
        rand0_std.append(estim_std0)
        rand0_ste.append(estim_ste0)
        rand0_stim.append(stim)
        
        # subjects included in split 0 for a particular stimulus
        stim_rand0_subjIDs = np.array(shuffled_subjIDs[0:int(len(shuffled_subjIDs)*proportion)])
        # keep data from subjects that are in the above list 
        stim_rand0_df = stim_df.loc[stim_df['subjID'].isin(stim_rand0_subjIDs)]
        rand0_stim_dfs.append(stim_rand0_df)
        
#         print(len(stim_df.subjID.unique()), len(stim_rand0_df.subjID.unique()))
        
        
        rand1_all_ys.append(np.array(shuffled_estimates[int(len(shuffled_estimates)*proportion):]))
        rand1_subjIDs.append(np.array(shuffled_subjIDs[int(len(shuffled_subjIDs)*proportion):]))
        rand1_RTs.append(np.array(shuffled_RTs[int(len(shuffled_RTs)*proportion):]))
        
        estim_avg_df1 = np.mean(np.array(shuffled_estimates[int(len(shuffled_estimates)*proportion):]))
        estim_std1 = np.std(np.array(shuffled_estimates[int(len(shuffled_estimates)*proportion):]))
        estim_ste1 = stats.sem(np.array(shuffled_estimates[int(len(shuffled_estimates)*proportion):]))
        
        rand1_y.append(estim_avg_df1) 
        rand1_std.append(estim_std1)
        rand1_ste.append(estim_ste1)
        rand1_stim.append(stim)
        
        # subjects included in split 1 for a particular stimulus
        stim_rand1_subjIDs = np.array(shuffled_subjIDs[int(len(shuffled_subjIDs)*proportion):])
        # keep data from subjects that are in the above list        
        stim_rand1_df = stim_df.loc[stim_df['subjID'].isin(stim_rand1_subjIDs)]
        rand1_stim_dfs.append(stim_rand1_df)

        
    # combine all stim dataframes for split 0
    rand0_df = pd.concat(rand0_stim_dfs)
    
    rand0_y = np.array(rand0_y).reshape(1,-1)[0]
    rand0_std = np.array(rand0_std).reshape(1,-1)[0]
    rand0_ste = np.array(rand0_ste).reshape(1,-1)[0]
    rand0_stim = np.array(rand0_stim).reshape(1,-1)[0]
    
    # combine all stim dataframes for split 1
    rand1_df = pd.concat(rand1_stim_dfs)

    rand1_y = np.array(rand1_y).reshape(1,-1)[0]
    rand1_std = np.array(rand1_std).reshape(1,-1)[0]
    rand1_ste = np.array(rand1_ste).reshape(1,-1)[0]
    rand1_stim = np.array(rand1_stim).reshape(1,-1)[0]
    
    
#     end_time = process_time()
#     print(f"rand_data: {(end_time - start_time)} seconds")

    print(len(rand0_y), len(rand1_y))
    
    return [rand0_y, rand0_std, rand0_ste, rand0_stim], rand0_df, [rand1_y, rand1_std, rand1_ste, rand1_stim], rand1_df

# %%
r0_125, r0_125_df, r1_125, r1_125_df = rand_data(VE_data_125, 0.5)
r0_250, r0_250_df, r1_250, r1_250_df = rand_data(VE_data_250, 0.5)
r0_1000, r0_1000_df, r1_1000, r1_1000_df = rand_data(VE_data_1000, 0.5)
# Out:
# 156 156
# 156 156
# 156 156

# %%
plt.hist(list(r1_125_df['trial_RT']))
# Out:
# (array([4.750e+02, 6.509e+03, 3.229e+03, 9.860e+02, 3.850e+02, 1.480e+02,
#         6.200e+01, 3.000e+01, 1.600e+01, 3.000e+00]),
#  array([-2.07047277, -1.08018989, -0.08990702,  0.90037586,  1.89065873,
#          2.88094161,  3.87122449,  4.86150736,  5.85179024,  6.84207311,
#          7.83235599]),
#  <a list of 10 Patch objects>)

# %%
# Out:
#          subjID                                           stimulus  duration  \
# 17035  478211.0  depth_duration_stimuli/001100_2014-06-15_17-46...     125.0
# 11476  525452.0  depth_duration_stimuli/001516_2014-06-20_16-25...     125.0
# 5840   959126.0  depth_duration_stimuli/002118_2014-06-25_20-32...     125.0
# 19368  102409.0  depth_duration_stimuli/003083_2014-06-15_15-21...     125.0
# 4813   965886.0  depth_duration_stimuli/003070_2014-06-15_14-58...     125.0
# ...         ...                                                ...       ...
# 12925  170213.0  depth_duration_stimuli/001450_2014-06-19_17-02...     125.0
# 3971   762610.0  depth_duration_stimuli/000691_2014-06-08_13-08...     125.0
# 17491  753290.0  depth_duration_stimuli/001555_2014-06-20_17-12...     125.0
# 18657  695213.0  depth_duration_stimuli/000483_2014-06-09_20-41...     125.0
# 13999  388057.0  depth_duration_stimuli/002663_2014-06-13_15-50...     125.0
#
#        actual_depth  depth_estimate  trial_RT
# 17035      2.240000       -1.443312  0.838246
# 11476      1.744500        0.130387 -0.244661
# 5840       2.646000       -0.137554 -0.548164
# 19368      4.140500        2.811643  1.381172
# 4813       2.941500       -0.143101 -0.420278
# ...             ...             ...       ...
# 12925      4.010667        0.447697 -0.022186
# 3971       4.153000        1.506442  3.374773
# 17491      1.633000       -1.290108 -0.120701
# 18657      1.337000       -1.247064 -0.786990
# 13999      4.749500        1.400550  0.514051
#
# [11772 rows x 6 columns]

# %%
# %%time
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, wait, as_completed


dfs = [] 
    
def run_analysis():
    
    r0_125, r0_125_df, r1_125, r1_125_df = rand_data(VE_data_125, 0.5)
    r0_250, r0_250_df, r1_250, r1_250_df = rand_data(VE_data_250, 0.5)
    r0_1000, r0_1000_df, r1_1000, r1_1000_df = rand_data(VE_data_1000, 0.5)
    
   
    r0_125_df = r0_125_df.sample(frac=1)
    r1_125_df = r1_125_df.sample(frac=1)

    data = {'r0_VE_125': list(r0_125_df['depth_estimate']),
        'r0_VE_250': list(r0_250_df['depth_estimate']),
        'r0_VE_1000': list(r0_1000_df['depth_estimate']),
        'r0_RT_125': list(r0_125_df['trial_RT']),
        'r0_RT_250': list(r0_250_df['trial_RT']),
        'r0_RT_1000': list(r0_1000_df['trial_RT']),
        'r1_VE_125': list(r1_125_df['depth_estimate']),
        'r1_VE_250': list(r1_250_df['depth_estimate']),
        'r1_VE_1000': list(r1_1000_df['depth_estimate']),
        'r1_RT_125': list(r1_125_df['trial_RT']),
        'r1_RT_250': list(r1_250_df['trial_RT']),
        'r1_RT_1000': list(r1_1000_df['trial_RT'])
        }
    
    # get size of shortest data column
    lens = []
    for key in data:
        lens.append(len(data[key]))
    min_len = min(lens)

    
    # make col data of equal length
    trunc_data = {'r0_VE_125': data['r0_VE_125'][:min_len],
                 'r0_VE_250': data['r0_VE_250'][:min_len],
                 'r0_VE_1000': data['r0_VE_1000'][:min_len],
                 'r0_RT_125': data['r0_RT_125'][:min_len],
                 'r0_RT_250': data['r0_RT_250'][:min_len],
                 'r0_RT_1000': data['r0_RT_1000'][:min_len],
                 'r1_VE_125': data['r1_VE_125'][:min_len],
                 'r1_VE_250': data['r1_VE_250'][:min_len],
                 'r1_VE_1000': data['r1_VE_1000'][:min_len],
                 'r1_RT_125': data['r1_RT_125'][:min_len],
                 'r1_RT_250': data['r1_RT_250'][:min_len],
                 'r1_RT_1000': data['r1_RT_1000'][:min_len]}
    
#     for key in trunc_data:
#         print(len(trunc_data[key]))
        
    trunc_data_df = pd.DataFrame(trunc_data,columns=['r0_VE_125', 'r0_VE_250', 'r0_VE_1000', 'r0_RT_125', 'r0_RT_250', 'r0_RT_1000',
                                               'r1_VE_125', 'r1_VE_250', 'r1_VE_1000', 'r1_RT_125', 'r1_RT_250', 'r1_RT_1000'])
    df_corr = trunc_data_df.corr()
    
    return df_corr    


reps = 10000
dfs = []


import multiprocessing as mp

executor = ProcessPoolExecutor(max_workers=mp.cpu_count()//4)
for i in range(reps):
    print("Enqueuing run_analysis rep: ", i)
    dfs.append(executor.submit(run_analysis))

for count, future in enumerate(as_completed(dfs)):
    print("Rep completed :", count)
    
print(len(dfs))
    
df_sum = 0
for i, df in enumerate(dfs):
    df_sum += df.result()

mean_df_corr = df_sum / len(dfs)
executor.shutdown(wait=True)

mean_df_corr.to_csv('VE_avg_randSplitMatrix_n' + str(reps) + '.csv')
# Out:
# Enqueuing run_analysis rep:  0
# Enqueuing run_analysis rep:  1
# Enqueuing run_analysis rep:  2
# Enqueuing run_analysis rep:  3
# Enqueuing run_analysis rep:  4
# Enqueuing run_analysis rep:  5
# Enqueuing run_analysis rep:  6
# Enqueuing run_analysis rep:  7
# Enqueuing run_analysis rep:  8
# Enqueuing run_analysis rep:  9
# Enqueuing run_analysis rep:  10
# Enqueuing run_analysis rep:  11
# Enqueuing run_analysis rep:  12
# Enqueuing run_analysis rep:  13
# Enqueuing run_analysis rep:  14
# Enqueuing run_analysis rep:  15
# Enqueuing run_analysis rep:  16
# Enqueuing run_analysis rep:  17
# Enqueuing run_analysis rep:  18
# Enqueuing run_analysis rep:  19
# Enqueuing run_analysis rep:  20
# Enqueuing run_analysis rep:  21
# Enqueuing run_analysis rep:  22
# Enqueuing run_analysis rep:  23
# Enqueuing run_analysis rep:  24
# Enqueuing run_analysis rep:  25
# Enqueuing run_analysis rep:  26
# Enqueuing run_analysis rep:  27
# Enqueuing run_analysis rep:  28
# Enqueuing run_analysis rep:  29
# Enqueuing run_analysis rep:  30
# Enqueuing run_analysis rep:  31
# Enqueuing run_analysis rep:  32
# Enqueuing run_analysis rep:  33
# Enqueuing run_analysis rep:  34
# Enqueuing run_analysis rep:  35
# Enqueuing run_analysis rep:  36
# Enqueuing run_analysis rep:  37
# Enqueuing run_analysis rep:  38
# Enqueuing run_analysis rep:  39
# Enqueuing run_analysis rep:  40
# Enqueuing run_analysis rep:  41
# Enqueuing run_analysis rep:  42
# Enqueuing run_analysis rep:  43
# Enqueuing run_analysis rep:  44
# Enqueuing run_analysis rep:  45
# Enqueuing run_analysis rep:  46
# Enqueuing run_analysis rep:  47
# Enqueuing run_analysis rep:  48
# Enqueuing run_analysis rep:  49
# Enqueuing run_analysis rep:  50
# Enqueuing run_analysis rep:  51
# Enqueuing run_analysis rep:  52
# Enqueuing run_analysis rep:  53
# Enqueuing run_analysis rep:  54
# Enqueuing run_analysis rep:  55
# Enqueuing run_analysis rep:  56
# Enqueuing run_analysis rep:  57
# Enqueuing run_analysis rep:  58
# Enqueuing run_analysis rep:  59
# Enqueuing run_analysis rep:  60
# Enqueuing run_analysis rep:  61
# Enqueuing run_analysis rep:  62
# Enqueuing run_analysis rep:  63
# Enqueuing run_analysis rep:  64
# Enqueuing run_analysis rep:  65
# Enqueuing run_analysis rep:  66
# Enqueuing run_analysis rep:  67
# Enqueuing run_analysis rep:  68
# Enqueuing run_analysis rep:  69
# Enqueuing run_analysis rep:  70
# Enqueuing run_analysis rep:  71
# Enqueuing run_analysis rep:  72
# Enqueuing run_analysis rep:  73
# Enqueuing run_analysis rep:  74
# Enqueuing run_analysis rep:  75
# Enqueuing run_analysis rep:  76
# Enqueuing run_analysis rep:  77
# Enqueuing run_analysis rep:  78
# Enqueuing run_analysis rep:  79
# Enqueuing run_analysis rep:  80
# Enqueuing run_analysis rep:  81
# Enqueuing run_analysis rep:  82
# Enqueuing run_analysis rep:  83
# Enqueuing run_analysis rep:  84
# Enqueuing run_analysis rep:  85
# Enqueuing run_analysis rep:  86
# Enqueuing run_analysis rep:  87
# Enqueuing run_analysis rep:  88
# Enqueuing run_analysis rep:  89
# Enqueuing run_analysis rep:  90
# Enqueuing run_analysis rep:  91
# Enqueuing run_analysis rep:  92
# Enqueuing run_analysis rep:  93
# Enqueuing run_analysis rep:  94
# Enqueuing run_analysis rep:  95
# Enqueuing run_analysis rep:  96
# Enqueuing run_analysis rep:  97
# Enqueuing run_analysis rep:  98
# Enqueuing run_analysis rep:  99
# Enqueuing run_analysis rep:  100
# Enqueuing run_analysis rep:  101
# Enqueuing run_analysis rep:  102
# Enqueuing run_analysis rep:  103
# Enqueuing run_analysis rep:  104
# Enqueuing run_analysis rep:  105
# Enqueuing run_analysis rep:  106
# Enqueuing run_analysis rep:  107
# Enqueuing run_analysis rep:  108
# Enqueuing run_analysis rep:  109
# Enqueuing run_analysis rep:  110
# Enqueuing run_analysis rep:  111
# Enqueuing run_analysis rep:  112
# Enqueuing run_analysis rep:  113
# Enqueuing run_analysis rep:  114
# Enqueuing run_analysis rep:  115
# Enqueuing run_analysis rep:  116
# Enqueuing run_analysis rep:  117
# Enqueuing run_analysis rep:  118
# Enqueuing run_analysis rep:  119
# Enqueuing run_analysis rep:  120
# Enqueuing run_analysis rep:  121
# Enqueuing run_analysis rep:  122
# Enqueuing run_analysis rep:  123
# Enqueuing run_analysis rep:  124
# Enqueuing run_analysis rep:  125
# Enqueuing run_analysis rep:  126
# Enqueuing run_analysis rep:  127
# Enqueuing run_analysis rep:  128
# Enqueuing run_analysis rep:  129
# Enqueuing run_analysis rep:  130
# Enqueuing run_analysis rep:  131
# Enqueuing run_analysis rep:  132
# Enqueuing run_analysis rep:  133
# Enqueuing run_analysis rep:  134
# Enqueuing run_analysis rep:  135
# Enqueuing run_analysis rep:  136
# Enqueuing run_analysis rep:  137
# Enqueuing run_analysis rep:  138
# Enqueuing run_analysis rep:  139
# Enqueuing run_analysis rep:  140
# Enqueuing run_analysis rep:  141
# Enqueuing run_analysis rep:  142
# Enqueuing run_analysis rep:  143
# Enqueuing run_analysis rep:  144
# Enqueuing run_analysis rep:  145
# Enqueuing run_analysis rep:  146
# Enqueuing run_analysis rep:  147
# Enqueuing run_analysis rep:  148
# Enqueuing run_analysis rep:  149
# Enqueuing run_analysis rep:  150
# Enqueuing run_analysis rep:  151
# Enqueuing run_analysis rep:  152
# Enqueuing run_analysis rep:  153
# Enqueuing run_analysis rep:  154
# Enqueuing run_analysis rep:  155
# Enqueuing run_analysis rep:  156
# Enqueuing run_analysis rep:  157
# Enqueuing run_analysis rep:  158
# Enqueuing run_analysis rep:  159
# Enqueuing run_analysis rep:  160
# Enqueuing run_analysis rep:  161
# Enqueuing run_analysis rep:  162
# Enqueuing run_analysis rep:  163
# Enqueuing run_analysis rep:  164
# Enqueuing run_analysis rep:  165
# Enqueuing run_analysis rep:  166
# Enqueuing run_analysis rep:  167
# Enqueuing run_analysis rep:  168
# Enqueuing run_analysis rep:  169
# Enqueuing run_analysis rep:  170
# Enqueuing run_analysis rep:  171
# Enqueuing run_analysis rep:  172
# Enqueuing run_analysis rep:  173
# Enqueuing run_analysis rep:  174
# Enqueuing run_analysis rep:  175
# Enqueuing run_analysis rep:  176
# Enqueuing run_analysis rep:  177
# Enqueuing run_analysis rep:  178
# Enqueuing run_analysis rep:  179
# Enqueuing run_analysis rep:  180
# Enqueuing run_analysis rep:  181
# Enqueuing run_analysis rep:  182
# Enqueuing run_analysis rep:  183
# Enqueuing run_analysis rep:  184
# Enqueuing run_analysis rep:  185
# Enqueuing run_analysis rep:  186
# Enqueuing run_analysis rep:  187
# Enqueuing run_analysis rep:  188
# Enqueuing run_analysis rep:  189
# Enqueuing run_analysis rep:  190
# Enqueuing run_analysis rep:  191
# Enqueuing run_analysis rep:  192
# Enqueuing run_analysis rep:  193
# Enqueuing run_analysis rep:  194
# Enqueuing run_analysis rep:  195
# Enqueuing run_analysis rep:  196
# Enqueuing run_analysis rep:  197
# Enqueuing run_analysis rep:  198
# Enqueuing run_analysis rep:  199
# Enqueuing run_analysis rep:  200
# Enqueuing run_analysis rep:  201
# Enqueuing run_analysis rep:  202
# Enqueuing run_analysis rep:  203
# Enqueuing run_analysis rep:  204
# Enqueuing run_analysis rep:  205
# Enqueuing run_analysis rep:  206
# Enqueuing run_analysis rep:  207
# Enqueuing run_analysis rep:  208
# Enqueuing run_analysis rep:  209
# Enqueuing run_analysis rep:  210
# Enqueuing run_analysis rep:  211
# Enqueuing run_analysis rep:  212
# Enqueuing run_analysis rep:  213
# Enqueuing run_analysis rep:  214
# Enqueuing run_analysis rep:  215
# Enqueuing run_analysis rep:  216
# Enqueuing run_analysis rep:  217
# Enqueuing run_analysis rep:  218
# Enqueuing run_analysis rep:  219
# Enqueuing run_analysis rep:  220
# Enqueuing run_analysis rep:  221
# Enqueuing run_analysis rep:  222
# Enqueuing run_analysis rep:  223
# Enqueuing run_analysis rep:  224
# Enqueuing run_analysis rep:  225
# Enqueuing run_analysis rep:  226
# Enqueuing run_analysis rep:  227
# Enqueuing run_analysis rep:  228
# Enqueuing run_analysis rep:  229
# Enqueuing run_analysis rep:  230
# Enqueuing run_analysis rep:  231
# Enqueuing run_analysis rep:  232
# Enqueuing run_analysis rep:  233
# Enqueuing run_analysis rep:  234
# Enqueuing run_analysis rep:  235
# Enqueuing run_analysis rep:  236
# Enqueuing run_analysis rep:  237
# Enqueuing run_analysis rep:  238
# Enqueuing run_analysis rep:  239
# Enqueuing run_analysis rep:  240
# Enqueuing run_analysis rep:  241
# Enqueuing run_analysis rep:  242
# Enqueuing run_analysis rep:  243
# Enqueuing run_analysis rep:  244
# Enqueuing run_analysis rep:  245
# Enqueuing run_analysis rep:  246
# Enqueuing run_analysis rep:  247
# Enqueuing run_analysis rep:  248
# Enqueuing run_analysis rep:  249
# Enqueuing run_analysis rep:  250
# Enqueuing run_analysis rep:  251
# Enqueuing run_analysis rep:  252
# Enqueuing run_analysis rep:  253
# Enqueuing run_analysis rep:  254
# Enqueuing run_analysis rep:  255
# Enqueuing run_analysis rep:  256
# Enqueuing run_analysis rep:  257
# Enqueuing run_analysis rep:  258
# Enqueuing run_analysis rep:  259
# Enqueuing run_analysis rep:  260
# Enqueuing run_analysis rep:  261
# Enqueuing run_analysis rep:  262
# Enqueuing run_analysis rep:  263
# Enqueuing run_analysis rep:  264
# Enqueuing run_analysis rep:  265
# Enqueuing run_analysis rep:  266
# Enqueuing run_analysis rep:  267
# Enqueuing run_analysis rep:  268
# Enqueuing run_analysis rep:  269
# Enqueuing run_analysis rep:  270
# Enqueuing run_analysis rep:  271
# Enqueuing run_analysis rep:  272
# Enqueuing run_analysis rep:  273
# Enqueuing run_analysis rep:  274
# Enqueuing run_analysis rep:  275
# Enqueuing run_analysis rep:  276
# Enqueuing run_analysis rep:  277
# Enqueuing run_analysis rep:  278
# Enqueuing run_analysis rep:  279
# Enqueuing run_analysis rep:  280
# Enqueuing run_analysis rep:  281
# Enqueuing run_analysis rep:  282
# Enqueuing run_analysis rep:  283
# Enqueuing run_analysis rep:  284
# Enqueuing run_analysis rep:  285
# Enqueuing run_analysis rep:  286
# Enqueuing run_analysis rep:  287
# Enqueuing run_analysis rep:  288
# Enqueuing run_analysis rep:  289
# Enqueuing run_analysis rep:  290
# Enqueuing run_analysis rep:  291
# Enqueuing run_analysis rep:  292
# Enqueuing run_analysis rep:  293
# Enqueuing run_analysis rep:  294
# Enqueuing run_analysis rep:  295
# Enqueuing run_analysis rep:  296
# Enqueuing run_analysis rep:  297
# Enqueuing run_analysis rep:  298
# Enqueuing run_analysis rep:  299
# Enqueuing run_analysis rep:  300
# Enqueuing run_analysis rep:  301
# Enqueuing run_analysis rep:  302
# Enqueuing run_analysis rep:  303
# Enqueuing run_analysis rep:  304
# Enqueuing run_analysis rep:  305
# Enqueuing run_analysis rep:  306
# Enqueuing run_analysis rep:  307
# Enqueuing run_analysis rep:  308
# Enqueuing run_analysis rep:  309
# Enqueuing run_analysis rep:  310
# Enqueuing run_analysis rep:  311
# Enqueuing run_analysis rep:  312
# Enqueuing run_analysis rep:  313
# Enqueuing run_analysis rep:  314
# Enqueuing run_analysis rep:  315
# Enqueuing run_analysis rep:  316
# Enqueuing run_analysis rep:  317
# Enqueuing run_analysis rep:  318
# Enqueuing run_analysis rep:  319
# Enqueuing run_analysis rep:  320
# Enqueuing run_analysis rep:  321
# Enqueuing run_analysis rep:  322
# Enqueuing run_analysis rep:  323
# Enqueuing run_analysis rep:  324
# Enqueuing run_analysis rep:  325
# Enqueuing run_analysis rep:  326
# Enqueuing run_analysis rep:  327
# Enqueuing run_analysis rep:  328
# Enqueuing run_analysis rep:  329
# Enqueuing run_analysis rep:  330
# Enqueuing run_analysis rep:  331
# Enqueuing run_analysis rep:  332
# Enqueuing run_analysis rep:  333
# Enqueuing run_analysis rep:  334
# Enqueuing run_analysis rep:  335
# Enqueuing run_analysis rep:  336
# Enqueuing run_analysis rep:  337
# Enqueuing run_analysis rep:  338
# Enqueuing run_analysis rep:  339
# Enqueuing run_analysis rep:  340
# Enqueuing run_analysis rep:  341
# Enqueuing run_analysis rep:  342
# Enqueuing run_analysis rep:  343
# Enqueuing run_analysis rep:  344
# Enqueuing run_analysis rep:  345
# Enqueuing run_analysis rep:  346
# Enqueuing run_analysis rep:  347
# Enqueuing run_analysis rep:  348
# Enqueuing run_analysis rep:  349
# Enqueuing run_analysis rep:  350
# Enqueuing run_analysis rep:  351
# Enqueuing run_analysis rep:  352
# Enqueuing run_analysis rep:  353
# Enqueuing run_analysis rep:  354
# Enqueuing run_analysis rep:  355
# Enqueuing run_analysis rep:  356
# Enqueuing run_analysis rep:  357
# Enqueuing run_analysis rep:  358
# Enqueuing run_analysis rep:  359
# Enqueuing run_analysis rep:  360
# Enqueuing run_analysis rep:  361
# Enqueuing run_analysis rep:  362
# Enqueuing run_analysis rep:  363
# Enqueuing run_analysis rep:  364
# Enqueuing run_analysis rep:  365
# Enqueuing run_analysis rep:  366
# Enqueuing run_analysis rep:  367
# Enqueuing run_analysis rep:  368
# Enqueuing run_analysis rep:  369
# Enqueuing run_analysis rep:  370
# Enqueuing run_analysis rep:  371
# Enqueuing run_analysis rep:  372
# Enqueuing run_analysis rep:  373
# Enqueuing run_analysis rep:  374
# Enqueuing run_analysis rep:  375
# Enqueuing run_analysis rep:  376
# Enqueuing run_analysis rep:  377
# Enqueuing run_analysis rep:  378
# Enqueuing run_analysis rep:  379
# Enqueuing run_analysis rep:  380
# Enqueuing run_analysis rep:  381
# Enqueuing run_analysis rep:  382
# Enqueuing run_analysis rep:  383
# Enqueuing run_analysis rep:  384
# Enqueuing run_analysis rep:  385
# Enqueuing run_analysis rep:  386
# Enqueuing run_analysis rep:  387
# Enqueuing run_analysis rep:  388
# Enqueuing run_analysis rep:  389
# Enqueuing run_analysis rep:  390
# Enqueuing run_analysis rep:  391
# Enqueuing run_analysis rep:  392
# Enqueuing run_analysis rep:  393
# Enqueuing run_analysis rep:  394
# Enqueuing run_analysis rep:  395
# Enqueuing run_analysis rep:  396
# Enqueuing run_analysis rep:  397
# Enqueuing run_analysis rep:  398
# Enqueuing run_analysis rep:  399
# Enqueuing run_analysis rep:  400
# Enqueuing run_analysis rep:  401
# Enqueuing run_analysis rep:  402
# Enqueuing run_analysis rep:  403
# Enqueuing run_analysis rep:  404
# Enqueuing run_analysis rep:  405
# Enqueuing run_analysis rep:  406
# Enqueuing run_analysis rep:  407
# Enqueuing run_analysis rep:  408
# Enqueuing run_analysis rep:  409
# Enqueuing run_analysis rep:  410
# Enqueuing run_analysis rep:  411
# Enqueuing run_analysis rep:  412
# Enqueuing run_analysis rep:  413
# Enqueuing run_analysis rep:  414
# Enqueuing run_analysis rep:  415
# Enqueuing run_analysis rep:  416
# Enqueuing run_analysis rep:  417
# Enqueuing run_analysis rep:  418
# Enqueuing run_analysis rep:  419
# Enqueuing run_analysis rep:  420
# Enqueuing run_analysis rep:  421
# Enqueuing run_analysis rep:  422
# Enqueuing run_analysis rep:  423
# Enqueuing run_analysis rep:  424
# Enqueuing run_analysis rep:  425
# Enqueuing run_analysis rep:  426
# Enqueuing run_analysis rep:  427
# Enqueuing run_analysis rep:  428
# Enqueuing run_analysis rep:  429
# Enqueuing run_analysis rep:  430
# Enqueuing run_analysis rep:  431
# Enqueuing run_analysis rep:  432
# Enqueuing run_analysis rep:  433
# Enqueuing run_analysis rep:  434
# Enqueuing run_analysis rep:  435
# Enqueuing run_analysis rep:  436
# Enqueuing run_analysis rep:  437
# Enqueuing run_analysis rep:  438
# Enqueuing run_analysis rep:  439
# Enqueuing run_analysis rep:  440
# Enqueuing run_analysis rep:  441
# Enqueuing run_analysis rep:  442
# Enqueuing run_analysis rep:  443
# Enqueuing run_analysis rep:  444
# Enqueuing run_analysis rep:  445
# Enqueuing run_analysis rep:  446
# Enqueuing run_analysis rep:  447
# Enqueuing run_analysis rep:  448
# Enqueuing run_analysis rep:  449
# Enqueuing run_analysis rep:  450
# Enqueuing run_analysis rep:  451
# Enqueuing run_analysis rep:  452
# Enqueuing run_analysis rep:  453
# Enqueuing run_analysis rep:  454
# Enqueuing run_analysis rep:  455
# Enqueuing run_analysis rep:  456
# Enqueuing run_analysis rep:  457
# Enqueuing run_analysis rep:  458
# Enqueuing run_analysis rep:  459
# Enqueuing run_analysis rep:  460
# Enqueuing run_analysis rep:  461
# Enqueuing run_analysis rep:  462
# Enqueuing run_analysis rep:  463
# Enqueuing run_analysis rep:  464
# Enqueuing run_analysis rep:  465
# Enqueuing run_analysis rep:  466
# Enqueuing run_analysis rep:  467
# Enqueuing run_analysis rep:  468
# Enqueuing run_analysis rep:  469
# Enqueuing run_analysis rep:  470
# Enqueuing run_analysis rep:  471
# Enqueuing run_analysis rep:  472
# Enqueuing run_analysis rep:  473
# Enqueuing run_analysis rep:  474
# Enqueuing run_analysis rep:  475
# Enqueuing run_analysis rep:  476
# Enqueuing run_analysis rep:  477
# Enqueuing run_analysis rep:  478
# Enqueuing run_analysis rep:  479
# Enqueuing run_analysis rep:  480
# Enqueuing run_analysis rep:  481
# Enqueuing run_analysis rep:  482
# Enqueuing run_analysis rep:  483
# Enqueuing run_analysis rep:  484
# Enqueuing run_analysis rep:  485
# Enqueuing run_analysis rep:  486
# Enqueuing run_analysis rep:  487
# Enqueuing run_analysis rep:  488
# Enqueuing run_analysis rep:  489
# Enqueuing run_analysis rep:  490
# Enqueuing run_analysis rep:  491
# Enqueuing run_analysis rep:  492
# Enqueuing run_analysis rep:  493
# Enqueuing run_analysis rep:  494
# Enqueuing run_analysis rep:  495
# Enqueuing run_analysis rep:  496
# Enqueuing run_analysis rep:  497
# Enqueuing run_analysis rep:  498
# Enqueuing run_analysis rep:  499
# Enqueuing run_analysis rep:  500
# Enqueuing run_analysis rep:  501
# Enqueuing run_analysis rep:  502
# Enqueuing run_analysis rep:  503
# Enqueuing run_analysis rep:  504
# Enqueuing run_analysis rep:  505
# Enqueuing run_analysis rep:  506
# Enqueuing run_analysis rep:  507
# Enqueuing run_analysis rep:  508
# Enqueuing run_analysis rep:  509
# Enqueuing run_analysis rep:  510
# Enqueuing run_analysis rep:  511
# Enqueuing run_analysis rep:  512
# Enqueuing run_analysis rep:  513
# Enqueuing run_analysis rep:  514
# Enqueuing run_analysis rep:  515
# Enqueuing run_analysis rep:  516
# Enqueuing run_analysis rep:  517
# Enqueuing run_analysis rep:  518
# Enqueuing run_analysis rep:  519
# Enqueuing run_analysis rep:  520
# Enqueuing run_analysis rep:  521
# Enqueuing run_analysis rep:  522
# Enqueuing run_analysis rep:  523
# Enqueuing run_analysis rep:  524
# Enqueuing run_analysis rep:  525
# Enqueuing run_analysis rep:  526
# Enqueuing run_analysis rep:  527
# Enqueuing run_analysis rep:  528
# Enqueuing run_analysis rep:  529
# Enqueuing run_analysis rep:  530
# Enqueuing run_analysis rep:  531
# Enqueuing run_analysis rep:  532
# Enqueuing run_analysis rep:  533
# Enqueuing run_analysis rep:  534
# Enqueuing run_analysis rep:  535
# Enqueuing run_analysis rep:  536
# Enqueuing run_analysis rep:  537
# Enqueuing run_analysis rep:  538
# Enqueuing run_analysis rep:  539
# Enqueuing run_analysis rep:  540
# Enqueuing run_analysis rep:  541
# Enqueuing run_analysis rep:  542
# Enqueuing run_analysis rep:  543
# Enqueuing run_analysis rep:  544
# Enqueuing run_analysis rep:  545
# Enqueuing run_analysis rep:  546
# Enqueuing run_analysis rep:  547
# Enqueuing run_analysis rep:  548
# Enqueuing run_analysis rep:  549
# Enqueuing run_analysis rep:  550
# Enqueuing run_analysis rep:  551
# Enqueuing run_analysis rep:  552
# Enqueuing run_analysis rep:  553
# Enqueuing run_analysis rep:  554
# Enqueuing run_analysis rep:  555
# Enqueuing run_analysis rep:  556
# Enqueuing run_analysis rep:  557
# Enqueuing run_analysis rep:  558
# Enqueuing run_analysis rep:  559
# Enqueuing run_analysis rep:  560
# Enqueuing run_analysis rep:  561
# Enqueuing run_analysis rep:  562
# Enqueuing run_analysis rep:  563
# Enqueuing run_analysis rep:  564
# Enqueuing run_analysis rep:  565
# Enqueuing run_analysis rep:  566
# Enqueuing run_analysis rep:  567
# Enqueuing run_analysis rep:  568
# Enqueuing run_analysis rep:  569
# Enqueuing run_analysis rep:  570
# Enqueuing run_analysis rep:  571
# Enqueuing run_analysis rep:  572
# Enqueuing run_analysis rep:  573
# Enqueuing run_analysis rep:  574
# Enqueuing run_analysis rep:  575
# Enqueuing run_analysis rep:  576
# Enqueuing run_analysis rep:  577
# Enqueuing run_analysis rep:  578
# Enqueuing run_analysis rep:  579
# Enqueuing run_analysis rep:  580
# Enqueuing run_analysis rep:  581
# Enqueuing run_analysis rep:  582
# Enqueuing run_analysis rep:  583
# Enqueuing run_analysis rep:  584
# Enqueuing run_analysis rep:  585
# Enqueuing run_analysis rep:  586
# Enqueuing run_analysis rep:  587
# Enqueuing run_analysis rep:  588
# Enqueuing run_analysis rep:  589
# Enqueuing run_analysis rep:  590
# Enqueuing run_analysis rep:  591
# Enqueuing run_analysis rep:  592
# Enqueuing run_analysis rep:  593
# Enqueuing run_analysis rep:  594
# Enqueuing run_analysis rep:  595
# Enqueuing run_analysis rep:  596
# Enqueuing run_analysis rep:  597
# Enqueuing run_analysis rep:  598
# Enqueuing run_analysis rep:  599
# Enqueuing run_analysis rep:  600
# Enqueuing run_analysis rep:  601
# Enqueuing run_analysis rep:  602
# Enqueuing run_analysis rep:  603
# Enqueuing run_analysis rep:  604
# Enqueuing run_analysis rep:  605
# Enqueuing run_analysis rep:  606
# Enqueuing run_analysis rep:  607
# Enqueuing run_analysis rep:  608
# Enqueuing run_analysis rep:  609
# Enqueuing run_analysis rep:  610
# Enqueuing run_analysis rep:  611
# Enqueuing run_analysis rep:  612
# Enqueuing run_analysis rep:  613
# Enqueuing run_analysis rep:  614
# Enqueuing run_analysis rep:  615
# Enqueuing run_analysis rep:  616
# Enqueuing run_analysis rep:  617
# Enqueuing run_analysis rep:  618
# Enqueuing run_analysis rep:  619
# Enqueuing run_analysis rep:  620
# Enqueuing run_analysis rep:  621
# Enqueuing run_analysis rep:  622
# Enqueuing run_analysis rep:  623
# Enqueuing run_analysis rep:  624
# Enqueuing run_analysis rep:  625
# Enqueuing run_analysis rep:  626
# Enqueuing run_analysis rep:  627
# Enqueuing run_analysis rep:  628
# Enqueuing run_analysis rep:  629
# Enqueuing run_analysis rep:  630
# Enqueuing run_analysis rep:  631
# Enqueuing run_analysis rep:  632
# Enqueuing run_analysis rep:  633
# Enqueuing run_analysis rep:  634
# Enqueuing run_analysis rep:  635
# Enqueuing run_analysis rep:  636
# Enqueuing run_analysis rep:  637
# Enqueuing run_analysis rep:  638
# Enqueuing run_analysis rep:  639
# Enqueuing run_analysis rep:  640
# Enqueuing run_analysis rep:  641
# Enqueuing run_analysis rep:  642
# Enqueuing run_analysis rep:  643
# Enqueuing run_analysis rep:  644
# Enqueuing run_analysis rep:  645
# Enqueuing run_analysis rep:  646
# Enqueuing run_analysis rep:  647
# Enqueuing run_analysis rep:  648
# Enqueuing run_analysis rep:  649
# Enqueuing run_analysis rep:  650
# Enqueuing run_analysis rep:  651
# Enqueuing run_analysis rep:  652
# Enqueuing run_analysis rep:  653
# Enqueuing run_analysis rep:  654
# Enqueuing run_analysis rep:  655
# Enqueuing run_analysis rep:  656
# Enqueuing run_analysis rep:  657
# Enqueuing run_analysis rep:  658
# Enqueuing run_analysis rep:  659
# Enqueuing run_analysis rep:  660
# Enqueuing run_analysis rep:  661
# Enqueuing run_analysis rep:  662
# Enqueuing run_analysis rep:  663
# Enqueuing run_analysis rep:  664
# Enqueuing run_analysis rep:  665
# Enqueuing run_analysis rep:  666
# Enqueuing run_analysis rep:  667
# Enqueuing run_analysis rep:  668
# Enqueuing run_analysis rep:  669
# Enqueuing run_analysis rep:  670
# Enqueuing run_analysis rep:  671
# Enqueuing run_analysis rep:  672
# Enqueuing run_analysis rep:  673
# Enqueuing run_analysis rep:  674
# Enqueuing run_analysis rep:  675
# Enqueuing run_analysis rep:  676
# Enqueuing run_analysis rep:  677
# Enqueuing run_analysis rep:  678
# Enqueuing run_analysis rep:  679
# Enqueuing run_analysis rep:  680
# Enqueuing run_analysis rep:  681
# Enqueuing run_analysis rep:  682
# Enqueuing run_analysis rep:  683
# Enqueuing run_analysis rep:  684
# Enqueuing run_analysis rep:  685
# Enqueuing run_analysis rep:  686
# Enqueuing run_analysis rep:  687
# Enqueuing run_analysis rep:  688
# Enqueuing run_analysis rep:  689
# Enqueuing run_analysis rep:  690
# Enqueuing run_analysis rep:  691
# Enqueuing run_analysis rep:  692
# Enqueuing run_analysis rep:  693
# Enqueuing run_analysis rep:  694
# Enqueuing run_analysis rep:  695
# Enqueuing run_analysis rep:  696
# Enqueuing run_analysis rep:  697
# Enqueuing run_analysis rep:  698
# Enqueuing run_analysis rep:  699
# Enqueuing run_analysis rep:  700
# Enqueuing run_analysis rep:  701
# Enqueuing run_analysis rep:  702
# Enqueuing run_analysis rep:  703
# Enqueuing run_analysis rep:  704
# Enqueuing run_analysis rep:  705
# Enqueuing run_analysis rep:  706
# Enqueuing run_analysis rep:  707
# Enqueuing run_analysis rep:  708
# Enqueuing run_analysis rep:  709
# Enqueuing run_analysis rep:  710
# Enqueuing run_analysis rep:  711
# Enqueuing run_analysis rep:  712
# Enqueuing run_analysis rep:  713
# Enqueuing run_analysis rep:  714
# Enqueuing run_analysis rep:  715
# Enqueuing run_analysis rep:  716
# Enqueuing run_analysis rep:  717
# Enqueuing run_analysis rep:  718
# Enqueuing run_analysis rep:  719
# Enqueuing run_analysis rep:  720
# Enqueuing run_analysis rep:  721
# Enqueuing run_analysis rep:  722
# Enqueuing run_analysis rep:  723
# Enqueuing run_analysis rep:  724
# Enqueuing run_analysis rep:  725
# Enqueuing run_analysis rep:  726
# Enqueuing run_analysis rep:  727
# Enqueuing run_analysis rep:  728
# Enqueuing run_analysis rep:  729
# Enqueuing run_analysis rep:  730
# Enqueuing run_analysis rep:  731
# Enqueuing run_analysis rep:  732
# Enqueuing run_analysis rep:  733
# Enqueuing run_analysis rep:  734
# Enqueuing run_analysis rep:  735
# Enqueuing run_analysis rep:  736
# Enqueuing run_analysis rep:  737
# Enqueuing run_analysis rep:  738
# Enqueuing run_analysis rep:  739
# Enqueuing run_analysis rep:  740
# Enqueuing run_analysis rep:  741
# Enqueuing run_analysis rep:  742
# Enqueuing run_analysis rep:  743
# Enqueuing run_analysis rep:  744
# Enqueuing run_analysis rep:  745
# Enqueuing run_analysis rep:  746
# Enqueuing run_analysis rep:  747
# Enqueuing run_analysis rep:  748
# Enqueuing run_analysis rep:  749
# Enqueuing run_analysis rep:  750
# Enqueuing run_analysis rep:  751
# Enqueuing run_analysis rep:  752
# Enqueuing run_analysis rep:  753
# Enqueuing run_analysis rep:  754
# Enqueuing run_analysis rep:  755
# Enqueuing run_analysis rep:  756
# Enqueuing run_analysis rep:  757
# Enqueuing run_analysis rep:  758
# Enqueuing run_analysis rep:  759
# Enqueuing run_analysis rep:  760
# Enqueuing run_analysis rep:  761
# Enqueuing run_analysis rep:  762
# Enqueuing run_analysis rep:  763
# Enqueuing run_analysis rep:  764
# Enqueuing run_analysis rep:  765
# Enqueuing run_analysis rep:  766
# Enqueuing run_analysis rep:  767
# Enqueuing run_analysis rep:  768
# Enqueuing run_analysis rep:  769
# Enqueuing run_analysis rep:  770
# Enqueuing run_analysis rep:  771
# Enqueuing run_analysis rep:  772
# Enqueuing run_analysis rep:  773
# Enqueuing run_analysis rep:  774
# Enqueuing run_analysis rep:  775
# Enqueuing run_analysis rep:  776
# Enqueuing run_analysis rep:  777
# Enqueuing run_analysis rep:  778
# Enqueuing run_analysis rep:  779
# Enqueuing run_analysis rep:  780
# Enqueuing run_analysis rep:  781
# Enqueuing run_analysis rep:  782
# Enqueuing run_analysis rep:  783
# Enqueuing run_analysis rep:  784
# Enqueuing run_analysis rep:  785
# Enqueuing run_analysis rep:  786
# Enqueuing run_analysis rep:  787
# Enqueuing run_analysis rep:  788
# Enqueuing run_analysis rep:  789
# Enqueuing run_analysis rep:  790
# Enqueuing run_analysis rep:  791
# Enqueuing run_analysis rep:  792
# Enqueuing run_analysis rep:  793
# Enqueuing run_analysis rep:  794
# Enqueuing run_analysis rep:  795
# Enqueuing run_analysis rep:  796
# Enqueuing run_analysis rep:  797
# Enqueuing run_analysis rep:  798
# Enqueuing run_analysis rep:  799
# Enqueuing run_analysis rep:  800
# Enqueuing run_analysis rep:  801
# Enqueuing run_analysis rep:  802
# Enqueuing run_analysis rep:  803
# Enqueuing run_analysis rep:  804
# Enqueuing run_analysis rep:  805
# Enqueuing run_analysis rep:  806
# Enqueuing run_analysis rep:  807
# Enqueuing run_analysis rep:  808
# Enqueuing run_analysis rep:  809
# Enqueuing run_analysis rep:  810
# Enqueuing run_analysis rep:  811
# Enqueuing run_analysis rep:  812
# Enqueuing run_analysis rep:  813
# Enqueuing run_analysis rep:  814
# Enqueuing run_analysis rep:  815
# Enqueuing run_analysis rep:  816
# Enqueuing run_analysis rep:  817
# Enqueuing run_analysis rep:  818
# Enqueuing run_analysis rep:  819
# Enqueuing run_analysis rep:  820
# Enqueuing run_analysis rep:  821
# Enqueuing run_analysis rep:  822
# Enqueuing run_analysis rep:  823
# Enqueuing run_analysis rep:  824
# Enqueuing run_analysis rep:  825
# Enqueuing run_analysis rep:  826
# Enqueuing run_analysis rep:  827
# Enqueuing run_analysis rep:  828
# Enqueuing run_analysis rep:  829
# Enqueuing run_analysis rep:  830
# Enqueuing run_analysis rep:  831
# Enqueuing run_analysis rep:  832
# Enqueuing run_analysis rep:  833
# Enqueuing run_analysis rep:  834
# Enqueuing run_analysis rep:  835
# Enqueuing run_analysis rep:  836
# Enqueuing run_analysis rep:  837
# Enqueuing run_analysis rep:  838
# Enqueuing run_analysis rep:  839
# Enqueuing run_analysis rep:  840
# Enqueuing run_analysis rep:  841
# Enqueuing run_analysis rep:  842
# Enqueuing run_analysis rep:  843
# Enqueuing run_analysis rep:  844
# Enqueuing run_analysis rep:  845
# Enqueuing run_analysis rep:  846
# Enqueuing run_analysis rep:  847
# Enqueuing run_analysis rep:  848
# Enqueuing run_analysis rep:  849
# Enqueuing run_analysis rep:  850
# Enqueuing run_analysis rep:  851
# Enqueuing run_analysis rep:  852
# Enqueuing run_analysis rep:  853
# Enqueuing run_analysis rep:  854
# Enqueuing run_analysis rep:  855
# Enqueuing run_analysis rep:  856
# Enqueuing run_analysis rep:  857
# Enqueuing run_analysis rep:  858
# Enqueuing run_analysis rep:  859
# Enqueuing run_analysis rep:  860
# Enqueuing run_analysis rep:  861
# Enqueuing run_analysis rep:  862
# Enqueuing run_analysis rep:  863
# Enqueuing run_analysis rep:  864
# Enqueuing run_analysis rep:  865
# Enqueuing run_analysis rep:  866
# Enqueuing run_analysis rep:  867
# Enqueuing run_analysis rep:  868
# Enqueuing run_analysis rep:  869
# Enqueuing run_analysis rep:  870
# Enqueuing run_analysis rep:  871
# Enqueuing run_analysis rep:  872
# Enqueuing run_analysis rep:  873
# Enqueuing run_analysis rep:  874
# Enqueuing run_analysis rep:  875
# Enqueuing run_analysis rep:  876
# Enqueuing run_analysis rep:  877
# Enqueuing run_analysis rep:  878
# Enqueuing run_analysis rep:  879
# Enqueuing run_analysis rep:  880
# Enqueuing run_analysis rep:  881
# Enqueuing run_analysis rep:  882
# Enqueuing run_analysis rep:  883
# Enqueuing run_analysis rep:  884
# Enqueuing run_analysis rep:  885
# Enqueuing run_analysis rep:  886
# Enqueuing run_analysis rep:  887
# Enqueuing run_analysis rep:  888
# Enqueuing run_analysis rep:  889
# Enqueuing run_analysis rep:  890
# Enqueuing run_analysis rep:  891
# Enqueuing run_analysis rep:  892
# Enqueuing run_analysis rep:  893
# Enqueuing run_analysis rep:  894
# Enqueuing run_analysis rep:  895
# Enqueuing run_analysis rep:  896
# Enqueuing run_analysis rep:  897
# Enqueuing run_analysis rep:  898
# Enqueuing run_analysis rep:  899
# Enqueuing run_analysis rep:  900
# Enqueuing run_analysis rep:  901
# Enqueuing run_analysis rep:  902
# Enqueuing run_analysis rep:  903
# Enqueuing run_analysis rep:  904
# Enqueuing run_analysis rep:  905
# Enqueuing run_analysis rep:  906
# Enqueuing run_analysis rep:  907
# Enqueuing run_analysis rep:  908
# Enqueuing run_analysis rep:  909
# Enqueuing run_analysis rep:  910
# Enqueuing run_analysis rep:  911
# Enqueuing run_analysis rep:  912
# Enqueuing run_analysis rep:  913
# Enqueuing run_analysis rep:  914
# Enqueuing run_analysis rep:  915
# Enqueuing run_analysis rep:  916
# Enqueuing run_analysis rep:  917
# Enqueuing run_analysis rep:  918
# Enqueuing run_analysis rep:  919
# Enqueuing run_analysis rep:  920
# Enqueuing run_analysis rep:  921
# Enqueuing run_analysis rep:  922
# Enqueuing run_analysis rep:  923
# Enqueuing run_analysis rep:  924
# Enqueuing run_analysis rep:  925
# Enqueuing run_analysis rep:  926
# Enqueuing run_analysis rep:  927
# Enqueuing run_analysis rep:  928
# Enqueuing run_analysis rep:  929
# Enqueuing run_analysis rep:  930
# Enqueuing run_analysis rep:  931
# Enqueuing run_analysis rep:  932
# Enqueuing run_analysis rep:  933
# Enqueuing run_analysis rep:  934
# Enqueuing run_analysis rep:  935
# Enqueuing run_analysis rep:  936
# Enqueuing run_analysis rep:  937
# Enqueuing run_analysis rep:  938
# Enqueuing run_analysis rep:  939
# Enqueuing run_analysis rep:  940
# Enqueuing run_analysis rep:  941
# Enqueuing run_analysis rep:  942
# Enqueuing run_analysis rep:  943
# Enqueuing run_analysis rep:  944
# Enqueuing run_analysis rep:  945
# Enqueuing run_analysis rep:  946
# Enqueuing run_analysis rep:  947
# Enqueuing run_analysis rep:  948
# Enqueuing run_analysis rep:  949
# Enqueuing run_analysis rep:  950
# Enqueuing run_analysis rep:  951
# Enqueuing run_analysis rep:  952
# Enqueuing run_analysis rep:  953
# Enqueuing run_analysis rep:  954
# Enqueuing run_analysis rep:  955
# Enqueuing run_analysis rep:  956
# Enqueuing run_analysis rep:  957
# Enqueuing run_analysis rep:  958
# Enqueuing run_analysis rep:  959
# Enqueuing run_analysis rep:  960
# Enqueuing run_analysis rep:  961
# Enqueuing run_analysis rep:  962
# Enqueuing run_analysis rep:  963
# Enqueuing run_analysis rep:  964
# Enqueuing run_analysis rep:  965
# Enqueuing run_analysis rep:  966
# Enqueuing run_analysis rep:  967
# Enqueuing run_analysis rep:  968
# Enqueuing run_analysis rep:  969
# Enqueuing run_analysis rep:  970
# Enqueuing run_analysis rep:  971
# Enqueuing run_analysis rep:  972
# Enqueuing run_analysis rep:  973
# Enqueuing run_analysis rep:  974
# Enqueuing run_analysis rep:  975
# Enqueuing run_analysis rep:  976
# Enqueuing run_analysis rep:  977
# Enqueuing run_analysis rep:  978
# Enqueuing run_analysis rep:  979
# Enqueuing run_analysis rep:  980
# Enqueuing run_analysis rep:  981
# Enqueuing run_analysis rep:  982
# Enqueuing run_analysis rep:  983
# Enqueuing run_analysis rep:  984
# Enqueuing run_analysis rep:  985
# Enqueuing run_analysis rep:  986
# Enqueuing run_analysis rep:  987
# Enqueuing run_analysis rep:  988
# Enqueuing run_analysis rep:  989
# Enqueuing run_analysis rep:  990
# Enqueuing run_analysis rep:  991
# Enqueuing run_analysis rep:  992
# Enqueuing run_analysis rep:  993
# Enqueuing run_analysis rep:  994
# Enqueuing run_analysis rep:  995
# Enqueuing run_analysis rep:  996
# Enqueuing run_analysis rep:  997
# Enqueuing run_analysis rep:  998
# Enqueuing run_analysis rep:  999
# Enqueuing run_analysis rep:  1000
# Enqueuing run_analysis rep:  1001
# Enqueuing run_analysis rep:  1002
# Enqueuing run_analysis rep:  1003
# Enqueuing run_analysis rep:  1004
# Enqueuing run_analysis rep:  1005
# Enqueuing run_analysis rep:  1006
# Enqueuing run_analysis rep:  1007
# Enqueuing run_analysis rep:  1008
# Enqueuing run_analysis rep:  1009
# Enqueuing run_analysis rep:  1010
# Enqueuing run_analysis rep:  1011
# Enqueuing run_analysis rep:  1012
# Enqueuing run_analysis rep:  1013
# Enqueuing run_analysis rep:  1014
# Enqueuing run_analysis rep:  1015
# Enqueuing run_analysis rep:  1016
# Enqueuing run_analysis rep:  1017
# Enqueuing run_analysis rep:  1018
# Enqueuing run_analysis rep:  1019
# Enqueuing run_analysis rep:  1020
# Enqueuing run_analysis rep:  1021
# Enqueuing run_analysis rep:  1022
# Enqueuing run_analysis rep:  1023
# Enqueuing run_analysis rep:  1024
# Enqueuing run_analysis rep:  1025
# Enqueuing run_analysis rep:  1026
# Enqueuing run_analysis rep:  1027
# Enqueuing run_analysis rep:  1028
# Enqueuing run_analysis rep:  1029
# Enqueuing run_analysis rep:  1030
# Enqueuing run_analysis rep:  1031
# Enqueuing run_analysis rep:  1032
# Enqueuing run_analysis rep:  1033
# Enqueuing run_analysis rep:  1034
# Enqueuing run_analysis rep:  1035
# Enqueuing run_analysis rep:  1036
# Enqueuing run_analysis rep:  1037
# Enqueuing run_analysis rep:  1038
# Enqueuing run_analysis rep:  1039
# Enqueuing run_analysis rep:  1040
# Enqueuing run_analysis rep:  1041
# Enqueuing run_analysis rep:  1042
# Enqueuing run_analysis rep:  1043
# Enqueuing run_analysis rep:  1044
# Enqueuing run_analysis rep:  1045
# Enqueuing run_analysis rep:  1046
# Enqueuing run_analysis rep:  1047
# Enqueuing run_analysis rep:  1048
# Enqueuing run_analysis rep:  1049
# Enqueuing run_analysis rep:  1050
# Enqueuing run_analysis rep:  1051
# Enqueuing run_analysis rep:  1052
# Enqueuing run_analysis rep:  1053
# Enqueuing run_analysis rep:  1054
# Enqueuing run_analysis rep:  1055
# Enqueuing run_analysis rep:  1056
# Enqueuing run_analysis rep:  1057
# Enqueuing run_analysis rep:  1058
# Enqueuing run_analysis rep:  1059
# Enqueuing run_analysis rep:  1060
# Enqueuing run_analysis rep:  1061
# Enqueuing run_analysis rep:  1062
# Enqueuing run_analysis rep:  1063
# Enqueuing run_analysis rep:  1064
# Enqueuing run_analysis rep:  1065
# Enqueuing run_analysis rep:  1066
# Enqueuing run_analysis rep:  1067
# Enqueuing run_analysis rep:  1068
# Enqueuing run_analysis rep:  1069
# Enqueuing run_analysis rep:  1070
# Enqueuing run_analysis rep:  1071
# Enqueuing run_analysis rep:  1072
# Enqueuing run_analysis rep:  1073
# Enqueuing run_analysis rep:  1074
# Enqueuing run_analysis rep:  1075
# Enqueuing run_analysis rep:  1076
# Enqueuing run_analysis rep:  1077
# Enqueuing run_analysis rep:  1078
# Enqueuing run_analysis rep:  1079
# Enqueuing run_analysis rep:  1080
# Enqueuing run_analysis rep:  1081
# Enqueuing run_analysis rep:  1082
# Enqueuing run_analysis rep:  1083
# Enqueuing run_analysis rep:  1084
# Enqueuing run_analysis rep:  1085
# Enqueuing run_analysis rep:  1086
# Enqueuing run_analysis rep:  1087
# Enqueuing run_analysis rep:  1088
# Enqueuing run_analysis rep:  1089
# Enqueuing run_analysis rep:  1090
# Enqueuing run_analysis rep:  1091
# Enqueuing run_analysis rep:  1092
# Enqueuing run_analysis rep:  1093
# Enqueuing run_analysis rep:  1094
# Enqueuing run_analysis rep:  1095
# Enqueuing run_analysis rep:  1096
# Enqueuing run_analysis rep:  1097
# Enqueuing run_analysis rep:  1098
# Enqueuing run_analysis rep:  1099
# Enqueuing run_analysis rep:  1100
# Enqueuing run_analysis rep:  1101
# Enqueuing run_analysis rep:  1102
# Enqueuing run_analysis rep:  1103
# Enqueuing run_analysis rep:  1104
# Enqueuing run_analysis rep:  1105
# Enqueuing run_analysis rep:  1106
# Enqueuing run_analysis rep:  1107
# Enqueuing run_analysis rep:  1108
# Enqueuing run_analysis rep:  1109
# Enqueuing run_analysis rep:  1110
# Enqueuing run_analysis rep:  1111
# Enqueuing run_analysis rep:  1112
# Enqueuing run_analysis rep:  1113
# Enqueuing run_analysis rep:  1114
# Enqueuing run_analysis rep:  1115
# Enqueuing run_analysis rep:  1116
# Enqueuing run_analysis rep:  1117
# Enqueuing run_analysis rep:  1118
# Enqueuing run_analysis rep:  1119
# Enqueuing run_analysis rep:  1120
# Enqueuing run_analysis rep:  1121
# Enqueuing run_analysis rep:  1122
# Enqueuing run_analysis rep:  1123
# Enqueuing run_analysis rep:  1124
# Enqueuing run_analysis rep:  1125
# Enqueuing run_analysis rep:  1126
# Enqueuing run_analysis rep:  1127
# Enqueuing run_analysis rep:  1128
# Enqueuing run_analysis rep:  1129
# Enqueuing run_analysis rep:  1130
# Enqueuing run_analysis rep:  1131
# Enqueuing run_analysis rep:  1132
# Enqueuing run_analysis rep:  1133
# Enqueuing run_analysis rep:  1134
# Enqueuing run_analysis rep:  1135
# Enqueuing run_analysis rep:  1136
# Enqueuing run_analysis rep:  1137
# Enqueuing run_analysis rep:  1138
# Enqueuing run_analysis rep:  1139
# Enqueuing run_analysis rep:  1140
# Enqueuing run_analysis rep:  1141
# Enqueuing run_analysis rep:  1142
# Enqueuing run_analysis rep:  1143
# Enqueuing run_analysis rep:  1144
# Enqueuing run_analysis rep:  1145
# Enqueuing run_analysis rep:  1146
# Enqueuing run_analysis rep:  1147
# Enqueuing run_analysis rep:  1148
# Enqueuing run_analysis rep:  1149
# Enqueuing run_analysis rep:  1150
# Enqueuing run_analysis rep:  1151
# Enqueuing run_analysis rep:  1152
# Enqueuing run_analysis rep:  1153
# Enqueuing run_analysis rep:  1154
# Enqueuing run_analysis rep:  1155
# Enqueuing run_analysis rep:  1156
# Enqueuing run_analysis rep:  1157
# Enqueuing run_analysis rep:  1158
# Enqueuing run_analysis rep:  1159
# Enqueuing run_analysis rep:  1160
# Enqueuing run_analysis rep:  1161
# Enqueuing run_analysis rep:  1162
# Enqueuing run_analysis rep:  1163
# Enqueuing run_analysis rep:  1164
# Enqueuing run_analysis rep:  1165
# Enqueuing run_analysis rep:  1166
# Enqueuing run_analysis rep:  1167
# Enqueuing run_analysis rep:  1168
# Enqueuing run_analysis rep:  1169
# Enqueuing run_analysis rep:  1170
# Enqueuing run_analysis rep:  1171
# Enqueuing run_analysis rep:  1172
# Enqueuing run_analysis rep:  1173
# Enqueuing run_analysis rep:  1174
# Enqueuing run_analysis rep:  1175
# Enqueuing run_analysis rep:  1176
# Enqueuing run_analysis rep:  1177
# Enqueuing run_analysis rep:  1178
# Enqueuing run_analysis rep:  1179
# Enqueuing run_analysis rep:  1180
# Enqueuing run_analysis rep:  1181
# Enqueuing run_analysis rep:  1182
# Enqueuing run_analysis rep:  1183
# Enqueuing run_analysis rep:  1184
# Enqueuing run_analysis rep:  1185
# Enqueuing run_analysis rep:  1186
# Enqueuing run_analysis rep:  1187
# Enqueuing run_analysis rep:  1188
# Enqueuing run_analysis rep:  1189
# Enqueuing run_analysis rep:  1190
# Enqueuing run_analysis rep:  1191
# Enqueuing run_analysis rep:  1192
# Enqueuing run_analysis rep:  1193
# Enqueuing run_analysis rep:  1194
# Enqueuing run_analysis rep:  1195
# Enqueuing run_analysis rep:  1196
# Enqueuing run_analysis rep:  1197
# Enqueuing run_analysis rep:  1198
# Enqueuing run_analysis rep:  1199
# Enqueuing run_analysis rep:  1200
# Enqueuing run_analysis rep:  1201
# Enqueuing run_analysis rep:  1202
# Enqueuing run_analysis rep:  1203
# Enqueuing run_analysis rep:  1204
# Enqueuing run_analysis rep:  1205
# Enqueuing run_analysis rep:  1206
# Enqueuing run_analysis rep:  1207
# Enqueuing run_analysis rep:  1208
# Enqueuing run_analysis rep:  1209
# Enqueuing run_analysis rep:  1210
# Enqueuing run_analysis rep:  1211
# Enqueuing run_analysis rep:  1212
# Enqueuing run_analysis rep:  1213
# Enqueuing run_analysis rep:  1214
# Enqueuing run_analysis rep:  1215
# Enqueuing run_analysis rep:  1216
# Enqueuing run_analysis rep:  1217
# Enqueuing run_analysis rep:  1218
# Enqueuing run_analysis rep:  1219
# Enqueuing run_analysis rep:  1220
# Enqueuing run_analysis rep:  1221
# Enqueuing run_analysis rep:  1222
# Enqueuing run_analysis rep:  1223
# Enqueuing run_analysis rep:  1224
# Enqueuing run_analysis rep:  1225
# Enqueuing run_analysis rep:  1226
# Enqueuing run_analysis rep:  1227
# Enqueuing run_analysis rep:  1228
# Enqueuing run_analysis rep:  1229
# Enqueuing run_analysis rep:  1230
# Enqueuing run_analysis rep:  1231
# Enqueuing run_analysis rep:  1232
# Enqueuing run_analysis rep:  1233
# Enqueuing run_analysis rep:  1234
# Enqueuing run_analysis rep:  1235
# Enqueuing run_analysis rep:  1236
# Enqueuing run_analysis rep:  1237
# Enqueuing run_analysis rep:  1238
# Enqueuing run_analysis rep:  1239
# Enqueuing run_analysis rep:  1240
# Enqueuing run_analysis rep:  1241
# Enqueuing run_analysis rep:  1242
# Enqueuing run_analysis rep:  1243
# Enqueuing run_analysis rep:  1244
# Enqueuing run_analysis rep:  1245
# Enqueuing run_analysis rep:  1246
# Enqueuing run_analysis rep:  1247
# Enqueuing run_analysis rep:  1248
# Enqueuing run_analysis rep:  1249
# Enqueuing run_analysis rep:  1250
# Enqueuing run_analysis rep:  1251
# Enqueuing run_analysis rep:  1252
# Enqueuing run_analysis rep:  1253
# Enqueuing run_analysis rep:  1254
# Enqueuing run_analysis rep:  1255
# Enqueuing run_analysis rep:  1256
# Enqueuing run_analysis rep:  1257
# Enqueuing run_analysis rep:  1258
# Enqueuing run_analysis rep:  1259
# Enqueuing run_analysis rep:  1260
# Enqueuing run_analysis rep:  1261
# Enqueuing run_analysis rep:  1262
# Enqueuing run_analysis rep:  1263
# Enqueuing run_analysis rep:  1264
# Enqueuing run_analysis rep:  1265
# Enqueuing run_analysis rep:  1266
# Enqueuing run_analysis rep:  1267
# Enqueuing run_analysis rep:  1268
# Enqueuing run_analysis rep:  1269
# Enqueuing run_analysis rep:  1270
# Enqueuing run_analysis rep:  1271
# Enqueuing run_analysis rep:  1272
# Enqueuing run_analysis rep:  1273
# Enqueuing run_analysis rep:  1274
# Enqueuing run_analysis rep:  1275
# Enqueuing run_analysis rep:  1276
# Enqueuing run_analysis rep:  1277
# Enqueuing run_analysis rep:  1278
# Enqueuing run_analysis rep:  1279
# Enqueuing run_analysis rep:  1280
# Enqueuing run_analysis rep:  1281
# Enqueuing run_analysis rep:  1282
# Enqueuing run_analysis rep:  1283
# Enqueuing run_analysis rep:  1284
# Enqueuing run_analysis rep:  1285
# Enqueuing run_analysis rep:  1286
# Enqueuing run_analysis rep:  1287
# Enqueuing run_analysis rep:  1288
# Enqueuing run_analysis rep:  1289
# Enqueuing run_analysis rep:  1290
# Enqueuing run_analysis rep:  1291
# Enqueuing run_analysis rep:  1292
# Enqueuing run_analysis rep:  1293
# Enqueuing run_analysis rep:  1294
# Enqueuing run_analysis rep:  1295
# Enqueuing run_analysis rep:  1296
# Enqueuing run_analysis rep:  1297
# Enqueuing run_analysis rep:  1298
# Enqueuing run_analysis rep:  1299
# Enqueuing run_analysis rep:  1300
# Enqueuing run_analysis rep:  1301
# Enqueuing run_analysis rep:  1302
# Enqueuing run_analysis rep:  1303
# Enqueuing run_analysis rep:  1304
# Enqueuing run_analysis rep:  1305
# Enqueuing run_analysis rep:  1306
# Enqueuing run_analysis rep:  1307
# Enqueuing run_analysis rep:  1308
# Enqueuing run_analysis rep:  1309
# Enqueuing run_analysis rep:  1310
# Enqueuing run_analysis rep:  1311
# Enqueuing run_analysis rep:  1312
# Enqueuing run_analysis rep:  1313
# Enqueuing run_analysis rep:  1314
# Enqueuing run_analysis rep:  1315
# Enqueuing run_analysis rep:  1316
# Enqueuing run_analysis rep:  1317
# Enqueuing run_analysis rep:  1318
# Enqueuing run_analysis rep:  1319
# Enqueuing run_analysis rep:  1320
# Enqueuing run_analysis rep:  1321
# Enqueuing run_analysis rep:  1322
# Enqueuing run_analysis rep:  1323
# Enqueuing run_analysis rep:  1324
# Enqueuing run_analysis rep:  1325
# Enqueuing run_analysis rep:  1326
# Enqueuing run_analysis rep:  1327
# Enqueuing run_analysis rep:  1328
# Enqueuing run_analysis rep:  1329
# Enqueuing run_analysis rep:  1330
# Enqueuing run_analysis rep:  1331
# Enqueuing run_analysis rep:  1332
# Enqueuing run_analysis rep:  1333
# Enqueuing run_analysis rep:  1334
# Enqueuing run_analysis rep:  1335
# Enqueuing run_analysis rep:  1336
# Enqueuing run_analysis rep:  1337
# Enqueuing run_analysis rep:  1338
# Enqueuing run_analysis rep:  1339
# Enqueuing run_analysis rep:  1340
# Enqueuing run_analysis rep:  1341
# Enqueuing run_analysis rep:  1342
# Enqueuing run_analysis rep:  1343
# Enqueuing run_analysis rep:  1344
# Enqueuing run_analysis rep:  1345
# Enqueuing run_analysis rep:  1346
# Enqueuing run_analysis rep:  1347
# Enqueuing run_analysis rep:  1348
# Enqueuing run_analysis rep:  1349
# Enqueuing run_analysis rep:  1350
# Enqueuing run_analysis rep:  1351
# Enqueuing run_analysis rep:  1352
# Enqueuing run_analysis rep:  1353
# Enqueuing run_analysis rep:  1354
# Enqueuing run_analysis rep:  1355
# Enqueuing run_analysis rep:  1356
# Enqueuing run_analysis rep:  1357
# Enqueuing run_analysis rep:  1358
# Enqueuing run_analysis rep:  1359
# Enqueuing run_analysis rep:  1360
# Enqueuing run_analysis rep:  1361
# Enqueuing run_analysis rep:  1362
# Enqueuing run_analysis rep:  1363
# Enqueuing run_analysis rep:  1364
# Enqueuing run_analysis rep:  1365
# Enqueuing run_analysis rep:  1366
# Enqueuing run_analysis rep:  1367
# Enqueuing run_analysis rep:  1368
# Enqueuing run_analysis rep:  1369
# Enqueuing run_analysis rep:  1370
# Enqueuing run_analysis rep:  1371
# Enqueuing run_analysis rep:  1372
# Enqueuing run_analysis rep:  1373
# Enqueuing run_analysis rep:  1374
# Enqueuing run_analysis rep:  1375
# Enqueuing run_analysis rep:  1376
# Enqueuing run_analysis rep:  1377
# Enqueuing run_analysis rep:  1378
# Enqueuing run_analysis rep:  1379
# Enqueuing run_analysis rep:  1380
# Enqueuing run_analysis rep:  1381
# Enqueuing run_analysis rep:  1382
# Enqueuing run_analysis rep:  1383
# Enqueuing run_analysis rep:  1384
# Enqueuing run_analysis rep:  1385
# Enqueuing run_analysis rep:  1386
# Enqueuing run_analysis rep:  1387
# Enqueuing run_analysis rep:  1388
# Enqueuing run_analysis rep:  1389
# Enqueuing run_analysis rep:  1390
# Enqueuing run_analysis rep:  1391
# Enqueuing run_analysis rep:  1392
# Enqueuing run_analysis rep:  1393
# Enqueuing run_analysis rep:  1394
# Enqueuing run_analysis rep:  1395
# Enqueuing run_analysis rep:  1396
# Enqueuing run_analysis rep:  1397
# Enqueuing run_analysis rep:  1398
# Enqueuing run_analysis rep:  1399
# Enqueuing run_analysis rep:  1400
# Enqueuing run_analysis rep:  1401
# Enqueuing run_analysis rep:  1402
# Enqueuing run_analysis rep:  1403
# Enqueuing run_analysis rep:  1404
# Enqueuing run_analysis rep:  1405
# Enqueuing run_analysis rep:  1406
# Enqueuing run_analysis rep:  1407
# Enqueuing run_analysis rep:  1408
# Enqueuing run_analysis rep:  1409
# Enqueuing run_analysis rep:  1410
# Enqueuing run_analysis rep:  1411
# Enqueuing run_analysis rep:  1412
# Enqueuing run_analysis rep:  1413
# Enqueuing run_analysis rep:  1414
# Enqueuing run_analysis rep:  1415
# Enqueuing run_analysis rep:  1416
# Enqueuing run_analysis rep:  1417
# Enqueuing run_analysis rep:  1418
# Enqueuing run_analysis rep:  1419
# Enqueuing run_analysis rep:  1420
# Enqueuing run_analysis rep:  1421
# Enqueuing run_analysis rep:  1422
# Enqueuing run_analysis rep:  1423
# Enqueuing run_analysis rep:  1424
# Enqueuing run_analysis rep:  1425
# Enqueuing run_analysis rep:  1426
# Enqueuing run_analysis rep:  1427
# Enqueuing run_analysis rep:  1428
# Enqueuing run_analysis rep:  1429
# Enqueuing run_analysis rep:  1430
# Enqueuing run_analysis rep:  1431
# Enqueuing run_analysis rep:  1432
# Enqueuing run_analysis rep:  1433
# Enqueuing run_analysis rep:  1434
# Enqueuing run_analysis rep:  1435
# Enqueuing run_analysis rep:  1436
# Enqueuing run_analysis rep:  1437
# Enqueuing run_analysis rep:  1438
# Enqueuing run_analysis rep:  1439
# Enqueuing run_analysis rep:  1440
# Enqueuing run_analysis rep:  1441
# Enqueuing run_analysis rep:  1442
# Enqueuing run_analysis rep:  1443
# ...
# Rep completed : 9242
# Rep completed : 9243
# Rep completed : 9244
# Rep completed : 9245
# Rep completed : 9246
# Rep completed : 9247
# Rep completed : 9248
# Rep completed : 9249
# Rep completed : 9250
# Rep completed : 9251
# Rep completed : 9252
# Rep completed : 9253
# Rep completed : 9254
# Rep completed : 9255
# Rep completed : 9256
# Rep completed : 9257
# Rep completed : 9258
# Rep completed : 9259
# Rep completed : 9260
# Rep completed : 9261
# Rep completed : 9262
# Rep completed : 9263
# Rep completed : 9264
# Rep completed : 9265
# Rep completed : 9266
# Rep completed : 9267
# Rep completed : 9268
# Rep completed : 9269
# Rep completed : 9270
# Rep completed : 9271
# Rep completed : 9272
# Rep completed : 9273
# Rep completed : 9274
# Rep completed : 9275
# Rep completed : 9276
# Rep completed : 9277
# Rep completed : 9278
# Rep completed : 9279
# Rep completed : 9280
# Rep completed : 9281
# Rep completed : 9282
# Rep completed : 9283
# Rep completed : 9284
# Rep completed : 9285
# Rep completed : 9286
# Rep completed : 9287
# Rep completed : 9288
# Rep completed : 9289
# Rep completed : 9290
# Rep completed : 9291
# Rep completed : 9292
# Rep completed : 9293
# Rep completed : 9294
# Rep completed : 9295
# Rep completed : 9296
# Rep completed : 9297
# Rep completed : 9298
# Rep completed : 9299
# Rep completed : 9300
# Rep completed : 9301
# Rep completed : 9302
# Rep completed : 9303
# Rep completed : 9304
# Rep completed : 9305
# Rep completed : 9306
# Rep completed : 9307
# Rep completed : 9308
# Rep completed : 9309
# Rep completed : 9310
# Rep completed : 9311
# Rep completed : 9312
# Rep completed : 9313
# Rep completed : 9314
# Rep completed : 9315
# Rep completed : 9316
# Rep completed : 9317
# Rep completed : 9318
# Rep completed : 9319
# Rep completed : 9320
# Rep completed : 9321
# Rep completed : 9322
# Rep completed : 9323
# Rep completed : 9324
# Rep completed : 9325
# Rep completed : 9326
# Rep completed : 9327
# Rep completed : 9328
# Rep completed : 9329
# Rep completed : 9330
# Rep completed : 9331
# Rep completed : 9332
# Rep completed : 9333
# Rep completed : 9334
# Rep completed : 9335
# Rep completed : 9336
# Rep completed : 9337
# Rep completed : 9338
# Rep completed : 9339
# Rep completed : 9340
# Rep completed : 9341
# Rep completed : 9342
# Rep completed : 9343
# Rep completed : 9344
# Rep completed : 9345
# Rep completed : 9346
# Rep completed : 9347
# Rep completed : 9348
# Rep completed : 9349
# Rep completed : 9350
# Rep completed : 9351
# Rep completed : 9352
# Rep completed : 9353
# Rep completed : 9354
# Rep completed : 9355
# Rep completed : 9356
# Rep completed : 9357
# Rep completed : 9358
# Rep completed : 9359
# Rep completed : 9360
# Rep completed : 9361
# Rep completed : 9362
# Rep completed : 9363
# Rep completed : 9364
# Rep completed : 9365
# Rep completed : 9366
# Rep completed : 9367
# Rep completed : 9368
# Rep completed : 9369
# Rep completed : 9370
# Rep completed : 9371
# Rep completed : 9372
# Rep completed : 9373
# Rep completed : 9374
# Rep completed : 9375
# Rep completed : 9376
# Rep completed : 9377
# Rep completed : 9378
# Rep completed : 9379
# Rep completed : 9380
# Rep completed : 9381
# Rep completed : 9382
# Rep completed : 9383
# Rep completed : 9384
# Rep completed : 9385
# Rep completed : 9386
# Rep completed : 9387
# Rep completed : 9388
# Rep completed : 9389
# Rep completed : 9390
# Rep completed : 9391
# Rep completed : 9392
# Rep completed : 9393
# Rep completed : 9394
# Rep completed : 9395
# Rep completed : 9396
# Rep completed : 9397
# Rep completed : 9398
# Rep completed : 9399
# Rep completed : 9400
# Rep completed : 9401
# Rep completed : 9402
# Rep completed : 9403
# Rep completed : 9404
# Rep completed : 9405
# Rep completed : 9406
# Rep completed : 9407
# Rep completed : 9408
# Rep completed : 9409
# Rep completed : 9410
# Rep completed : 9411
# Rep completed : 9412
# Rep completed : 9413
# Rep completed : 9414
# Rep completed : 9415
# Rep completed : 9416
# Rep completed : 9417
# Rep completed : 9418
# Rep completed : 9419
# Rep completed : 9420
# Rep completed : 9421
# Rep completed : 9422
# Rep completed : 9423
# Rep completed : 9424
# Rep completed : 9425
# Rep completed : 9426
# Rep completed : 9427
# Rep completed : 9428
# Rep completed : 9429
# Rep completed : 9430
# Rep completed : 9431
# Rep completed : 9432
# Rep completed : 9433
# Rep completed : 9434
# Rep completed : 9435
# Rep completed : 9436
# Rep completed : 9437
# Rep completed : 9438
# Rep completed : 9439
# Rep completed : 9440
# Rep completed : 9441
# Rep completed : 9442
# Rep completed : 9443
# Rep completed : 9444
# Rep completed : 9445
# Rep completed : 9446
# Rep completed : 9447
# Rep completed : 9448
# Rep completed : 9449
# Rep completed : 9450
# Rep completed : 9451
# Rep completed : 9452
# Rep completed : 9453
# Rep completed : 9454
# Rep completed : 9455
# Rep completed : 9456
# Rep completed : 9457
# Rep completed : 9458
# Rep completed : 9459
# Rep completed : 9460
# Rep completed : 9461
# Rep completed : 9462
# Rep completed : 9463
# Rep completed : 9464
# Rep completed : 9465
# Rep completed : 9466
# Rep completed : 9467
# Rep completed : 9468
# Rep completed : 9469
# Rep completed : 9470
# Rep completed : 9471
# Rep completed : 9472
# Rep completed : 9473
# Rep completed : 9474
# Rep completed : 9475
# Rep completed : 9476
# Rep completed : 9477
# Rep completed : 9478
# Rep completed : 9479
# Rep completed : 9480
# Rep completed : 9481
# Rep completed : 9482
# Rep completed : 9483
# Rep completed : 9484
# Rep completed : 9485
# Rep completed : 9486
# Rep completed : 9487
# Rep completed : 9488
# Rep completed : 9489
# Rep completed : 9490
# Rep completed : 9491
# Rep completed : 9492
# Rep completed : 9493
# Rep completed : 9494
# Rep completed : 9495
# Rep completed : 9496
# Rep completed : 9497
# Rep completed : 9498
# Rep completed : 9499
# Rep completed : 9500
# Rep completed : 9501
# Rep completed : 9502
# Rep completed : 9503
# Rep completed : 9504
# Rep completed : 9505
# Rep completed : 9506
# Rep completed : 9507
# Rep completed : 9508
# Rep completed : 9509
# Rep completed : 9510
# Rep completed : 9511
# Rep completed : 9512
# Rep completed : 9513
# Rep completed : 9514
# Rep completed : 9515
# Rep completed : 9516
# Rep completed : 9517
# Rep completed : 9518
# Rep completed : 9519
# Rep completed : 9520
# Rep completed : 9521
# Rep completed : 9522
# Rep completed : 9523
# Rep completed : 9524
# Rep completed : 9525
# Rep completed : 9526
# Rep completed : 9527
# Rep completed : 9528
# Rep completed : 9529
# Rep completed : 9530
# Rep completed : 9531
# Rep completed : 9532
# Rep completed : 9533
# Rep completed : 9534
# Rep completed : 9535
# Rep completed : 9536
# Rep completed : 9537
# Rep completed : 9538
# Rep completed : 9539
# Rep completed : 9540
# Rep completed : 9541
# Rep completed : 9542
# Rep completed : 9543
# Rep completed : 9544
# Rep completed : 9545
# Rep completed : 9546
# Rep completed : 9547
# Rep completed : 9548
# Rep completed : 9549
# Rep completed : 9550
# Rep completed : 9551
# Rep completed : 9552
# Rep completed : 9553
# Rep completed : 9554
# Rep completed : 9555
# Rep completed : 9556
# Rep completed : 9557
# Rep completed : 9558
# Rep completed : 9559
# Rep completed : 9560
# Rep completed : 9561
# Rep completed : 9562
# Rep completed : 9563
# Rep completed : 9564
# Rep completed : 9565
# Rep completed : 9566
# Rep completed : 9567
# Rep completed : 9568
# Rep completed : 9569
# Rep completed : 9570
# Rep completed : 9571
# Rep completed : 9572
# Rep completed : 9573
# Rep completed : 9574
# Rep completed : 9575
# Rep completed : 9576
# Rep completed : 9577
# Rep completed : 9578
# Rep completed : 9579
# Rep completed : 9580
# Rep completed : 9581
# Rep completed : 9582
# Rep completed : 9583
# Rep completed : 9584
# Rep completed : 9585
# Rep completed : 9586
# Rep completed : 9587
# Rep completed : 9588
# Rep completed : 9589
# Rep completed : 9590
# Rep completed : 9591
# Rep completed : 9592
# Rep completed : 9593
# Rep completed : 9594
# Rep completed : 9595
# Rep completed : 9596
# Rep completed : 9597
# Rep completed : 9598
# Rep completed : 9599
# Rep completed : 9600
# Rep completed : 9601
# Rep completed : 9602
# Rep completed : 9603
# Rep completed : 9604
# Rep completed : 9605
# Rep completed : 9606
# Rep completed : 9607
# Rep completed : 9608
# Rep completed : 9609
# Rep completed : 9610
# Rep completed : 9611
# Rep completed : 9612
# Rep completed : 9613
# Rep completed : 9614
# Rep completed : 9615
# Rep completed : 9616
# Rep completed : 9617
# Rep completed : 9618
# Rep completed : 9619
# Rep completed : 9620
# Rep completed : 9621
# Rep completed : 9622
# Rep completed : 9623
# Rep completed : 9624
# Rep completed : 9625
# Rep completed : 9626
# Rep completed : 9627
# Rep completed : 9628
# Rep completed : 9629
# Rep completed : 9630
# Rep completed : 9631
# Rep completed : 9632
# Rep completed : 9633
# Rep completed : 9634
# Rep completed : 9635
# Rep completed : 9636
# Rep completed : 9637
# Rep completed : 9638
# Rep completed : 9639
# Rep completed : 9640
# Rep completed : 9641
# Rep completed : 9642
# Rep completed : 9643
# Rep completed : 9644
# Rep completed : 9645
# Rep completed : 9646
# Rep completed : 9647
# Rep completed : 9648
# Rep completed : 9649
# Rep completed : 9650
# Rep completed : 9651
# Rep completed : 9652
# Rep completed : 9653
# Rep completed : 9654
# Rep completed : 9655
# Rep completed : 9656
# Rep completed : 9657
# Rep completed : 9658
# Rep completed : 9659
# Rep completed : 9660
# Rep completed : 9661
# Rep completed : 9662
# Rep completed : 9663
# Rep completed : 9664
# Rep completed : 9665
# Rep completed : 9666
# Rep completed : 9667
# Rep completed : 9668
# Rep completed : 9669
# Rep completed : 9670
# Rep completed : 9671
# Rep completed : 9672
# Rep completed : 9673
# Rep completed : 9674
# Rep completed : 9675
# Rep completed : 9676
# Rep completed : 9677
# Rep completed : 9678
# Rep completed : 9679
# Rep completed : 9680
# Rep completed : 9681
# Rep completed : 9682
# Rep completed : 9683
# Rep completed : 9684
# Rep completed : 9685
# Rep completed : 9686
# Rep completed : 9687
# Rep completed : 9688
# Rep completed : 9689
# Rep completed : 9690
# Rep completed : 9691
# Rep completed : 9692
# Rep completed : 9693
# Rep completed : 9694
# Rep completed : 9695
# Rep completed : 9696
# Rep completed : 9697
# Rep completed : 9698
# Rep completed : 9699
# Rep completed : 9700
# Rep completed : 9701
# Rep completed : 9702
# Rep completed : 9703
# Rep completed : 9704
# Rep completed : 9705
# Rep completed : 9706
# Rep completed : 9707
# Rep completed : 9708
# Rep completed : 9709
# Rep completed : 9710
# Rep completed : 9711
# Rep completed : 9712
# Rep completed : 9713
# Rep completed : 9714
# Rep completed : 9715
# Rep completed : 9716
# Rep completed : 9717
# Rep completed : 9718
# Rep completed : 9719
# Rep completed : 9720
# Rep completed : 9721
# Rep completed : 9722
# Rep completed : 9723
# Rep completed : 9724
# Rep completed : 9725
# Rep completed : 9726
# Rep completed : 9727
# Rep completed : 9728
# Rep completed : 9729
# Rep completed : 9730
# Rep completed : 9731
# Rep completed : 9732
# Rep completed : 9733
# Rep completed : 9734
# Rep completed : 9735
# Rep completed : 9736
# Rep completed : 9737
# Rep completed : 9738
# Rep completed : 9739
# Rep completed : 9740
# Rep completed : 9741
# Rep completed : 9742
# Rep completed : 9743
# Rep completed : 9744
# Rep completed : 9745
# Rep completed : 9746
# Rep completed : 9747
# Rep completed : 9748
# Rep completed : 9749
# Rep completed : 9750
# Rep completed : 9751
# Rep completed : 9752
# Rep completed : 9753
# Rep completed : 9754
# Rep completed : 9755
# Rep completed : 9756
# Rep completed : 9757
# Rep completed : 9758
# Rep completed : 9759
# Rep completed : 9760
# Rep completed : 9761
# Rep completed : 9762
# Rep completed : 9763
# Rep completed : 9764
# Rep completed : 9765
# Rep completed : 9766
# Rep completed : 9767
# Rep completed : 9768
# Rep completed : 9769
# Rep completed : 9770
# Rep completed : 9771
# Rep completed : 9772
# Rep completed : 9773
# Rep completed : 9774
# Rep completed : 9775
# Rep completed : 9776
# Rep completed : 9777
# Rep completed : 9778
# Rep completed : 9779
# Rep completed : 9780
# Rep completed : 9781
# Rep completed : 9782
# Rep completed : 9783
# Rep completed : 9784
# Rep completed : 9785
# Rep completed : 9786
# Rep completed : 9787
# Rep completed : 9788
# Rep completed : 9789
# Rep completed : 9790
# Rep completed : 9791
# Rep completed : 9792
# Rep completed : 9793
# Rep completed : 9794
# Rep completed : 9795
# Rep completed : 9796
# Rep completed : 9797
# Rep completed : 9798
# Rep completed : 9799
# Rep completed : 9800
# Rep completed : 9801
# Rep completed : 9802
# Rep completed : 9803
# Rep completed : 9804
# Rep completed : 9805
# Rep completed : 9806
# Rep completed : 9807
# Rep completed : 9808
# Rep completed : 9809
# Rep completed : 9810
# Rep completed : 9811
# Rep completed : 9812
# Rep completed : 9813
# Rep completed : 9814
# Rep completed : 9815
# Rep completed : 9816
# Rep completed : 9817
# Rep completed : 9818
# Rep completed : 9819
# Rep completed : 9820
# Rep completed : 9821
# Rep completed : 9822
# Rep completed : 9823
# Rep completed : 9824
# Rep completed : 9825
# Rep completed : 9826
# Rep completed : 9827
# Rep completed : 9828
# Rep completed : 9829
# Rep completed : 9830
# Rep completed : 9831
# Rep completed : 9832
# Rep completed : 9833
# Rep completed : 9834
# Rep completed : 9835
# Rep completed : 9836
# Rep completed : 9837
# Rep completed : 9838
# Rep completed : 9839
# Rep completed : 9840
# Rep completed : 9841
# Rep completed : 9842
# Rep completed : 9843
# Rep completed : 9844
# Rep completed : 9845
# Rep completed : 9846
# Rep completed : 9847
# Rep completed : 9848
# Rep completed : 9849
# Rep completed : 9850
# Rep completed : 9851
# Rep completed : 9852
# Rep completed : 9853
# Rep completed : 9854
# Rep completed : 9855
# Rep completed : 9856
# Rep completed : 9857
# Rep completed : 9858
# Rep completed : 9859
# Rep completed : 9860
# Rep completed : 9861
# Rep completed : 9862
# Rep completed : 9863
# Rep completed : 9864
# Rep completed : 9865
# Rep completed : 9866
# Rep completed : 9867
# Rep completed : 9868
# Rep completed : 9869
# Rep completed : 9870
# Rep completed : 9871
# Rep completed : 9872
# Rep completed : 9873
# Rep completed : 9874
# Rep completed : 9875
# Rep completed : 9876
# Rep completed : 9877
# Rep completed : 9878
# Rep completed : 9879
# Rep completed : 9880
# Rep completed : 9881
# Rep completed : 9882
# Rep completed : 9883
# Rep completed : 9884
# Rep completed : 9885
# Rep completed : 9886
# Rep completed : 9887
# Rep completed : 9888
# Rep completed : 9889
# Rep completed : 9890
# Rep completed : 9891
# Rep completed : 9892
# Rep completed : 9893
# Rep completed : 9894
# Rep completed : 9895
# Rep completed : 9896
# Rep completed : 9897
# Rep completed : 9898
# Rep completed : 9899
# Rep completed : 9900
# Rep completed : 9901
# Rep completed : 9902
# Rep completed : 9903
# Rep completed : 9904
# Rep completed : 9905
# Rep completed : 9906
# Rep completed : 9907
# Rep completed : 9908
# Rep completed : 9909
# Rep completed : 9910
# Rep completed : 9911
# Rep completed : 9912
# Rep completed : 9913
# Rep completed : 9914
# Rep completed : 9915
# Rep completed : 9916
# Rep completed : 9917
# Rep completed : 9918
# Rep completed : 9919
# Rep completed : 9920
# Rep completed : 9921
# Rep completed : 9922
# Rep completed : 9923
# Rep completed : 9924
# Rep completed : 9925
# Rep completed : 9926
# Rep completed : 9927
# Rep completed : 9928
# Rep completed : 9929
# Rep completed : 9930
# Rep completed : 9931
# Rep completed : 9932
# Rep completed : 9933
# Rep completed : 9934
# Rep completed : 9935
# Rep completed : 9936
# Rep completed : 9937
# Rep completed : 9938
# Rep completed : 9939
# Rep completed : 9940
# Rep completed : 9941
# Rep completed : 9942
# Rep completed : 9943
# Rep completed : 9944
# Rep completed : 9945
# Rep completed : 9946
# Rep completed : 9947
# Rep completed : 9948
# Rep completed : 9949
# Rep completed : 9950
# Rep completed : 9951
# Rep completed : 9952
# Rep completed : 9953
# Rep completed : 9954
# Rep completed : 9955
# Rep completed : 9956
# Rep completed : 9957
# Rep completed : 9958
# Rep completed : 9959
# Rep completed : 9960
# Rep completed : 9961
# Rep completed : 9962
# Rep completed : 9963
# Rep completed : 9964
# Rep completed : 9965
# Rep completed : 9966
# Rep completed : 9967
# Rep completed : 9968
# Rep completed : 9969
# Rep completed : 9970
# Rep completed : 9971
# Rep completed : 9972
# Rep completed : 9973
# Rep completed : 9974
# Rep completed : 9975
# Rep completed : 9976
# Rep completed : 9977
# Rep completed : 9978
# Rep completed : 9979
# Rep completed : 9980
# Rep completed : 9981
# Rep completed : 9982
# Rep completed : 9983
# Rep completed : 9984
# Rep completed : 9985
# Rep completed : 9986
# Rep completed : 9987
# Rep completed : 9988
# Rep completed : 9989
# Rep completed : 9990
# Rep completed : 9991
# Rep completed : 9992
# Rep completed : 9993
# Rep completed : 9994
# Rep completed : 9995
# Rep completed : 9996
# Rep completed : 9997
# Rep completed : 9998
# Rep completed : 9999
# 10000
# CPU times: user 11.3 s, sys: 2.42 s, total: 13.7 s
# Wall time: 27min 33s

# %%
plt.figure(figsize=[25,25])

ax = sns.heatmap(mean_df_corr, annot=True, fmt=".2f", cmap= "seismic", square=True, center=0, vmin=-1, vmax=1, edgecolors='w', linewidths=3, cbar_kws={"shrink": .82}, ) #notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)


plt.show();

# %%
def split_residual_rsquare(df, proportion):
    
    num_durations = len(df.duration.unique())
    
    duration_residual_r2 = [None] * num_durations
    
    i = 0
    for dur in df.duration.unique():
        split1 = [] 
        split2 = []
        stim_actual = []
        duration_df = df.loc[df['duration'] == dur]
        duration_stim = duration_df.stimulus.unique()
        
        grouped = duration_df.groupby(duration_df.stimulus) 
        for stim in duration_stim:   
            stim_df = grouped.get_group(stim)
            stim_df_estimates = stim_df['depth_estimate'].tolist()
            stim_df_actual = stim_df['actual_depth'].tolist()[0]
            random.shuffle(stim_df_estimates)
            
            estim_avg_df0 = np.mean(np.array(stim_df_estimates[0:int(len(stim_df_estimates)*proportion)]))
            estim_avg_df1 = np.mean(np.array(stim_df_estimates[int(len(stim_df_estimates)*proportion):int(len(stim_df_estimates)*proportion) * 2]))
   
            split1.append(estim_avg_df0) 
            split2.append(estim_avg_df1)
            stim_actual.append(stim_df_actual)
        
        split1 = np.array(split1).reshape(1,-1)
        split2 = np.array(split2).reshape(1,-1)
        stim_actual = np.array(stim_actual).reshape(1,-1)

        reg_split1 = LinearRegression().fit(split1, stim_actual)
        reg_split2 = LinearRegression().fit(split2, stim_actual)

        #Generated Predictions
        y_predicted_s1 = reg_split1.predict(stim_actual)
        split1_residuals = split1-y_predicted_s1
        
        y_predicted_s2 = reg_split2.predict(stim_actual)
        split2_residuals = split2-y_predicted_s2
        # add duration corr to list                                
        duration_residual_r2[i] = r2_score(split1_residuals[0], split2_residuals[0])
        i += 1
        

    return duration_residual_r2

def generate_n_split_r2(n, data, proportion):
    """
    add
    """

    residual_r2s = np.array([split_residual_rsquare(data, proportion) for i in range(n)])
    mean = np.mean(residual_r2s, axis = 0) 
    
    return residual_r2s, mean

# %%
# r2_100_05 = generate_n_split_r2(100, zs_df, 0.5)
# r2_100_04 = generate_n_split_r2(100, zs_df, 0.4)
# r2_100_03 = generate_n_split_r2(100, zs_df, 0.3)
# r2_100_02 = generate_n_split_r2(100, zs_df, 0.2)

r2_100_05 = generate_n_split_r2(10, zs_df, 0.5)

# %%
durations = ['125 ms', '250 ms', '1000 ms']
plt.plot(durations, r2_100_05[1], color = 'green', label= 'fraction = 0.5')
plt.plot(durations, r2_100_04[1], color = 'blue', label= 'fraction = 0.4')
plt.plot(durations, r2_100_03[1], color = 'purple', label= 'fraction = 0.3')
plt.plot(durations, r2_100_02[1], color = 'orange', label= 'fraction = 0.2')
plt.title('Average Residual R-Squared')
plt.legend(fontsize = 9)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize = [8, 7])
a = [r2_100_05[1], r2_100_04[1], r2_100_03[1], r2_100_02[1]]

ax = sns.heatmap(a, annot=True, fmt=".2f", annot_kws={"fontsize":22}, cmap= "PRGn", square=False, center=0, vmin=-1, vmax=1, edgecolors='w', linewidths=2, cbar_kws={"shrink": .82}) #notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

# ax = sns.heatmap(a, linewidth=0.5, annot=True, cmap='coolwarm')
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

plt.xlabel('Duration', fontsize = 14)

plt.ylabel('Fraction', fontsize = 14)



plt.title('Raw Split Residual R-Squared', fontsize = 15)
# Out:
# Text(0.5, 1, 'Raw Split Residual R-Squared')
